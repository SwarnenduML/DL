# %% [markdown]
# # Deep learning programming I-A: Regression
# Felix Wiewel, Institute of Signal Processing and System Theory, University of Stuttgart, 08.02.2021
# ###  Implementation
#
# In the following we consider a simple regression task, implement a neural network and train it based on the mathematical fomrulation above. For this we first need to create a set of input-output pairs, which then needs to be partitioned into a training, validation and test set. We also define some constants to be used for partitioning the data and the hyperparameters for our neural network.
#
# But before we can start, we need to import the necessary packages tensorflow, numpy and matplotlib.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Next we define our constants and set the random seeds of tensorflow and numpy in order to get reproducable results.

# %%
N_train_samples = 600
N_validation_samples = 100
N_test_samples = 100
N_samples = N_train_samples + N_validation_samples + N_test_samples
noise_sig = 0.1
N_epochs = 150
batch_size = 8
learning_rate = 0.01

tf.random.set_seed(0)
np.random.seed(0)

# %% [markdown]
# We create $600$ training samples, $100$ validation samples to optimize our hyperparameters and $100$ test samples, which are used to check if our model can generalize to unseen data. Furthermore we set the level of noise added to the observations. For training the model we plan to train it for $150$ epochs with a batch size of $8$ and a learning rate of $0.01$. Next we create the actual input-output pairs $\mathbf{x},\mathbf{y}$ for which we want to learn the regression model and plot them. In this simple example we choose scalar inputs as well as output but in general $\mathbf{x}$ and $\mathbf{y}$ can be vectors.

# %%
x = np.linspace(0.0, 3.0, N_samples, dtype=np.float32)
y = np.expand_dims(np.sin(1.0+x*x) + noise_sig*np.random.randn(N_samples).astype(np.float32), axis=-1)
y_true = np.sin(1.0+x*x)

plt.plot(x, y)
plt.plot(x, y_true)
plt.legend(["Observation", "Ground truth"])
plt.show()

# %% [markdown]
# With the input-output pairs created, your first task is now to partition the data in the training, validation and test sets. Keep in mind that we have created the data in a structured way, i.e. the input-output pairs are ordered. This means you need to shuffle the data before partitioning it.

# %%
""" Shuffle and partition the data set accordingly. you can use the predefined constants "N_train_samples", "N_validation_samples" and "N_test_samples". Use the variable names that are already in the below code 
to store the final shuffled and partitioned data. Hint: Shuffle the data and the labels in such a way that the pairing between an image and it's label is preserved."""
# Shuffle the data
tmp_var = np.arange(N_samples)
np.random.shuffle(tmp_var)
ind_train = tmp_var[:N_train_samples]
ind_test = tmp_var[N_train_samples:N_train_samples+N_test_samples]
ind_val = tmp_var[N_train_samples + N_test_samples:]
#print(ind_train)
# Partition the data
x_train = x[ind_train]#.reshape([1,N_train_samples,])
y_train = y[ind_train]#.reshape([1,N_train_samples,])
x_validation = x[ind_val].reshape([1,N_validation_samples])
y_validation = y[ind_val].reshape([1,N_validation_samples])
x_test = x[ind_test].reshape([1,N_test_samples])
y_test = y[ind_test].reshape([1,N_test_samples])

# %% [markdown]
# In order to feed the data to our model, we will use the Dataset class provided by Tensorflow. This class is simple to use and provides all the functionality we need for shuffling, batching and feeding the data to our model. It is also tightly integrated into the Tensorflow framework, which makes it very performant. Performance is not an aspect we need to worry about in this exercise, but it is important in more demanding applications.
#
# In this exercise we instantiate a separate Dataset object for the training, validation and test data sets, where we shuffle and repeat just the training data set. Shuffling the validation and test data sets is not necessary, since we only evaluate the loss on those data sets and do not perform SGD on it. Please fill in the missing part of the code.

# %%
""" Create three tensorflow Dataset objects that can be used to feed the training test and validation data to a neural network. Hint: For the training data set use shuffling, batching with the size according to
the predefined constant "batch_size" and repeat the data set indefinetly. For the validation and test data sets no shuffling or batching is needed."""

train_ds = tf.data.Dataset.from_tensor_slices((x_train,y_train))
train_ds = train_ds.shuffle(batch_size).batch(batch_size).repeat()

validation_ds = tf.data.Dataset.from_tensor_slices((x_validation,y_validation))
test_ds = tf.data.Dataset.from_tensor_slices((x_test, y_test))

# %% [markdown]
# In this exercise we will create a a simple neural network with two hidden layers containing $10$ neurons. For creating a model and keeping track of its weights a class called MyModel is used. When initializing an instance of this class the necessary variables are created and stored in a list called "trainable_variables". This makes it easy to get all trainable variables of the model. We also override the \__call__ method of this class in order to implement the forward pass of the neural network. This method should accept the inputs to the neural network and should return the result of the forward pass as an output. Please fill in the missing part of the code and select suitable activation functions for the different layers.

# %%
""" Implement a neural network with two hidden dense layers containing 10 neurons each. As an activation function use the tangens hyperbolicus (tf.nn.tanh()). Since we are not using Keras, we need to create and 
manage all the variables that we need ourselves. The varaibles are created in the constructor of our model class. Since we want to be able to just call the class with some inputs in order to make a prediction, 
we implement a __call__ method which computes the forward pass and returns the output of the network."""

class MyModel(object):
    def __init__(self):
        # Create model variables
        self.W0 = tf.Variable(tf.random.normal(([1,10])))
        self.b0 = tf.Variable(tf.random.normal(()))
        self.W1 = tf.Variable(tf.random.normal(([10,10])))
        self.b1 = tf.Variable(tf.random.normal(([10])))
        self.W2 = tf.Variable(tf.random.normal(([10,1])))
        self.b2 = tf.Variable(tf.random.normal(()))
        self.trainable_variables = [self.W0, self.b0, self.W1, self.b1, self.W2, self.b2]

    def __call__(self, inputs):
        # Compute forward pass
        output = tf.reshape(inputs, [-1, 1])
#        print(output.numpy().shape)
        output = tf.nn.tanh(tf.add(tf.matmul(output, self.W0), self.b0))
#        print(output.numpy().shape)
#        print(output.numpy())
        output = tf.nn.tanh(tf.add(tf.matmul(output, self.W1), self.b1))
#        print(output.numpy().shape)
#        print(output.numpy())
        output = tf.add(tf.matmul(output, self.W2), self.b2)
#        print(output.numpy().shape)
#        print(output.numpy())
        return output

# %% [markdown]
# Now after the model class is defined we can instantiate a MyModel object by running

# %%
mdl = MyModel()

# %% [markdown]
# We can now use the model to make predictions by calling it. In the following we predict on the inputs an plot the result.

# %%
""" We want to plot a prediction on the complete data set with a model before training. For this make a prediction on the variable "x". """

y_pred = mdl.__call__(x) # Compute a prediction on the variable "x"
plt.plot(x, y)
plt.plot(x, y_true)
plt.plot(x, y_pred.numpy())
plt.legend(["Observation", "Target", "Prediction"])
plt.show()

# %% [markdown]
# Since we have initialized the variables of the neural network randomly, it's prediction is also random. In order to fit the model we need to minimize the expected mean squared error over all input-ouput pairs in our training data set. For this we need to create a function, that performs a training step when provided with the model, an optimizer and a batch of input-ouput pairs.

# %%
""" For training we need to implement a function that executes one training step. Fill in the missing code pieces for this function."""

def train_step(model, optimizer, x, y):
    with tf.GradientTape() as tape:
        tape.watch(model.trainable_variables)
        y_pred = model.__call__(x) # Compute a prediction with "model" on the input "x"
        loss_val = tf.reduce_sum(tf.pow(y_pred-y, 2)) / (2 * y_pred.shape[0])# Compute the Mean Squared Error (MSE) for the prediction "y_pred" and the targets "y"
    grads = tape.gradient(loss_val, model.trainable_variables)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))
    return loss_val

# %% [markdown]
# This function uses the GradientTape to record the operations for which gradients have to be calculated. In our case this is the forward pass through our model and the computation of the loss function. After these operations are recoded we can get their gradients and apply these through the use of an optimizer. Finally we return the loss value in order to print it.
#
# With the training step function defined we now need to choose a suitable optimizer. Tensorflow offers a wide variety of optimizers but in this exercise we will use the RMSprop optimizer.

# %%
opt = tf.optimizers.RMSprop(learning_rate)

# %% [markdown]
# We now have everything we need to start training the model. For this we repeatedly sample a batch of input-output pairs from our training data set and use the train_step function to minimize the loss function over this batch. We repeat this until we have iterated over the complete training data set once. After this we compute the loss on the validation data set, print it and repeat with another epoch until we have reached $N\_epochs$ epochs.

# %%
for x_t, y_t in test_ds:
    y_pred = mdl.__call__(x_t) # Compute a prediction with "mdl" on the input "x_v"
    test_loss = tf.reduce_sum(tf.pow(y_pred-y_t, 2)) / (2 * y_pred.shape[0])
print("Test loss: {:.5}".format(test_loss))
# Out:
# Test loss: 489.25

# %%
""" We can now use the train_step function to perform the training. Fill in the missing code parts."""

epoch = 0
train_iters = 0
train_loss = 0.0
for x_t, y_t in train_ds:
    train_loss += train_step(mdl,opt,x_t,y_t)# Perform a training step with the model "mdl" and the optimizer "opt" on the inputs "x_t" and the corresponding targets "y_t"
    train_iters += 1
#    print(train_iters)
    if batch_size * train_iters == N_train_samples:# An epoch is completed
        for x_v, y_v in validation_ds:
            y_pred = mdl.__call__(x_v) # Compute a prediction with "mdl" on the input "x_v"
            validation_loss = tf.reduce_sum(tf.pow(y_pred-y_v, 2)) / (2 * y_pred.shape[0])# Compute the Mean Squared Error (MSE) for the prediction "y_pred" and the targets "y_v"
        print("Epoch: {} Train loss: {:.5} Validation loss: {:.5}".format(epoch, train_loss/train_iters, validation_loss))
        train_iters = 0
        train_loss = 0.0
        epoch += 1
    if (epoch == N_epochs):
        break
# Out:
# Epoch: 0 Train loss: 0.35257 Validation loss: 40.11
# Epoch: 1 Train loss: 0.065208 Validation loss: 38.272
# Epoch: 2 Train loss: 0.051965 Validation loss: 39.468
# Epoch: 3 Train loss: 0.043215 Validation loss: 40.169
# Epoch: 4 Train loss: 0.037421 Validation loss: 39.324
# Epoch: 5 Train loss: 0.030171 Validation loss: 40.753
# Epoch: 6 Train loss: 0.023832 Validation loss: 39.862
# Epoch: 7 Train loss: 0.018726 Validation loss: 41.653
# Epoch: 8 Train loss: 0.015103 Validation loss: 42.239
# Epoch: 9 Train loss: 0.016208 Validation loss: 41.536
# Epoch: 10 Train loss: 0.015502 Validation loss: 42.186
# Epoch: 11 Train loss: 0.014624 Validation loss: 42.184
# Epoch: 12 Train loss: 0.014765 Validation loss: 41.87
# Epoch: 13 Train loss: 0.013866 Validation loss: 42.475
# Epoch: 14 Train loss: 0.014583 Validation loss: 41.926
# Epoch: 15 Train loss: 0.013647 Validation loss: 42.082
# Epoch: 16 Train loss: 0.013624 Validation loss: 42.391
# Epoch: 17 Train loss: 0.013951 Validation loss: 42.821
# Epoch: 18 Train loss: 0.013116 Validation loss: 42.219
# Epoch: 19 Train loss: 0.013032 Validation loss: 42.58
# Epoch: 20 Train loss: 0.01236 Validation loss: 42.242
# Epoch: 21 Train loss: 0.014524 Validation loss: 42.28
# Epoch: 22 Train loss: 0.012952 Validation loss: 42.715
# Epoch: 23 Train loss: 0.013675 Validation loss: 44.007
# Epoch: 24 Train loss: 0.013563 Validation loss: 42.036
# Epoch: 25 Train loss: 0.012885 Validation loss: 43.364
# Epoch: 26 Train loss: 0.013233 Validation loss: 42.707
# Epoch: 27 Train loss: 0.012532 Validation loss: 43.134
# Epoch: 28 Train loss: 0.013908 Validation loss: 42.387
# Epoch: 29 Train loss: 0.013323 Validation loss: 42.62
# Epoch: 30 Train loss: 0.012955 Validation loss: 42.42
# Epoch: 31 Train loss: 0.013634 Validation loss: 42.31
# Epoch: 32 Train loss: 0.01168 Validation loss: 42.444
# Epoch: 33 Train loss: 0.01278 Validation loss: 42.153
# Epoch: 34 Train loss: 0.011738 Validation loss: 43.09
# Epoch: 35 Train loss: 0.013339 Validation loss: 43.879
# Epoch: 36 Train loss: 0.013149 Validation loss: 41.615
# Epoch: 37 Train loss: 0.01265 Validation loss: 42.323
# Epoch: 38 Train loss: 0.013924 Validation loss: 42.625
# Epoch: 39 Train loss: 0.012024 Validation loss: 43.657
# Epoch: 40 Train loss: 0.013194 Validation loss: 42.298
# Epoch: 41 Train loss: 0.011961 Validation loss: 43.126
# Epoch: 42 Train loss: 0.012369 Validation loss: 44.009
# Epoch: 43 Train loss: 0.01206 Validation loss: 42.956
# Epoch: 44 Train loss: 0.013087 Validation loss: 43.488
# Epoch: 45 Train loss: 0.01268 Validation loss: 42.757
# Epoch: 46 Train loss: 0.01207 Validation loss: 42.637
# Epoch: 47 Train loss: 0.011853 Validation loss: 42.967
# Epoch: 48 Train loss: 0.012661 Validation loss: 42.642
# Epoch: 49 Train loss: 0.01187 Validation loss: 42.5
# Epoch: 50 Train loss: 0.01235 Validation loss: 42.727
# Epoch: 51 Train loss: 0.011044 Validation loss: 43.155
# Epoch: 52 Train loss: 0.01186 Validation loss: 42.39
# Epoch: 53 Train loss: 0.012582 Validation loss: 42.648
# Epoch: 54 Train loss: 0.012017 Validation loss: 42.525
# Epoch: 55 Train loss: 0.012424 Validation loss: 42.724
# Epoch: 56 Train loss: 0.011176 Validation loss: 43.58
# Epoch: 57 Train loss: 0.012952 Validation loss: 42.595
# Epoch: 58 Train loss: 0.012173 Validation loss: 42.588
# Epoch: 59 Train loss: 0.011497 Validation loss: 43.042
# Epoch: 60 Train loss: 0.013011 Validation loss: 42.546
# Epoch: 61 Train loss: 0.011864 Validation loss: 43.618
# Epoch: 62 Train loss: 0.012127 Validation loss: 42.34
# Epoch: 63 Train loss: 0.011656 Validation loss: 43.026
# Epoch: 64 Train loss: 0.011236 Validation loss: 43.637
# Epoch: 65 Train loss: 0.011626 Validation loss: 43.395
# Epoch: 66 Train loss: 0.011628 Validation loss: 42.4
# Epoch: 67 Train loss: 0.012156 Validation loss: 43.075
# Epoch: 68 Train loss: 0.012967 Validation loss: 42.745
# Epoch: 69 Train loss: 0.01241 Validation loss: 42.355
# Epoch: 70 Train loss: 0.012127 Validation loss: 42.287
# Epoch: 71 Train loss: 0.012554 Validation loss: 42.138
# Epoch: 72 Train loss: 0.011317 Validation loss: 42.83
# Epoch: 73 Train loss: 0.011891 Validation loss: 42.589
# Epoch: 74 Train loss: 0.011502 Validation loss: 42.292
# Epoch: 75 Train loss: 0.011955 Validation loss: 42.94
# Epoch: 76 Train loss: 0.012021 Validation loss: 42.962
# Epoch: 77 Train loss: 0.011979 Validation loss: 42.705
# Epoch: 78 Train loss: 0.012247 Validation loss: 44.098
# Epoch: 79 Train loss: 0.01203 Validation loss: 41.88
# Epoch: 80 Train loss: 0.010978 Validation loss: 43.381
# Epoch: 81 Train loss: 0.012293 Validation loss: 43.171
# Epoch: 82 Train loss: 0.011547 Validation loss: 43.433
# Epoch: 83 Train loss: 0.011787 Validation loss: 43.148
# Epoch: 84 Train loss: 0.011229 Validation loss: 43.234
# Epoch: 85 Train loss: 0.01173 Validation loss: 43.624
# Epoch: 86 Train loss: 0.01165 Validation loss: 42.177
# Epoch: 87 Train loss: 0.011875 Validation loss: 42.733
# Epoch: 88 Train loss: 0.011824 Validation loss: 42.546
# Epoch: 89 Train loss: 0.011115 Validation loss: 42.621
# Epoch: 90 Train loss: 0.011574 Validation loss: 42.491
# Epoch: 91 Train loss: 0.01228 Validation loss: 42.973
# Epoch: 92 Train loss: 0.011784 Validation loss: 43.123
# Epoch: 93 Train loss: 0.010977 Validation loss: 43.736
# Epoch: 94 Train loss: 0.012868 Validation loss: 42.607
# Epoch: 95 Train loss: 0.011887 Validation loss: 43.113
# Epoch: 96 Train loss: 0.012401 Validation loss: 43.007
# Epoch: 97 Train loss: 0.011285 Validation loss: 42.679
# Epoch: 98 Train loss: 0.011306 Validation loss: 43.089
# Epoch: 99 Train loss: 0.011983 Validation loss: 42.654
# Epoch: 100 Train loss: 0.011734 Validation loss: 43.187
# Epoch: 101 Train loss: 0.011338 Validation loss: 42.484
# Epoch: 102 Train loss: 0.011631 Validation loss: 42.05
# Epoch: 103 Train loss: 0.011375 Validation loss: 42.174
# Epoch: 104 Train loss: 0.011705 Validation loss: 42.97
# Epoch: 105 Train loss: 0.011866 Validation loss: 42.37
# Epoch: 106 Train loss: 0.011811 Validation loss: 42.806
# Epoch: 107 Train loss: 0.011665 Validation loss: 43.452
# Epoch: 108 Train loss: 0.011092 Validation loss: 43.453
# Epoch: 109 Train loss: 0.011651 Validation loss: 42.787
# Epoch: 110 Train loss: 0.01196 Validation loss: 42.792
# Epoch: 111 Train loss: 0.010673 Validation loss: 41.943
# Epoch: 112 Train loss: 0.011859 Validation loss: 42.539
# Epoch: 113 Train loss: 0.011585 Validation loss: 42.735
# Epoch: 114 Train loss: 0.012093 Validation loss: 42.847
# Epoch: 115 Train loss: 0.011909 Validation loss: 43.041
# Epoch: 116 Train loss: 0.012337 Validation loss: 42.583
# Epoch: 117 Train loss: 0.011359 Validation loss: 42.83
# Epoch: 118 Train loss: 0.011089 Validation loss: 42.953
# Epoch: 119 Train loss: 0.011685 Validation loss: 43.15
# Epoch: 120 Train loss: 0.011118 Validation loss: 43.215
# Epoch: 121 Train loss: 0.011784 Validation loss: 43.327
# Epoch: 122 Train loss: 0.0116 Validation loss: 43.237
# Epoch: 123 Train loss: 0.011116 Validation loss: 42.907
# Epoch: 124 Train loss: 0.011468 Validation loss: 43.122
# Epoch: 125 Train loss: 0.011013 Validation loss: 43.315
# Epoch: 126 Train loss: 0.011832 Validation loss: 42.23
# Epoch: 127 Train loss: 0.010978 Validation loss: 42.902
# Epoch: 128 Train loss: 0.011436 Validation loss: 42.871
# Epoch: 129 Train loss: 0.011569 Validation loss: 42.535
# Epoch: 130 Train loss: 0.011489 Validation loss: 43.379
# Epoch: 131 Train loss: 0.011092 Validation loss: 43.589
# Epoch: 132 Train loss: 0.012579 Validation loss: 42.793
# Epoch: 133 Train loss: 0.011733 Validation loss: 43.083
# Epoch: 134 Train loss: 0.01198 Validation loss: 42.975
# Epoch: 135 Train loss: 0.011262 Validation loss: 43.009
# Epoch: 136 Train loss: 0.012011 Validation loss: 42.734
# Epoch: 137 Train loss: 0.011683 Validation loss: 42.417
# Epoch: 138 Train loss: 0.011123 Validation loss: 43.011
# Epoch: 139 Train loss: 0.011844 Validation loss: 42.963
# Epoch: 140 Train loss: 0.011459 Validation loss: 42.712
# Epoch: 141 Train loss: 0.011518 Validation loss: 42.726
# Epoch: 142 Train loss: 0.012161 Validation loss: 42.885
# Epoch: 143 Train loss: 0.011569 Validation loss: 43.246
# Epoch: 144 Train loss: 0.011378 Validation loss: 43.453
# Epoch: 145 Train loss: 0.011461 Validation loss: 42.269
# Epoch: 146 Train loss: 0.011458 Validation loss: 43.077
# Epoch: 147 Train loss: 0.011442 Validation loss: 43.063
# Epoch: 148 Train loss: 0.011595 Validation loss: 42.393
# Epoch: 149 Train loss: 0.010694 Validation loss: 42.712

# %% [markdown]
# After completion of the training process we use the test data set to test the models generalization to unseen data.

# %%
for x_t, y_t in test_ds:
    y_pred = mdl.__call__(x_t) # Compute a prediction with "mdl" on the input "x_v"
    test_loss = tf.reduce_sum(tf.pow(y_pred-y_t, 2)) / (2 * y_pred.shape[0])
print("Test loss: {:.5}".format(test_loss))
# Out:
# Test loss: 45.732

# %% [markdown]
# After we have verified that our model achieves a similar loss on the test as on the validation and training data set, we can conclude that our model is not overfitting or underfitting and generalizes to unseen data. We can now predict on the inputs again and plot the results.

# %%
""" Now we want to plot the prediction after training. Predict on the variable "x" again. """

y_pred = mdl.__call__(x)# Compute a prediction on the variable "x"
plt.plot(x, y)
plt.plot(x, y_true)
plt.plot(x, y_pred.numpy())
plt.legend(["Observation", "Target", "Prediction"])
plt.show()

# %% [markdown]
# Now our model has learned to approximate the function mapping from the input to the output. The capability of neural networks to learn from input-ouput pairs alone and approximate an arbitrary function, see universal approximation theorem, can be very useful if the mapping between the input and output is too complex to be captured with model based approaches. But learning from input-ouput pairs alone implies that the model will only be able to make accurate predictions over input ranges it has seen during training. In order to demonstrate this we will predict on an interval that exeeds the $\left[0,3\right]$ interval the model was trained on, i.e. we will predict on the interval $\left[-2,5\right]$.

# %%
x_generalize = np.linspace(-2.0, 5.0, N_samples, dtype=np.float32)
y_generalize = np.sin(1.0+x_generalize*x_generalize) + noise_sig*np.random.randn(N_samples).astype(np.float32)
y_truey_generalize = np.sin(1.0+x_generalize*x_generalize)
y_pred = mdl(x_generalize)
plt.plot(x_generalize, y_generalize)
plt.plot(x_generalize, y_truey_generalize)
plt.plot(x_generalize, y_pred.numpy())
plt.legend(["Observation", "Target", "Prediction"])
plt.show()

# %% [markdown]
# As expected, the model is able to make farely accurate predictions on the interval it was trained on but makes unreliable predictions outside this interval.
#
# ### Regularization
# With the theoretical background on regularization we can now implement it and observe it's effects on the regression problem covered in this exercise. For this we will define a model with a high capacity and train it for a extended time to provoke overfitting. For this, we will increase the number of hidden neurons in both hidden layers to $100$ and $50$.

# %%
""" Implement a bigger model with again two hidden layers contatining 100 and 50 neurons. As an activation use the tangens hyperbolicus function where it is appropiate. """

class MyBigModel(object):
    def __init__(self):
        # Create model variables
        self.W0 = tf.Variable(tf.random.normal(([1,100])))
        self.b0 = tf.Variable(tf.random.normal(()))
        self.W1 = tf.Variable(tf.random.normal(([100,50])))
        self.b1 = tf.Variable(tf.random.normal(([50])))
        self.W2 = tf.Variable(tf.random.normal(([50,1])))
        self.b2 = tf.Variable(tf.random.normal(()))
        self.trainable_variables = [self.W0, self.b0, self.W1, self.b1, self.W2, self.b2]

    def __call__(self, inputs):
        # Compute forward pass
        output = tf.reshape(inputs, [-1, 1])
        output = tf.nn.tanh(tf.add(tf.matmul(output, self.W0), self.b0))
        output = tf.nn.tanh(tf.add(tf.matmul(output, self.W1), self.b1))
        output = tf.add(tf.matmul(output, self.W2), self.b2)
        # self.W0 = self.W0 - 0.01*self.W0
        # self.b0 = self.b0 - 0.01*self.b0
        # self.W1 = self.W1 - 0.01*self.W1
        # self.b1 = self.b1 - 0.01*self.b1
        # self.W2 = self.W2 - 0.01*self.W2
        # self.b2 = self.b2 - 0.01*self.b2
        return output

# %% [markdown]
# After creating one instance of this class we can again train it on our data set. We will also create a new optimizer for training this bigger model, since some optimizers adapt the learning rates for individual parameters during a training process and we do not want to train our bigger model with learning rates adopted from an earlier training run.

# %%
big_mdl = MyBigModel()
big_opt = tf.optimizers.SGD(0.001)

# %% [markdown]
# Now we are ready to train this bigger model using the same training step and training loop. In order to provoke overfitting we also reduce the number of samples in the training data set a lot, increase the batch size and train for a more epochs.

# %%
""" Implement the training for the bigger model similar to the training of the small model before. """

N_train_samples_overfit = 30
N_epochs = 1000
batch_size = 30

sel_idx = np.arange(0, N_train_samples)
sel_idx = np.random.choice(sel_idx, N_train_samples_overfit)
x_train_overfit = x_train[sel_idx]
y_train_overfit = y_train[sel_idx]
print(type(x_train_overfit))

train_overfit_ds = tf.data.Dataset.from_tensor_slices((x_train_overfit, y_train_overfit)).shuffle(N_train_samples_overfit).batch(batch_size).repeat()

epoch = 0
train_iters = 0
train_loss = 0.0
for x_t, y_t in train_overfit_ds:
    # print(x_t.shape)
    train_loss += train_step(big_mdl,big_opt,x_t,y_t)# Perform a training step with the model "big_mdl" and the optimizer "big_opt" on the inputs "x_t" and the corresponding targets "y_t"
    train_iters += 1
    if batch_size * train_iters == N_train_samples:# An epoch is completed
        for x_v, y_v in validation_ds:
            y_pred = big_mdl(x_v)# Compute a prediction with "big_mdl" on the input "x_v"
            validation_loss = tf.reduce_sum(tf.pow(y_pred-y_v, 2)) / (2 * y_pred.shape[0])# Compute the Mean Squared Error (MSE) for the prediction "y_pred" and the targets "y_v"
        print("Epoch: {} Train loss: {:.5} Validation loss: {:.5}".format(epoch, train_loss/train_iters, validation_loss))
        train_iters = 0
        train_loss = 0.0
        epoch += 1
    if (epoch == N_epochs):
        break
# Out:
# <class 'numpy.ndarray'>
# Epoch: 0 Train loss: 0.0059147 Validation loss: 40.525
# Epoch: 1 Train loss: 0.0056356 Validation loss: 40.607
# Epoch: 2 Train loss: 0.0055655 Validation loss: 40.732
# Epoch: 3 Train loss: 0.0055224 Validation loss: 40.844
# Epoch: 4 Train loss: 0.0054916 Validation loss: 40.936
# Epoch: 5 Train loss: 0.0054678 Validation loss: 41.011
# Epoch: 6 Train loss: 0.0054486 Validation loss: 41.072
# Epoch: 7 Train loss: 0.0054323 Validation loss: 41.122
# Epoch: 8 Train loss: 0.0054178 Validation loss: 41.163
# Epoch: 9 Train loss: 0.0054047 Validation loss: 41.197
# Epoch: 10 Train loss: 0.0053926 Validation loss: 41.227
# Epoch: 11 Train loss: 0.0053811 Validation loss: 41.251
# Epoch: 12 Train loss: 0.0053701 Validation loss: 41.273
# Epoch: 13 Train loss: 0.0053595 Validation loss: 41.292
# Epoch: 14 Train loss: 0.0053493 Validation loss: 41.309
# Epoch: 15 Train loss: 0.0053394 Validation loss: 41.324
# Epoch: 16 Train loss: 0.0053298 Validation loss: 41.338
# Epoch: 17 Train loss: 0.0053203 Validation loss: 41.35
# Epoch: 18 Train loss: 0.0053111 Validation loss: 41.362
# Epoch: 19 Train loss: 0.0053021 Validation loss: 41.373
# Epoch: 20 Train loss: 0.0052933 Validation loss: 41.384
# Epoch: 21 Train loss: 0.0052846 Validation loss: 41.394
# Epoch: 22 Train loss: 0.0052761 Validation loss: 41.404
# Epoch: 23 Train loss: 0.0052677 Validation loss: 41.413
# Epoch: 24 Train loss: 0.0052595 Validation loss: 41.422
# Epoch: 25 Train loss: 0.0052514 Validation loss: 41.431
# Epoch: 26 Train loss: 0.0052434 Validation loss: 41.439
# Epoch: 27 Train loss: 0.0052356 Validation loss: 41.447
# Epoch: 28 Train loss: 0.0052278 Validation loss: 41.455
# Epoch: 29 Train loss: 0.0052202 Validation loss: 41.463
# Epoch: 30 Train loss: 0.0052127 Validation loss: 41.471
# Epoch: 31 Train loss: 0.0052052 Validation loss: 41.478
# Epoch: 32 Train loss: 0.0051979 Validation loss: 41.486
# Epoch: 33 Train loss: 0.0051907 Validation loss: 41.493
# Epoch: 34 Train loss: 0.0051836 Validation loss: 41.5
# Epoch: 35 Train loss: 0.0051766 Validation loss: 41.507
# Epoch: 36 Train loss: 0.0051697 Validation loss: 41.514
# Epoch: 37 Train loss: 0.0051628 Validation loss: 41.521
# Epoch: 38 Train loss: 0.0051561 Validation loss: 41.528
# Epoch: 39 Train loss: 0.0051494 Validation loss: 41.535
# Epoch: 40 Train loss: 0.0051428 Validation loss: 41.541
# Epoch: 41 Train loss: 0.0051363 Validation loss: 41.548
# Epoch: 42 Train loss: 0.0051298 Validation loss: 41.554
# Epoch: 43 Train loss: 0.0051234 Validation loss: 41.561
# Epoch: 44 Train loss: 0.0051171 Validation loss: 41.567
# Epoch: 45 Train loss: 0.0051109 Validation loss: 41.573
# Epoch: 46 Train loss: 0.0051047 Validation loss: 41.58
# Epoch: 47 Train loss: 0.0050986 Validation loss: 41.586
# Epoch: 48 Train loss: 0.0050926 Validation loss: 41.592
# Epoch: 49 Train loss: 0.0050866 Validation loss: 41.598
# Epoch: 50 Train loss: 0.0050807 Validation loss: 41.604
# Epoch: 51 Train loss: 0.0050749 Validation loss: 41.61
# Epoch: 52 Train loss: 0.0050691 Validation loss: 41.616
# Epoch: 53 Train loss: 0.0050633 Validation loss: 41.622
# Epoch: 54 Train loss: 0.0050577 Validation loss: 41.627
# Epoch: 55 Train loss: 0.005052 Validation loss: 41.633
# Epoch: 56 Train loss: 0.0050465 Validation loss: 41.639
# Epoch: 57 Train loss: 0.0050409 Validation loss: 41.645
# Epoch: 58 Train loss: 0.0050355 Validation loss: 41.65
# Epoch: 59 Train loss: 0.00503 Validation loss: 41.656
# Epoch: 60 Train loss: 0.0050247 Validation loss: 41.661
# Epoch: 61 Train loss: 0.0050194 Validation loss: 41.667
# Epoch: 62 Train loss: 0.0050141 Validation loss: 41.673
# Epoch: 63 Train loss: 0.0050088 Validation loss: 41.678
# Epoch: 64 Train loss: 0.0050037 Validation loss: 41.684
# Epoch: 65 Train loss: 0.0049985 Validation loss: 41.689
# Epoch: 66 Train loss: 0.0049934 Validation loss: 41.694
# Epoch: 67 Train loss: 0.0049884 Validation loss: 41.7
# Epoch: 68 Train loss: 0.0049834 Validation loss: 41.705
# Epoch: 69 Train loss: 0.0049784 Validation loss: 41.71
# Epoch: 70 Train loss: 0.0049735 Validation loss: 41.716
# Epoch: 71 Train loss: 0.0049686 Validation loss: 41.721
# Epoch: 72 Train loss: 0.0049637 Validation loss: 41.726
# Epoch: 73 Train loss: 0.0049589 Validation loss: 41.731
# Epoch: 74 Train loss: 0.0049541 Validation loss: 41.736
# Epoch: 75 Train loss: 0.0049494 Validation loss: 41.741
# Epoch: 76 Train loss: 0.0049447 Validation loss: 41.746
# Epoch: 77 Train loss: 0.00494 Validation loss: 41.751
# Epoch: 78 Train loss: 0.0049354 Validation loss: 41.756
# Epoch: 79 Train loss: 0.0049308 Validation loss: 41.761
# Epoch: 80 Train loss: 0.0049262 Validation loss: 41.765
# Epoch: 81 Train loss: 0.0049217 Validation loss: 41.77
# Epoch: 82 Train loss: 0.0049172 Validation loss: 41.775
# Epoch: 83 Train loss: 0.0049127 Validation loss: 41.78
# Epoch: 84 Train loss: 0.0049083 Validation loss: 41.785
# Epoch: 85 Train loss: 0.0049039 Validation loss: 41.79
# Epoch: 86 Train loss: 0.0048995 Validation loss: 41.794
# Epoch: 87 Train loss: 0.0048951 Validation loss: 41.799
# Epoch: 88 Train loss: 0.0048908 Validation loss: 41.804
# Epoch: 89 Train loss: 0.0048865 Validation loss: 41.808
# Epoch: 90 Train loss: 0.0048823 Validation loss: 41.813
# Epoch: 91 Train loss: 0.004878 Validation loss: 41.818
# Epoch: 92 Train loss: 0.0048738 Validation loss: 41.822
# Epoch: 93 Train loss: 0.0048696 Validation loss: 41.827
# Epoch: 94 Train loss: 0.0048654 Validation loss: 41.832
# Epoch: 95 Train loss: 0.0048613 Validation loss: 41.836
# Epoch: 96 Train loss: 0.0048572 Validation loss: 41.841
# Epoch: 97 Train loss: 0.0048531 Validation loss: 41.845
# Epoch: 98 Train loss: 0.004849 Validation loss: 41.85
# Epoch: 99 Train loss: 0.004845 Validation loss: 41.855
# Epoch: 100 Train loss: 0.0048409 Validation loss: 41.859
# Epoch: 101 Train loss: 0.004837 Validation loss: 41.864
# Epoch: 102 Train loss: 0.004833 Validation loss: 41.868
# Epoch: 103 Train loss: 0.004829 Validation loss: 41.873
# Epoch: 104 Train loss: 0.0048251 Validation loss: 41.877
# Epoch: 105 Train loss: 0.0048212 Validation loss: 41.882
# Epoch: 106 Train loss: 0.0048173 Validation loss: 41.886
# Epoch: 107 Train loss: 0.0048134 Validation loss: 41.891
# Epoch: 108 Train loss: 0.0048096 Validation loss: 41.895
# Epoch: 109 Train loss: 0.0048058 Validation loss: 41.9
# Epoch: 110 Train loss: 0.0048019 Validation loss: 41.904
# Epoch: 111 Train loss: 0.0047982 Validation loss: 41.909
# Epoch: 112 Train loss: 0.0047944 Validation loss: 41.913
# Epoch: 113 Train loss: 0.0047907 Validation loss: 41.918
# Epoch: 114 Train loss: 0.0047869 Validation loss: 41.922
# Epoch: 115 Train loss: 0.0047833 Validation loss: 41.926
# Epoch: 116 Train loss: 0.0047796 Validation loss: 41.931
# Epoch: 117 Train loss: 0.0047759 Validation loss: 41.935
# Epoch: 118 Train loss: 0.0047722 Validation loss: 41.94
# Epoch: 119 Train loss: 0.0047686 Validation loss: 41.944
# Epoch: 120 Train loss: 0.004765 Validation loss: 41.949
# Epoch: 121 Train loss: 0.0047614 Validation loss: 41.953
# Epoch: 122 Train loss: 0.0047578 Validation loss: 41.957
# Epoch: 123 Train loss: 0.0047542 Validation loss: 41.962
# Epoch: 124 Train loss: 0.0047506 Validation loss: 41.966
# Epoch: 125 Train loss: 0.0047471 Validation loss: 41.971
# Epoch: 126 Train loss: 0.0047436 Validation loss: 41.975
# Epoch: 127 Train loss: 0.0047401 Validation loss: 41.979
# Epoch: 128 Train loss: 0.0047365 Validation loss: 41.984
# Epoch: 129 Train loss: 0.0047331 Validation loss: 41.988
# Epoch: 130 Train loss: 0.0047296 Validation loss: 41.992
# Epoch: 131 Train loss: 0.0047261 Validation loss: 41.997
# Epoch: 132 Train loss: 0.0047227 Validation loss: 42.001
# Epoch: 133 Train loss: 0.0047193 Validation loss: 42.006
# Epoch: 134 Train loss: 0.0047159 Validation loss: 42.01
# Epoch: 135 Train loss: 0.0047125 Validation loss: 42.015
# Epoch: 136 Train loss: 0.0047091 Validation loss: 42.019
# Epoch: 137 Train loss: 0.0047057 Validation loss: 42.023
# Epoch: 138 Train loss: 0.0047023 Validation loss: 42.028
# Epoch: 139 Train loss: 0.004699 Validation loss: 42.032
# Epoch: 140 Train loss: 0.0046957 Validation loss: 42.037
# Epoch: 141 Train loss: 0.0046923 Validation loss: 42.041
# Epoch: 142 Train loss: 0.004689 Validation loss: 42.046
# Epoch: 143 Train loss: 0.0046857 Validation loss: 42.05
# Epoch: 144 Train loss: 0.0046824 Validation loss: 42.055
# Epoch: 145 Train loss: 0.0046791 Validation loss: 42.059
# Epoch: 146 Train loss: 0.0046759 Validation loss: 42.063
# Epoch: 147 Train loss: 0.0046726 Validation loss: 42.068
# Epoch: 148 Train loss: 0.0046693 Validation loss: 42.072
# Epoch: 149 Train loss: 0.0046661 Validation loss: 42.077
# Epoch: 150 Train loss: 0.0046629 Validation loss: 42.081
# Epoch: 151 Train loss: 0.0046597 Validation loss: 42.086
# Epoch: 152 Train loss: 0.0046565 Validation loss: 42.09
# Epoch: 153 Train loss: 0.0046533 Validation loss: 42.095
# Epoch: 154 Train loss: 0.0046501 Validation loss: 42.099
# Epoch: 155 Train loss: 0.0046469 Validation loss: 42.104
# Epoch: 156 Train loss: 0.0046438 Validation loss: 42.108
# Epoch: 157 Train loss: 0.0046406 Validation loss: 42.113
# Epoch: 158 Train loss: 0.0046375 Validation loss: 42.117
# Epoch: 159 Train loss: 0.0046343 Validation loss: 42.122
# Epoch: 160 Train loss: 0.0046312 Validation loss: 42.127
# Epoch: 161 Train loss: 0.0046281 Validation loss: 42.131
# Epoch: 162 Train loss: 0.0046249 Validation loss: 42.136
# Epoch: 163 Train loss: 0.0046218 Validation loss: 42.14
# Epoch: 164 Train loss: 0.0046187 Validation loss: 42.145
# Epoch: 165 Train loss: 0.0046156 Validation loss: 42.15
# Epoch: 166 Train loss: 0.0046125 Validation loss: 42.154
# Epoch: 167 Train loss: 0.0046095 Validation loss: 42.159
# Epoch: 168 Train loss: 0.0046064 Validation loss: 42.164
# Epoch: 169 Train loss: 0.0046033 Validation loss: 42.168
# Epoch: 170 Train loss: 0.0046003 Validation loss: 42.173
# Epoch: 171 Train loss: 0.0045972 Validation loss: 42.178
# Epoch: 172 Train loss: 0.0045942 Validation loss: 42.182
# Epoch: 173 Train loss: 0.0045912 Validation loss: 42.187
# Epoch: 174 Train loss: 0.0045882 Validation loss: 42.192
# Epoch: 175 Train loss: 0.0045851 Validation loss: 42.196
# Epoch: 176 Train loss: 0.0045821 Validation loss: 42.201
# Epoch: 177 Train loss: 0.0045791 Validation loss: 42.206
# Epoch: 178 Train loss: 0.0045761 Validation loss: 42.211
# Epoch: 179 Train loss: 0.0045731 Validation loss: 42.216
# Epoch: 180 Train loss: 0.0045701 Validation loss: 42.22
# Epoch: 181 Train loss: 0.0045671 Validation loss: 42.225
# Epoch: 182 Train loss: 0.0045641 Validation loss: 42.23
# Epoch: 183 Train loss: 0.0045612 Validation loss: 42.235
# Epoch: 184 Train loss: 0.0045582 Validation loss: 42.24
# Epoch: 185 Train loss: 0.0045552 Validation loss: 42.244
# Epoch: 186 Train loss: 0.0045523 Validation loss: 42.249
# Epoch: 187 Train loss: 0.0045493 Validation loss: 42.254
# Epoch: 188 Train loss: 0.0045464 Validation loss: 42.259
# Epoch: 189 Train loss: 0.0045434 Validation loss: 42.264
# Epoch: 190 Train loss: 0.0045405 Validation loss: 42.269
# Epoch: 191 Train loss: 0.0045376 Validation loss: 42.274
# Epoch: 192 Train loss: 0.0045346 Validation loss: 42.279
# Epoch: 193 Train loss: 0.0045317 Validation loss: 42.284
# Epoch: 194 Train loss: 0.0045288 Validation loss: 42.288
# Epoch: 195 Train loss: 0.0045259 Validation loss: 42.293
# Epoch: 196 Train loss: 0.004523 Validation loss: 42.298
# Epoch: 197 Train loss: 0.0045201 Validation loss: 42.303
# Epoch: 198 Train loss: 0.0045172 Validation loss: 42.308
# Epoch: 199 Train loss: 0.0045143 Validation loss: 42.313
# Epoch: 200 Train loss: 0.0045114 Validation loss: 42.318
# Epoch: 201 Train loss: 0.0045085 Validation loss: 42.323
# Epoch: 202 Train loss: 0.0045057 Validation loss: 42.329
# Epoch: 203 Train loss: 0.0045028 Validation loss: 42.334
# Epoch: 204 Train loss: 0.0044999 Validation loss: 42.339
# Epoch: 205 Train loss: 0.004497 Validation loss: 42.344
# Epoch: 206 Train loss: 0.0044942 Validation loss: 42.349
# Epoch: 207 Train loss: 0.0044913 Validation loss: 42.354
# Epoch: 208 Train loss: 0.0044884 Validation loss: 42.36
# Epoch: 209 Train loss: 0.0044856 Validation loss: 42.365
# Epoch: 210 Train loss: 0.0044827 Validation loss: 42.37
# Epoch: 211 Train loss: 0.0044799 Validation loss: 42.375
# Epoch: 212 Train loss: 0.004477 Validation loss: 42.38
# Epoch: 213 Train loss: 0.0044742 Validation loss: 42.386
# Epoch: 214 Train loss: 0.0044714 Validation loss: 42.391
# Epoch: 215 Train loss: 0.0044685 Validation loss: 42.397
# Epoch: 216 Train loss: 0.0044657 Validation loss: 42.402
# Epoch: 217 Train loss: 0.0044629 Validation loss: 42.407
# Epoch: 218 Train loss: 0.00446 Validation loss: 42.413
# Epoch: 219 Train loss: 0.0044572 Validation loss: 42.418
# Epoch: 220 Train loss: 0.0044544 Validation loss: 42.424
# Epoch: 221 Train loss: 0.0044515 Validation loss: 42.429
# Epoch: 222 Train loss: 0.0044487 Validation loss: 42.435
# Epoch: 223 Train loss: 0.0044459 Validation loss: 42.44
# Epoch: 224 Train loss: 0.0044431 Validation loss: 42.446
# Epoch: 225 Train loss: 0.0044403 Validation loss: 42.452
# Epoch: 226 Train loss: 0.0044374 Validation loss: 42.457
# Epoch: 227 Train loss: 0.0044346 Validation loss: 42.463
# Epoch: 228 Train loss: 0.0044318 Validation loss: 42.469
# Epoch: 229 Train loss: 0.004429 Validation loss: 42.475
# Epoch: 230 Train loss: 0.0044262 Validation loss: 42.48
# Epoch: 231 Train loss: 0.0044234 Validation loss: 42.486
# Epoch: 232 Train loss: 0.0044206 Validation loss: 42.492
# Epoch: 233 Train loss: 0.0044177 Validation loss: 42.498
# Epoch: 234 Train loss: 0.0044149 Validation loss: 42.504
# Epoch: 235 Train loss: 0.0044121 Validation loss: 42.51
# Epoch: 236 Train loss: 0.0044093 Validation loss: 42.516
# Epoch: 237 Train loss: 0.0044065 Validation loss: 42.522
# Epoch: 238 Train loss: 0.0044037 Validation loss: 42.528
# Epoch: 239 Train loss: 0.0044008 Validation loss: 42.534
# Epoch: 240 Train loss: 0.004398 Validation loss: 42.54
# Epoch: 241 Train loss: 0.0043952 Validation loss: 42.546
# Epoch: 242 Train loss: 0.0043924 Validation loss: 42.552
# Epoch: 243 Train loss: 0.0043895 Validation loss: 42.558
# Epoch: 244 Train loss: 0.0043867 Validation loss: 42.565
# Epoch: 245 Train loss: 0.0043839 Validation loss: 42.571
# Epoch: 246 Train loss: 0.0043811 Validation loss: 42.577
# Epoch: 247 Train loss: 0.0043783 Validation loss: 42.583
# Epoch: 248 Train loss: 0.0043755 Validation loss: 42.589
# Epoch: 249 Train loss: 0.0043726 Validation loss: 42.596
# Epoch: 250 Train loss: 0.0043698 Validation loss: 42.602
# Epoch: 251 Train loss: 0.004367 Validation loss: 42.608
# Epoch: 252 Train loss: 0.0043642 Validation loss: 42.615
# Epoch: 253 Train loss: 0.0043613 Validation loss: 42.621
# Epoch: 254 Train loss: 0.0043585 Validation loss: 42.628
# Epoch: 255 Train loss: 0.0043557 Validation loss: 42.634
# Epoch: 256 Train loss: 0.0043529 Validation loss: 42.641
# Epoch: 257 Train loss: 0.00435 Validation loss: 42.647
# Epoch: 258 Train loss: 0.0043472 Validation loss: 42.654
# Epoch: 259 Train loss: 0.0043443 Validation loss: 42.661
# Epoch: 260 Train loss: 0.0043415 Validation loss: 42.668
# Epoch: 261 Train loss: 0.0043387 Validation loss: 42.674
# Epoch: 262 Train loss: 0.0043358 Validation loss: 42.681
# Epoch: 263 Train loss: 0.0043329 Validation loss: 42.688
# Epoch: 264 Train loss: 0.0043301 Validation loss: 42.695
# Epoch: 265 Train loss: 0.0043272 Validation loss: 42.702
# Epoch: 266 Train loss: 0.0043244 Validation loss: 42.709
# Epoch: 267 Train loss: 0.0043215 Validation loss: 42.716
# Epoch: 268 Train loss: 0.0043186 Validation loss: 42.723
# Epoch: 269 Train loss: 0.0043158 Validation loss: 42.73
# Epoch: 270 Train loss: 0.0043129 Validation loss: 42.737
# Epoch: 271 Train loss: 0.00431 Validation loss: 42.744
# Epoch: 272 Train loss: 0.0043071 Validation loss: 42.751
# Epoch: 273 Train loss: 0.0043042 Validation loss: 42.759
# Epoch: 274 Train loss: 0.0043014 Validation loss: 42.766
# Epoch: 275 Train loss: 0.0042985 Validation loss: 42.773
# Epoch: 276 Train loss: 0.0042956 Validation loss: 42.781
# Epoch: 277 Train loss: 0.0042927 Validation loss: 42.788
# Epoch: 278 Train loss: 0.0042898 Validation loss: 42.796
# Epoch: 279 Train loss: 0.0042869 Validation loss: 42.803
# Epoch: 280 Train loss: 0.004284 Validation loss: 42.811
# Epoch: 281 Train loss: 0.0042811 Validation loss: 42.818
# Epoch: 282 Train loss: 0.0042781 Validation loss: 42.826
# Epoch: 283 Train loss: 0.0042752 Validation loss: 42.834
# Epoch: 284 Train loss: 0.0042723 Validation loss: 42.841
# Epoch: 285 Train loss: 0.0042693 Validation loss: 42.849
# Epoch: 286 Train loss: 0.0042664 Validation loss: 42.857
# Epoch: 287 Train loss: 0.0042635 Validation loss: 42.865
# Epoch: 288 Train loss: 0.0042605 Validation loss: 42.873
# Epoch: 289 Train loss: 0.0042576 Validation loss: 42.881
# Epoch: 290 Train loss: 0.0042546 Validation loss: 42.889
# Epoch: 291 Train loss: 0.0042517 Validation loss: 42.897
# Epoch: 292 Train loss: 0.0042487 Validation loss: 42.905
# Epoch: 293 Train loss: 0.0042457 Validation loss: 42.913
# Epoch: 294 Train loss: 0.0042428 Validation loss: 42.921
# Epoch: 295 Train loss: 0.0042398 Validation loss: 42.93
# Epoch: 296 Train loss: 0.0042368 Validation loss: 42.938
# Epoch: 297 Train loss: 0.0042338 Validation loss: 42.946
# Epoch: 298 Train loss: 0.0042308 Validation loss: 42.955
# Epoch: 299 Train loss: 0.0042278 Validation loss: 42.963
# Epoch: 300 Train loss: 0.0042248 Validation loss: 42.972
# Epoch: 301 Train loss: 0.0042218 Validation loss: 42.981
# Epoch: 302 Train loss: 0.0042188 Validation loss: 42.989
# Epoch: 303 Train loss: 0.0042157 Validation loss: 42.998
# Epoch: 304 Train loss: 0.0042127 Validation loss: 43.007
# Epoch: 305 Train loss: 0.0042097 Validation loss: 43.016
# Epoch: 306 Train loss: 0.0042066 Validation loss: 43.025
# Epoch: 307 Train loss: 0.0042035 Validation loss: 43.034
# Epoch: 308 Train loss: 0.0042005 Validation loss: 43.043
# Epoch: 309 Train loss: 0.0041974 Validation loss: 43.052
# Epoch: 310 Train loss: 0.0041943 Validation loss: 43.061
# Epoch: 311 Train loss: 0.0041912 Validation loss: 43.071
# Epoch: 312 Train loss: 0.0041882 Validation loss: 43.08
# Epoch: 313 Train loss: 0.004185 Validation loss: 43.09
# Epoch: 314 Train loss: 0.0041819 Validation loss: 43.099
# Epoch: 315 Train loss: 0.0041788 Validation loss: 43.109
# Epoch: 316 Train loss: 0.0041757 Validation loss: 43.118
# Epoch: 317 Train loss: 0.0041725 Validation loss: 43.128
# Epoch: 318 Train loss: 0.0041694 Validation loss: 43.138
# Epoch: 319 Train loss: 0.0041662 Validation loss: 43.148
# Epoch: 320 Train loss: 0.0041631 Validation loss: 43.158
# Epoch: 321 Train loss: 0.0041599 Validation loss: 43.168
# Epoch: 322 Train loss: 0.0041568 Validation loss: 43.178
# Epoch: 323 Train loss: 0.0041536 Validation loss: 43.188
# Epoch: 324 Train loss: 0.0041504 Validation loss: 43.198
# Epoch: 325 Train loss: 0.0041472 Validation loss: 43.208
# Epoch: 326 Train loss: 0.004144 Validation loss: 43.219
# Epoch: 327 Train loss: 0.0041408 Validation loss: 43.229
# Epoch: 328 Train loss: 0.0041375 Validation loss: 43.239
# Epoch: 329 Train loss: 0.0041343 Validation loss: 43.25
# Epoch: 330 Train loss: 0.0041311 Validation loss: 43.261
# Epoch: 331 Train loss: 0.0041278 Validation loss: 43.271
# Epoch: 332 Train loss: 0.0041246 Validation loss: 43.282
# Epoch: 333 Train loss: 0.0041213 Validation loss: 43.293
# Epoch: 334 Train loss: 0.004118 Validation loss: 43.304
# Epoch: 335 Train loss: 0.0041148 Validation loss: 43.315
# Epoch: 336 Train loss: 0.0041115 Validation loss: 43.326
# Epoch: 337 Train loss: 0.0041082 Validation loss: 43.337
# Epoch: 338 Train loss: 0.0041049 Validation loss: 43.348
# Epoch: 339 Train loss: 0.0041016 Validation loss: 43.36
# Epoch: 340 Train loss: 0.0040983 Validation loss: 43.371
# Epoch: 341 Train loss: 0.0040949 Validation loss: 43.383
# Epoch: 342 Train loss: 0.0040916 Validation loss: 43.394
# Epoch: 343 Train loss: 0.0040883 Validation loss: 43.406
# Epoch: 344 Train loss: 0.0040849 Validation loss: 43.418
# Epoch: 345 Train loss: 0.0040816 Validation loss: 43.429
# Epoch: 346 Train loss: 0.0040782 Validation loss: 43.441
# Epoch: 347 Train loss: 0.0040748 Validation loss: 43.453
# Epoch: 348 Train loss: 0.0040714 Validation loss: 43.465
# Epoch: 349 Train loss: 0.0040681 Validation loss: 43.477
# Epoch: 350 Train loss: 0.0040647 Validation loss: 43.49
# Epoch: 351 Train loss: 0.0040613 Validation loss: 43.502
# Epoch: 352 Train loss: 0.0040579 Validation loss: 43.514
# Epoch: 353 Train loss: 0.0040544 Validation loss: 43.527
# Epoch: 354 Train loss: 0.004051 Validation loss: 43.539
# Epoch: 355 Train loss: 0.0040476 Validation loss: 43.552
# Epoch: 356 Train loss: 0.0040441 Validation loss: 43.564
# Epoch: 357 Train loss: 0.0040407 Validation loss: 43.577
# Epoch: 358 Train loss: 0.0040372 Validation loss: 43.59
# Epoch: 359 Train loss: 0.0040338 Validation loss: 43.603
# Epoch: 360 Train loss: 0.0040303 Validation loss: 43.616
# Epoch: 361 Train loss: 0.0040268 Validation loss: 43.629
# Epoch: 362 Train loss: 0.0040233 Validation loss: 43.642
# Epoch: 363 Train loss: 0.0040198 Validation loss: 43.656
# Epoch: 364 Train loss: 0.0040164 Validation loss: 43.669
# Epoch: 365 Train loss: 0.0040128 Validation loss: 43.682
# Epoch: 366 Train loss: 0.0040093 Validation loss: 43.696
# Epoch: 367 Train loss: 0.0040058 Validation loss: 43.71
# Epoch: 368 Train loss: 0.0040023 Validation loss: 43.723
# Epoch: 369 Train loss: 0.0039988 Validation loss: 43.737
# Epoch: 370 Train loss: 0.0039953 Validation loss: 43.751
# Epoch: 371 Train loss: 0.0039917 Validation loss: 43.765
# Epoch: 372 Train loss: 0.0039882 Validation loss: 43.779
# Epoch: 373 Train loss: 0.0039847 Validation loss: 43.793
# Epoch: 374 Train loss: 0.0039811 Validation loss: 43.807
# Epoch: 375 Train loss: 0.0039776 Validation loss: 43.821
# Epoch: 376 Train loss: 0.003974 Validation loss: 43.836
# Epoch: 377 Train loss: 0.0039705 Validation loss: 43.85
# Epoch: 378 Train loss: 0.0039669 Validation loss: 43.865
# Epoch: 379 Train loss: 0.0039634 Validation loss: 43.879
# Epoch: 380 Train loss: 0.0039598 Validation loss: 43.894
# Epoch: 381 Train loss: 0.0039563 Validation loss: 43.909
# Epoch: 382 Train loss: 0.0039527 Validation loss: 43.923
# Epoch: 383 Train loss: 0.0039491 Validation loss: 43.938
# Epoch: 384 Train loss: 0.0039456 Validation loss: 43.953
# Epoch: 385 Train loss: 0.003942 Validation loss: 43.968
# Epoch: 386 Train loss: 0.0039385 Validation loss: 43.984
# Epoch: 387 Train loss: 0.0039349 Validation loss: 43.999
# Epoch: 388 Train loss: 0.0039313 Validation loss: 44.014
# Epoch: 389 Train loss: 0.0039278 Validation loss: 44.029
# Epoch: 390 Train loss: 0.0039242 Validation loss: 44.045
# Epoch: 391 Train loss: 0.0039206 Validation loss: 44.06
# Epoch: 392 Train loss: 0.0039171 Validation loss: 44.075
# Epoch: 393 Train loss: 0.0039135 Validation loss: 44.091
# Epoch: 394 Train loss: 0.00391 Validation loss: 44.106
# Epoch: 395 Train loss: 0.0039064 Validation loss: 44.122
# Epoch: 396 Train loss: 0.0039029 Validation loss: 44.138
# Epoch: 397 Train loss: 0.0038993 Validation loss: 44.153
# Epoch: 398 Train loss: 0.0038958 Validation loss: 44.169
# Epoch: 399 Train loss: 0.0038922 Validation loss: 44.185
# Epoch: 400 Train loss: 0.0038887 Validation loss: 44.201
# Epoch: 401 Train loss: 0.0038852 Validation loss: 44.217
# Epoch: 402 Train loss: 0.0038816 Validation loss: 44.233
# Epoch: 403 Train loss: 0.0038781 Validation loss: 44.249
# Epoch: 404 Train loss: 0.0038746 Validation loss: 44.265
# Epoch: 405 Train loss: 0.0038711 Validation loss: 44.281
# Epoch: 406 Train loss: 0.0038676 Validation loss: 44.297
# Epoch: 407 Train loss: 0.0038641 Validation loss: 44.314
# Epoch: 408 Train loss: 0.0038606 Validation loss: 44.33
# Epoch: 409 Train loss: 0.0038571 Validation loss: 44.346
# Epoch: 410 Train loss: 0.0038536 Validation loss: 44.363
# Epoch: 411 Train loss: 0.0038501 Validation loss: 44.379
# Epoch: 412 Train loss: 0.0038467 Validation loss: 44.395
# Epoch: 413 Train loss: 0.0038432 Validation loss: 44.412
# Epoch: 414 Train loss: 0.0038398 Validation loss: 44.428
# Epoch: 415 Train loss: 0.0038364 Validation loss: 44.445
# Epoch: 416 Train loss: 0.0038329 Validation loss: 44.461
# Epoch: 417 Train loss: 0.0038295 Validation loss: 44.478
# Epoch: 418 Train loss: 0.0038262 Validation loss: 44.494
# Epoch: 419 Train loss: 0.0038228 Validation loss: 44.511
# Epoch: 420 Train loss: 0.0038194 Validation loss: 44.527
# Epoch: 421 Train loss: 0.003816 Validation loss: 44.544
# Epoch: 422 Train loss: 0.0038127 Validation loss: 44.56
# Epoch: 423 Train loss: 0.0038094 Validation loss: 44.577
# Epoch: 424 Train loss: 0.0038061 Validation loss: 44.593
# Epoch: 425 Train loss: 0.0038027 Validation loss: 44.61
# Epoch: 426 Train loss: 0.0037995 Validation loss: 44.626
# Epoch: 427 Train loss: 0.0037962 Validation loss: 44.643
# Epoch: 428 Train loss: 0.003793 Validation loss: 44.659
# Epoch: 429 Train loss: 0.0037897 Validation loss: 44.676
# Epoch: 430 Train loss: 0.0037865 Validation loss: 44.692
# Epoch: 431 Train loss: 0.0037833 Validation loss: 44.708
# Epoch: 432 Train loss: 0.0037801 Validation loss: 44.725
# Epoch: 433 Train loss: 0.0037769 Validation loss: 44.741
# Epoch: 434 Train loss: 0.0037738 Validation loss: 44.757
# Epoch: 435 Train loss: 0.0037706 Validation loss: 44.774
# Epoch: 436 Train loss: 0.0037675 Validation loss: 44.79
# Epoch: 437 Train loss: 0.0037644 Validation loss: 44.806
# Epoch: 438 Train loss: 0.0037614 Validation loss: 44.822
# Epoch: 439 Train loss: 0.0037583 Validation loss: 44.838
# Epoch: 440 Train loss: 0.0037552 Validation loss: 44.854
# Epoch: 441 Train loss: 0.0037522 Validation loss: 44.87
# Epoch: 442 Train loss: 0.0037492 Validation loss: 44.887
# Epoch: 443 Train loss: 0.0037462 Validation loss: 44.902
# Epoch: 444 Train loss: 0.0037433 Validation loss: 44.918
# Epoch: 445 Train loss: 0.0037403 Validation loss: 44.934
# Epoch: 446 Train loss: 0.0037374 Validation loss: 44.95
# Epoch: 447 Train loss: 0.0037345 Validation loss: 44.966
# Epoch: 448 Train loss: 0.0037316 Validation loss: 44.981
# Epoch: 449 Train loss: 0.0037287 Validation loss: 44.997
# Epoch: 450 Train loss: 0.0037259 Validation loss: 45.012
# Epoch: 451 Train loss: 0.0037231 Validation loss: 45.028
# Epoch: 452 Train loss: 0.0037203 Validation loss: 45.043
# Epoch: 453 Train loss: 0.0037175 Validation loss: 45.058
# Epoch: 454 Train loss: 0.0037148 Validation loss: 45.074
# Epoch: 455 Train loss: 0.003712 Validation loss: 45.089
# Epoch: 456 Train loss: 0.0037093 Validation loss: 45.104
# Epoch: 457 Train loss: 0.0037066 Validation loss: 45.119
# Epoch: 458 Train loss: 0.003704 Validation loss: 45.134
# Epoch: 459 Train loss: 0.0037013 Validation loss: 45.148
# Epoch: 460 Train loss: 0.0036987 Validation loss: 45.163
# Epoch: 461 Train loss: 0.0036961 Validation loss: 45.178
# Epoch: 462 Train loss: 0.0036935 Validation loss: 45.193
# Epoch: 463 Train loss: 0.0036909 Validation loss: 45.207
# Epoch: 464 Train loss: 0.0036884 Validation loss: 45.222
# Epoch: 465 Train loss: 0.0036859 Validation loss: 45.236
# Epoch: 466 Train loss: 0.0036834 Validation loss: 45.25
# Epoch: 467 Train loss: 0.0036809 Validation loss: 45.264
# Epoch: 468 Train loss: 0.0036784 Validation loss: 45.279
# Epoch: 469 Train loss: 0.003676 Validation loss: 45.293
# Epoch: 470 Train loss: 0.0036736 Validation loss: 45.307
# Epoch: 471 Train loss: 0.0036712 Validation loss: 45.321
# Epoch: 472 Train loss: 0.0036688 Validation loss: 45.334
# Epoch: 473 Train loss: 0.0036664 Validation loss: 45.348
# Epoch: 474 Train loss: 0.0036641 Validation loss: 45.362
# Epoch: 475 Train loss: 0.0036618 Validation loss: 45.375
# Epoch: 476 Train loss: 0.0036595 Validation loss: 45.388
# Epoch: 477 Train loss: 0.0036572 Validation loss: 45.402
# Epoch: 478 Train loss: 0.003655 Validation loss: 45.415
# Epoch: 479 Train loss: 0.0036528 Validation loss: 45.428
# Epoch: 480 Train loss: 0.0036506 Validation loss: 45.441
# Epoch: 481 Train loss: 0.0036484 Validation loss: 45.454
# Epoch: 482 Train loss: 0.0036462 Validation loss: 45.467
# Epoch: 483 Train loss: 0.0036441 Validation loss: 45.479
# Epoch: 484 Train loss: 0.0036419 Validation loss: 45.492
# Epoch: 485 Train loss: 0.0036398 Validation loss: 45.504
# Epoch: 486 Train loss: 0.0036378 Validation loss: 45.517
# Epoch: 487 Train loss: 0.0036357 Validation loss: 45.529
# Epoch: 488 Train loss: 0.0036336 Validation loss: 45.541
# Epoch: 489 Train loss: 0.0036316 Validation loss: 45.553
# Epoch: 490 Train loss: 0.0036296 Validation loss: 45.565
# Epoch: 491 Train loss: 0.0036276 Validation loss: 45.577
# Epoch: 492 Train loss: 0.0036257 Validation loss: 45.589
# Epoch: 493 Train loss: 0.0036237 Validation loss: 45.601
# Epoch: 494 Train loss: 0.0036218 Validation loss: 45.612
# Epoch: 495 Train loss: 0.0036199 Validation loss: 45.624
# Epoch: 496 Train loss: 0.003618 Validation loss: 45.635
# Epoch: 497 Train loss: 0.0036161 Validation loss: 45.647
# Epoch: 498 Train loss: 0.0036143 Validation loss: 45.658
# Epoch: 499 Train loss: 0.0036124 Validation loss: 45.669
# Epoch: 500 Train loss: 0.0036106 Validation loss: 45.68
# Epoch: 501 Train loss: 0.0036088 Validation loss: 45.691
# Epoch: 502 Train loss: 0.003607 Validation loss: 45.702
# Epoch: 503 Train loss: 0.0036053 Validation loss: 45.712
# Epoch: 504 Train loss: 0.0036035 Validation loss: 45.723
# Epoch: 505 Train loss: 0.0036018 Validation loss: 45.734
# Epoch: 506 Train loss: 0.0036001 Validation loss: 45.744
# Epoch: 507 Train loss: 0.0035984 Validation loss: 45.755
# Epoch: 508 Train loss: 0.0035967 Validation loss: 45.765
# Epoch: 509 Train loss: 0.0035951 Validation loss: 45.775
# Epoch: 510 Train loss: 0.0035934 Validation loss: 45.785
# Epoch: 511 Train loss: 0.0035918 Validation loss: 45.795
# Epoch: 512 Train loss: 0.0035902 Validation loss: 45.805
# Epoch: 513 Train loss: 0.0035886 Validation loss: 45.815
# Epoch: 514 Train loss: 0.003587 Validation loss: 45.824
# Epoch: 515 Train loss: 0.0035854 Validation loss: 45.834
# Epoch: 516 Train loss: 0.0035838 Validation loss: 45.844
# Epoch: 517 Train loss: 0.0035823 Validation loss: 45.853
# Epoch: 518 Train loss: 0.0035808 Validation loss: 45.862
# Epoch: 519 Train loss: 0.0035793 Validation loss: 45.872
# Epoch: 520 Train loss: 0.0035778 Validation loss: 45.881
# Epoch: 521 Train loss: 0.0035763 Validation loss: 45.89
# Epoch: 522 Train loss: 0.0035748 Validation loss: 45.899
# Epoch: 523 Train loss: 0.0035734 Validation loss: 45.908
# Epoch: 524 Train loss: 0.0035719 Validation loss: 45.917
# Epoch: 525 Train loss: 0.0035705 Validation loss: 45.926
# Epoch: 526 Train loss: 0.0035691 Validation loss: 45.934
# Epoch: 527 Train loss: 0.0035677 Validation loss: 45.943
# Epoch: 528 Train loss: 0.0035663 Validation loss: 45.951
# Epoch: 529 Train loss: 0.003565 Validation loss: 45.96
# Epoch: 530 Train loss: 0.0035636 Validation loss: 45.968
# Epoch: 531 Train loss: 0.0035623 Validation loss: 45.977
# Epoch: 532 Train loss: 0.0035609 Validation loss: 45.985
# Epoch: 533 Train loss: 0.0035596 Validation loss: 45.993
# Epoch: 534 Train loss: 0.0035583 Validation loss: 46.001
# Epoch: 535 Train loss: 0.003557 Validation loss: 46.009
# Epoch: 536 Train loss: 0.0035557 Validation loss: 46.017
# Epoch: 537 Train loss: 0.0035545 Validation loss: 46.025
# Epoch: 538 Train loss: 0.0035532 Validation loss: 46.033
# Epoch: 539 Train loss: 0.003552 Validation loss: 46.04
# Epoch: 540 Train loss: 0.0035507 Validation loss: 46.048
# Epoch: 541 Train loss: 0.0035495 Validation loss: 46.056
# Epoch: 542 Train loss: 0.0035483 Validation loss: 46.063
# Epoch: 543 Train loss: 0.0035471 Validation loss: 46.071
# Epoch: 544 Train loss: 0.0035459 Validation loss: 46.078
# Epoch: 545 Train loss: 0.0035447 Validation loss: 46.086
# Epoch: 546 Train loss: 0.0035435 Validation loss: 46.093
# Epoch: 547 Train loss: 0.0035424 Validation loss: 46.1
# Epoch: 548 Train loss: 0.0035412 Validation loss: 46.107
# Epoch: 549 Train loss: 0.0035401 Validation loss: 46.114
# Epoch: 550 Train loss: 0.003539 Validation loss: 46.121
# Epoch: 551 Train loss: 0.0035378 Validation loss: 46.129
# Epoch: 552 Train loss: 0.0035367 Validation loss: 46.136
# Epoch: 553 Train loss: 0.0035356 Validation loss: 46.142
# Epoch: 554 Train loss: 0.0035345 Validation loss: 46.149
# Epoch: 555 Train loss: 0.0035334 Validation loss: 46.156
# Epoch: 556 Train loss: 0.0035323 Validation loss: 46.163
# Epoch: 557 Train loss: 0.0035313 Validation loss: 46.17
# Epoch: 558 Train loss: 0.0035302 Validation loss: 46.176
# Epoch: 559 Train loss: 0.0035292 Validation loss: 46.183
# Epoch: 560 Train loss: 0.0035282 Validation loss: 46.189
# Epoch: 561 Train loss: 0.0035271 Validation loss: 46.196
# Epoch: 562 Train loss: 0.0035261 Validation loss: 46.202
# Epoch: 563 Train loss: 0.0035251 Validation loss: 46.209
# Epoch: 564 Train loss: 0.0035241 Validation loss: 46.215
# Epoch: 565 Train loss: 0.0035231 Validation loss: 46.221
# Epoch: 566 Train loss: 0.0035221 Validation loss: 46.227
# Epoch: 567 Train loss: 0.0035211 Validation loss: 46.233
# Epoch: 568 Train loss: 0.0035202 Validation loss: 46.239
# Epoch: 569 Train loss: 0.0035192 Validation loss: 46.246
# Epoch: 570 Train loss: 0.0035183 Validation loss: 46.251
# Epoch: 571 Train loss: 0.0035173 Validation loss: 46.257
# Epoch: 572 Train loss: 0.0035164 Validation loss: 46.263
# Epoch: 573 Train loss: 0.0035154 Validation loss: 46.269
# Epoch: 574 Train loss: 0.0035145 Validation loss: 46.275
# Epoch: 575 Train loss: 0.0035136 Validation loss: 46.281
# Epoch: 576 Train loss: 0.0035127 Validation loss: 46.286
# Epoch: 577 Train loss: 0.0035118 Validation loss: 46.292
# Epoch: 578 Train loss: 0.0035109 Validation loss: 46.297
# Epoch: 579 Train loss: 0.00351 Validation loss: 46.303
# Epoch: 580 Train loss: 0.0035091 Validation loss: 46.308
# Epoch: 581 Train loss: 0.0035083 Validation loss: 46.314
# Epoch: 582 Train loss: 0.0035074 Validation loss: 46.319
# Epoch: 583 Train loss: 0.0035065 Validation loss: 46.324
# Epoch: 584 Train loss: 0.0035057 Validation loss: 46.33
# Epoch: 585 Train loss: 0.0035049 Validation loss: 46.335
# Epoch: 586 Train loss: 0.003504 Validation loss: 46.34
# Epoch: 587 Train loss: 0.0035032 Validation loss: 46.345
# Epoch: 588 Train loss: 0.0035024 Validation loss: 46.351
# Epoch: 589 Train loss: 0.0035015 Validation loss: 46.356
# Epoch: 590 Train loss: 0.0035007 Validation loss: 46.361
# Epoch: 591 Train loss: 0.0034999 Validation loss: 46.366
# Epoch: 592 Train loss: 0.0034991 Validation loss: 46.371
# Epoch: 593 Train loss: 0.0034983 Validation loss: 46.376
# Epoch: 594 Train loss: 0.0034975 Validation loss: 46.381
# Epoch: 595 Train loss: 0.0034968 Validation loss: 46.386
# Epoch: 596 Train loss: 0.003496 Validation loss: 46.39
# Epoch: 597 Train loss: 0.0034952 Validation loss: 46.395
# Epoch: 598 Train loss: 0.0034944 Validation loss: 46.4
# Epoch: 599 Train loss: 0.0034937 Validation loss: 46.405
# Epoch: 600 Train loss: 0.0034929 Validation loss: 46.409
# Epoch: 601 Train loss: 0.0034922 Validation loss: 46.414
# Epoch: 602 Train loss: 0.0034915 Validation loss: 46.419
# Epoch: 603 Train loss: 0.0034907 Validation loss: 46.423
# Epoch: 604 Train loss: 0.00349 Validation loss: 46.428
# Epoch: 605 Train loss: 0.0034892 Validation loss: 46.432
# Epoch: 606 Train loss: 0.0034885 Validation loss: 46.437
# Epoch: 607 Train loss: 0.0034878 Validation loss: 46.441
# Epoch: 608 Train loss: 0.0034871 Validation loss: 46.446
# Epoch: 609 Train loss: 0.0034864 Validation loss: 46.45
# Epoch: 610 Train loss: 0.0034857 Validation loss: 46.454
# Epoch: 611 Train loss: 0.003485 Validation loss: 46.459
# Epoch: 612 Train loss: 0.0034843 Validation loss: 46.463
# Epoch: 613 Train loss: 0.0034836 Validation loss: 46.467
# Epoch: 614 Train loss: 0.003483 Validation loss: 46.472
# Epoch: 615 Train loss: 0.0034823 Validation loss: 46.476
# Epoch: 616 Train loss: 0.0034816 Validation loss: 46.48
# Epoch: 617 Train loss: 0.003481 Validation loss: 46.484
# Epoch: 618 Train loss: 0.0034803 Validation loss: 46.488
# Epoch: 619 Train loss: 0.0034796 Validation loss: 46.492
# Epoch: 620 Train loss: 0.003479 Validation loss: 46.497
# Epoch: 621 Train loss: 0.0034783 Validation loss: 46.501
# Epoch: 622 Train loss: 0.0034777 Validation loss: 46.505
# Epoch: 623 Train loss: 0.003477 Validation loss: 46.509
# Epoch: 624 Train loss: 0.0034764 Validation loss: 46.513
# Epoch: 625 Train loss: 0.0034758 Validation loss: 46.517
# Epoch: 626 Train loss: 0.0034752 Validation loss: 46.521
# Epoch: 627 Train loss: 0.0034745 Validation loss: 46.524
# Epoch: 628 Train loss: 0.0034739 Validation loss: 46.528
# Epoch: 629 Train loss: 0.0034733 Validation loss: 46.532
# Epoch: 630 Train loss: 0.0034727 Validation loss: 46.536
# Epoch: 631 Train loss: 0.0034721 Validation loss: 46.54
# Epoch: 632 Train loss: 0.0034715 Validation loss: 46.544
# Epoch: 633 Train loss: 0.0034709 Validation loss: 46.548
# Epoch: 634 Train loss: 0.0034703 Validation loss: 46.552
# Epoch: 635 Train loss: 0.0034697 Validation loss: 46.555
# Epoch: 636 Train loss: 0.0034691 Validation loss: 46.559
# Epoch: 637 Train loss: 0.0034685 Validation loss: 46.563
# Epoch: 638 Train loss: 0.0034679 Validation loss: 46.567
# Epoch: 639 Train loss: 0.0034673 Validation loss: 46.57
# Epoch: 640 Train loss: 0.0034668 Validation loss: 46.574
# Epoch: 641 Train loss: 0.0034662 Validation loss: 46.578
# Epoch: 642 Train loss: 0.0034656 Validation loss: 46.581
# Epoch: 643 Train loss: 0.0034651 Validation loss: 46.585
# Epoch: 644 Train loss: 0.0034645 Validation loss: 46.588
# Epoch: 645 Train loss: 0.003464 Validation loss: 46.592
# Epoch: 646 Train loss: 0.0034634 Validation loss: 46.595
# Epoch: 647 Train loss: 0.0034628 Validation loss: 46.599
# Epoch: 648 Train loss: 0.0034623 Validation loss: 46.602
# Epoch: 649 Train loss: 0.0034618 Validation loss: 46.606
# Epoch: 650 Train loss: 0.0034612 Validation loss: 46.609
# Epoch: 651 Train loss: 0.0034607 Validation loss: 46.613
# Epoch: 652 Train loss: 0.0034601 Validation loss: 46.616
# Epoch: 653 Train loss: 0.0034596 Validation loss: 46.619
# Epoch: 654 Train loss: 0.0034591 Validation loss: 46.623
# Epoch: 655 Train loss: 0.0034585 Validation loss: 46.626
# Epoch: 656 Train loss: 0.003458 Validation loss: 46.629
# Epoch: 657 Train loss: 0.0034575 Validation loss: 46.633
# Epoch: 658 Train loss: 0.003457 Validation loss: 46.636
# Epoch: 659 Train loss: 0.0034565 Validation loss: 46.639
# Epoch: 660 Train loss: 0.003456 Validation loss: 46.642
# Epoch: 661 Train loss: 0.0034555 Validation loss: 46.646
# Epoch: 662 Train loss: 0.0034549 Validation loss: 46.649
# Epoch: 663 Train loss: 0.0034545 Validation loss: 46.652
# Epoch: 664 Train loss: 0.003454 Validation loss: 46.655
# Epoch: 665 Train loss: 0.0034535 Validation loss: 46.658
# Epoch: 666 Train loss: 0.003453 Validation loss: 46.662
# Epoch: 667 Train loss: 0.0034525 Validation loss: 46.665
# Epoch: 668 Train loss: 0.003452 Validation loss: 46.668
# Epoch: 669 Train loss: 0.0034515 Validation loss: 46.671
# Epoch: 670 Train loss: 0.003451 Validation loss: 46.674
# Epoch: 671 Train loss: 0.0034505 Validation loss: 46.677
# Epoch: 672 Train loss: 0.0034501 Validation loss: 46.68
# Epoch: 673 Train loss: 0.0034496 Validation loss: 46.683
# Epoch: 674 Train loss: 0.0034491 Validation loss: 46.686
# Epoch: 675 Train loss: 0.0034486 Validation loss: 46.689
# Epoch: 676 Train loss: 0.0034482 Validation loss: 46.692
# Epoch: 677 Train loss: 0.0034477 Validation loss: 46.695
# Epoch: 678 Train loss: 0.0034472 Validation loss: 46.698
# Epoch: 679 Train loss: 0.0034468 Validation loss: 46.701
# Epoch: 680 Train loss: 0.0034463 Validation loss: 46.704
# Epoch: 681 Train loss: 0.0034459 Validation loss: 46.707
# Epoch: 682 Train loss: 0.0034454 Validation loss: 46.71
# Epoch: 683 Train loss: 0.003445 Validation loss: 46.713
# Epoch: 684 Train loss: 0.0034445 Validation loss: 46.716
# Epoch: 685 Train loss: 0.0034441 Validation loss: 46.719
# Epoch: 686 Train loss: 0.0034436 Validation loss: 46.722
# Epoch: 687 Train loss: 0.0034432 Validation loss: 46.725
# Epoch: 688 Train loss: 0.0034427 Validation loss: 46.728
# Epoch: 689 Train loss: 0.0034423 Validation loss: 46.73
# Epoch: 690 Train loss: 0.0034419 Validation loss: 46.733
# Epoch: 691 Train loss: 0.0034414 Validation loss: 46.736
# Epoch: 692 Train loss: 0.003441 Validation loss: 46.739
# Epoch: 693 Train loss: 0.0034406 Validation loss: 46.742
# Epoch: 694 Train loss: 0.0034401 Validation loss: 46.744
# Epoch: 695 Train loss: 0.0034397 Validation loss: 46.747
# Epoch: 696 Train loss: 0.0034393 Validation loss: 46.75
# Epoch: 697 Train loss: 0.0034389 Validation loss: 46.753
# Epoch: 698 Train loss: 0.0034384 Validation loss: 46.755
# Epoch: 699 Train loss: 0.003438 Validation loss: 46.758
# Epoch: 700 Train loss: 0.0034376 Validation loss: 46.761
# Epoch: 701 Train loss: 0.0034372 Validation loss: 46.764
# Epoch: 702 Train loss: 0.0034368 Validation loss: 46.766
# Epoch: 703 Train loss: 0.0034364 Validation loss: 46.769
# Epoch: 704 Train loss: 0.0034359 Validation loss: 46.772
# Epoch: 705 Train loss: 0.0034355 Validation loss: 46.774
# Epoch: 706 Train loss: 0.0034351 Validation loss: 46.777
# Epoch: 707 Train loss: 0.0034347 Validation loss: 46.78
# Epoch: 708 Train loss: 0.0034343 Validation loss: 46.783
# Epoch: 709 Train loss: 0.0034339 Validation loss: 46.785
# Epoch: 710 Train loss: 0.0034335 Validation loss: 46.788
# Epoch: 711 Train loss: 0.0034331 Validation loss: 46.791
# Epoch: 712 Train loss: 0.0034327 Validation loss: 46.794
# Epoch: 713 Train loss: 0.0034323 Validation loss: 46.796
# Epoch: 714 Train loss: 0.003432 Validation loss: 46.799
# Epoch: 715 Train loss: 0.0034316 Validation loss: 46.801
# Epoch: 716 Train loss: 0.0034312 Validation loss: 46.804
# Epoch: 717 Train loss: 0.0034308 Validation loss: 46.807
# Epoch: 718 Train loss: 0.0034304 Validation loss: 46.809
# Epoch: 719 Train loss: 0.00343 Validation loss: 46.812
# Epoch: 720 Train loss: 0.0034297 Validation loss: 46.815
# Epoch: 721 Train loss: 0.0034293 Validation loss: 46.817
# Epoch: 722 Train loss: 0.0034289 Validation loss: 46.82
# Epoch: 723 Train loss: 0.0034285 Validation loss: 46.823
# Epoch: 724 Train loss: 0.0034282 Validation loss: 46.825
# Epoch: 725 Train loss: 0.0034278 Validation loss: 46.828
# Epoch: 726 Train loss: 0.0034274 Validation loss: 46.83
# Epoch: 727 Train loss: 0.003427 Validation loss: 46.833
# Epoch: 728 Train loss: 0.0034267 Validation loss: 46.835
# Epoch: 729 Train loss: 0.0034263 Validation loss: 46.838
# Epoch: 730 Train loss: 0.003426 Validation loss: 46.841
# Epoch: 731 Train loss: 0.0034256 Validation loss: 46.843
# Epoch: 732 Train loss: 0.0034253 Validation loss: 46.846
# Epoch: 733 Train loss: 0.0034249 Validation loss: 46.848
# Epoch: 734 Train loss: 0.0034245 Validation loss: 46.851
# Epoch: 735 Train loss: 0.0034242 Validation loss: 46.853
# Epoch: 736 Train loss: 0.0034238 Validation loss: 46.856
# Epoch: 737 Train loss: 0.0034235 Validation loss: 46.858
# Epoch: 738 Train loss: 0.0034231 Validation loss: 46.861
# Epoch: 739 Train loss: 0.0034228 Validation loss: 46.863
# Epoch: 740 Train loss: 0.0034224 Validation loss: 46.866
# Epoch: 741 Train loss: 0.0034221 Validation loss: 46.868
# Epoch: 742 Train loss: 0.0034218 Validation loss: 46.871
# Epoch: 743 Train loss: 0.0034214 Validation loss: 46.873
# Epoch: 744 Train loss: 0.0034211 Validation loss: 46.876
# Epoch: 745 Train loss: 0.0034207 Validation loss: 46.878
# Epoch: 746 Train loss: 0.0034204 Validation loss: 46.88
# Epoch: 747 Train loss: 0.0034201 Validation loss: 46.883
# Epoch: 748 Train loss: 0.0034197 Validation loss: 46.885
# Epoch: 749 Train loss: 0.0034194 Validation loss: 46.888
# Epoch: 750 Train loss: 0.0034191 Validation loss: 46.89
# Epoch: 751 Train loss: 0.0034187 Validation loss: 46.892
# Epoch: 752 Train loss: 0.0034184 Validation loss: 46.895
# Epoch: 753 Train loss: 0.0034181 Validation loss: 46.897
# Epoch: 754 Train loss: 0.0034177 Validation loss: 46.9
# Epoch: 755 Train loss: 0.0034174 Validation loss: 46.902
# Epoch: 756 Train loss: 0.0034171 Validation loss: 46.904
# Epoch: 757 Train loss: 0.0034168 Validation loss: 46.907
# Epoch: 758 Train loss: 0.0034165 Validation loss: 46.909
# Epoch: 759 Train loss: 0.0034161 Validation loss: 46.912
# Epoch: 760 Train loss: 0.0034158 Validation loss: 46.914
# Epoch: 761 Train loss: 0.0034155 Validation loss: 46.916
# Epoch: 762 Train loss: 0.0034152 Validation loss: 46.919
# Epoch: 763 Train loss: 0.0034149 Validation loss: 46.921
# Epoch: 764 Train loss: 0.0034146 Validation loss: 46.924
# Epoch: 765 Train loss: 0.0034142 Validation loss: 46.926
# Epoch: 766 Train loss: 0.0034139 Validation loss: 46.928
# Epoch: 767 Train loss: 0.0034136 Validation loss: 46.93
# Epoch: 768 Train loss: 0.0034133 Validation loss: 46.933
# Epoch: 769 Train loss: 0.003413 Validation loss: 46.935
# Epoch: 770 Train loss: 0.0034127 Validation loss: 46.937
# Epoch: 771 Train loss: 0.0034124 Validation loss: 46.94
# Epoch: 772 Train loss: 0.0034121 Validation loss: 46.942
# Epoch: 773 Train loss: 0.0034118 Validation loss: 46.944
# Epoch: 774 Train loss: 0.0034115 Validation loss: 46.946
# Epoch: 775 Train loss: 0.0034112 Validation loss: 46.949
# Epoch: 776 Train loss: 0.0034109 Validation loss: 46.951
# Epoch: 777 Train loss: 0.0034106 Validation loss: 46.953
# Epoch: 778 Train loss: 0.0034103 Validation loss: 46.956
# Epoch: 779 Train loss: 0.00341 Validation loss: 46.958
# Epoch: 780 Train loss: 0.0034097 Validation loss: 46.96
# Epoch: 781 Train loss: 0.0034094 Validation loss: 46.962
# Epoch: 782 Train loss: 0.0034091 Validation loss: 46.965
# Epoch: 783 Train loss: 0.0034088 Validation loss: 46.967
# Epoch: 784 Train loss: 0.0034085 Validation loss: 46.969
# Epoch: 785 Train loss: 0.0034082 Validation loss: 46.971
# Epoch: 786 Train loss: 0.0034079 Validation loss: 46.974
# Epoch: 787 Train loss: 0.0034076 Validation loss: 46.976
# Epoch: 788 Train loss: 0.0034073 Validation loss: 46.978
# Epoch: 789 Train loss: 0.0034071 Validation loss: 46.98
# Epoch: 790 Train loss: 0.0034068 Validation loss: 46.983
# Epoch: 791 Train loss: 0.0034065 Validation loss: 46.985
# Epoch: 792 Train loss: 0.0034062 Validation loss: 46.987
# Epoch: 793 Train loss: 0.0034059 Validation loss: 46.989
# Epoch: 794 Train loss: 0.0034056 Validation loss: 46.992
# Epoch: 795 Train loss: 0.0034053 Validation loss: 46.994
# Epoch: 796 Train loss: 0.0034051 Validation loss: 46.996
# Epoch: 797 Train loss: 0.0034048 Validation loss: 46.998
# Epoch: 798 Train loss: 0.0034045 Validation loss: 47.0
# Epoch: 799 Train loss: 0.0034042 Validation loss: 47.002
# Epoch: 800 Train loss: 0.0034039 Validation loss: 47.005
# Epoch: 801 Train loss: 0.0034037 Validation loss: 47.007
# Epoch: 802 Train loss: 0.0034034 Validation loss: 47.009
# Epoch: 803 Train loss: 0.0034031 Validation loss: 47.011
# Epoch: 804 Train loss: 0.0034028 Validation loss: 47.013
# Epoch: 805 Train loss: 0.0034026 Validation loss: 47.015
# Epoch: 806 Train loss: 0.0034023 Validation loss: 47.017
# Epoch: 807 Train loss: 0.003402 Validation loss: 47.019
# Epoch: 808 Train loss: 0.0034017 Validation loss: 47.022
# Epoch: 809 Train loss: 0.0034015 Validation loss: 47.024
# Epoch: 810 Train loss: 0.0034012 Validation loss: 47.026
# Epoch: 811 Train loss: 0.0034009 Validation loss: 47.028
# Epoch: 812 Train loss: 0.0034007 Validation loss: 47.03
# Epoch: 813 Train loss: 0.0034004 Validation loss: 47.032
# Epoch: 814 Train loss: 0.0034001 Validation loss: 47.034
# Epoch: 815 Train loss: 0.0033999 Validation loss: 47.036
# Epoch: 816 Train loss: 0.0033996 Validation loss: 47.038
# Epoch: 817 Train loss: 0.0033993 Validation loss: 47.04
# Epoch: 818 Train loss: 0.0033991 Validation loss: 47.042
# Epoch: 819 Train loss: 0.0033988 Validation loss: 47.044
# Epoch: 820 Train loss: 0.0033985 Validation loss: 47.046
# Epoch: 821 Train loss: 0.0033983 Validation loss: 47.048
# Epoch: 822 Train loss: 0.003398 Validation loss: 47.05
# Epoch: 823 Train loss: 0.0033977 Validation loss: 47.052
# Epoch: 824 Train loss: 0.0033975 Validation loss: 47.054
# Epoch: 825 Train loss: 0.0033972 Validation loss: 47.056
# Epoch: 826 Train loss: 0.003397 Validation loss: 47.058
# Epoch: 827 Train loss: 0.0033967 Validation loss: 47.06
# Epoch: 828 Train loss: 0.0033965 Validation loss: 47.062
# Epoch: 829 Train loss: 0.0033962 Validation loss: 47.065
# Epoch: 830 Train loss: 0.003396 Validation loss: 47.067
# Epoch: 831 Train loss: 0.0033957 Validation loss: 47.069
# Epoch: 832 Train loss: 0.0033954 Validation loss: 47.071
# Epoch: 833 Train loss: 0.0033952 Validation loss: 47.073
# Epoch: 834 Train loss: 0.0033949 Validation loss: 47.075
# Epoch: 835 Train loss: 0.0033947 Validation loss: 47.077
# Epoch: 836 Train loss: 0.0033945 Validation loss: 47.079
# Epoch: 837 Train loss: 0.0033942 Validation loss: 47.081
# Epoch: 838 Train loss: 0.003394 Validation loss: 47.083
# Epoch: 839 Train loss: 0.0033937 Validation loss: 47.085
# Epoch: 840 Train loss: 0.0033935 Validation loss: 47.087
# Epoch: 841 Train loss: 0.0033932 Validation loss: 47.089
# Epoch: 842 Train loss: 0.003393 Validation loss: 47.091
# Epoch: 843 Train loss: 0.0033927 Validation loss: 47.093
# Epoch: 844 Train loss: 0.0033925 Validation loss: 47.095
# Epoch: 845 Train loss: 0.0033922 Validation loss: 47.097
# Epoch: 846 Train loss: 0.003392 Validation loss: 47.099
# Epoch: 847 Train loss: 0.0033918 Validation loss: 47.101
# Epoch: 848 Train loss: 0.0033915 Validation loss: 47.103
# Epoch: 849 Train loss: 0.0033913 Validation loss: 47.105
# Epoch: 850 Train loss: 0.003391 Validation loss: 47.107
# Epoch: 851 Train loss: 0.0033908 Validation loss: 47.11
# Epoch: 852 Train loss: 0.0033906 Validation loss: 47.112
# Epoch: 853 Train loss: 0.0033903 Validation loss: 47.114
# Epoch: 854 Train loss: 0.0033901 Validation loss: 47.116
# Epoch: 855 Train loss: 0.0033899 Validation loss: 47.118
# Epoch: 856 Train loss: 0.0033896 Validation loss: 47.12
# Epoch: 857 Train loss: 0.0033894 Validation loss: 47.122
# Epoch: 858 Train loss: 0.0033891 Validation loss: 47.124
# Epoch: 859 Train loss: 0.0033889 Validation loss: 47.126
# Epoch: 860 Train loss: 0.0033887 Validation loss: 47.129
# Epoch: 861 Train loss: 0.0033885 Validation loss: 47.131
# Epoch: 862 Train loss: 0.0033882 Validation loss: 47.133
# Epoch: 863 Train loss: 0.003388 Validation loss: 47.135
# Epoch: 864 Train loss: 0.0033878 Validation loss: 47.137
# Epoch: 865 Train loss: 0.0033875 Validation loss: 47.139
# Epoch: 866 Train loss: 0.0033873 Validation loss: 47.141
# Epoch: 867 Train loss: 0.0033871 Validation loss: 47.143
# Epoch: 868 Train loss: 0.0033869 Validation loss: 47.145
# Epoch: 869 Train loss: 0.0033866 Validation loss: 47.147
# Epoch: 870 Train loss: 0.0033864 Validation loss: 47.149
# Epoch: 871 Train loss: 0.0033862 Validation loss: 47.151
# Epoch: 872 Train loss: 0.003386 Validation loss: 47.153
# Epoch: 873 Train loss: 0.0033857 Validation loss: 47.155
# Epoch: 874 Train loss: 0.0033855 Validation loss: 47.157
# Epoch: 875 Train loss: 0.0033853 Validation loss: 47.159
# Epoch: 876 Train loss: 0.0033851 Validation loss: 47.161
# Epoch: 877 Train loss: 0.0033848 Validation loss: 47.163
# Epoch: 878 Train loss: 0.0033846 Validation loss: 47.165
# Epoch: 879 Train loss: 0.0033844 Validation loss: 47.167
# Epoch: 880 Train loss: 0.0033842 Validation loss: 47.169
# Epoch: 881 Train loss: 0.0033839 Validation loss: 47.171
# Epoch: 882 Train loss: 0.0033837 Validation loss: 47.173
# Epoch: 883 Train loss: 0.0033835 Validation loss: 47.175
# Epoch: 884 Train loss: 0.0033833 Validation loss: 47.177
# Epoch: 885 Train loss: 0.0033831 Validation loss: 47.179
# Epoch: 886 Train loss: 0.0033828 Validation loss: 47.181
# Epoch: 887 Train loss: 0.0033826 Validation loss: 47.183
# Epoch: 888 Train loss: 0.0033824 Validation loss: 47.185
# Epoch: 889 Train loss: 0.0033822 Validation loss: 47.187
# Epoch: 890 Train loss: 0.003382 Validation loss: 47.189
# Epoch: 891 Train loss: 0.0033818 Validation loss: 47.191
# Epoch: 892 Train loss: 0.0033815 Validation loss: 47.193
# Epoch: 893 Train loss: 0.0033813 Validation loss: 47.195
# Epoch: 894 Train loss: 0.0033811 Validation loss: 47.197
# Epoch: 895 Train loss: 0.0033809 Validation loss: 47.199
# Epoch: 896 Train loss: 0.0033807 Validation loss: 47.201
# Epoch: 897 Train loss: 0.0033805 Validation loss: 47.203
# Epoch: 898 Train loss: 0.0033802 Validation loss: 47.205
# Epoch: 899 Train loss: 0.00338 Validation loss: 47.207
# Epoch: 900 Train loss: 0.0033798 Validation loss: 47.209
# Epoch: 901 Train loss: 0.0033796 Validation loss: 47.211
# Epoch: 902 Train loss: 0.0033794 Validation loss: 47.213
# Epoch: 903 Train loss: 0.0033792 Validation loss: 47.215
# Epoch: 904 Train loss: 0.003379 Validation loss: 47.217
# Epoch: 905 Train loss: 0.0033788 Validation loss: 47.218
# Epoch: 906 Train loss: 0.0033786 Validation loss: 47.22
# Epoch: 907 Train loss: 0.0033783 Validation loss: 47.222
# Epoch: 908 Train loss: 0.0033781 Validation loss: 47.224
# Epoch: 909 Train loss: 0.0033779 Validation loss: 47.226
# Epoch: 910 Train loss: 0.0033777 Validation loss: 47.228
# Epoch: 911 Train loss: 0.0033775 Validation loss: 47.23
# Epoch: 912 Train loss: 0.0033773 Validation loss: 47.232
# Epoch: 913 Train loss: 0.0033771 Validation loss: 47.234
# Epoch: 914 Train loss: 0.0033769 Validation loss: 47.236
# Epoch: 915 Train loss: 0.0033767 Validation loss: 47.238
# Epoch: 916 Train loss: 0.0033765 Validation loss: 47.24
# Epoch: 917 Train loss: 0.0033763 Validation loss: 47.242
# Epoch: 918 Train loss: 0.0033761 Validation loss: 47.244
# Epoch: 919 Train loss: 0.0033759 Validation loss: 47.246
# Epoch: 920 Train loss: 0.0033757 Validation loss: 47.248
# Epoch: 921 Train loss: 0.0033755 Validation loss: 47.25
# Epoch: 922 Train loss: 0.0033752 Validation loss: 47.252
# Epoch: 923 Train loss: 0.003375 Validation loss: 47.254
# Epoch: 924 Train loss: 0.0033748 Validation loss: 47.256
# Epoch: 925 Train loss: 0.0033746 Validation loss: 47.258
# Epoch: 926 Train loss: 0.0033744 Validation loss: 47.26
# Epoch: 927 Train loss: 0.0033742 Validation loss: 47.262
# Epoch: 928 Train loss: 0.003374 Validation loss: 47.264
# Epoch: 929 Train loss: 0.0033738 Validation loss: 47.265
# Epoch: 930 Train loss: 0.0033736 Validation loss: 47.267
# Epoch: 931 Train loss: 0.0033734 Validation loss: 47.269
# Epoch: 932 Train loss: 0.0033732 Validation loss: 47.271
# Epoch: 933 Train loss: 0.003373 Validation loss: 47.273
# Epoch: 934 Train loss: 0.0033728 Validation loss: 47.275
# Epoch: 935 Train loss: 0.0033726 Validation loss: 47.277
# Epoch: 936 Train loss: 0.0033724 Validation loss: 47.279
# Epoch: 937 Train loss: 0.0033722 Validation loss: 47.281
# Epoch: 938 Train loss: 0.003372 Validation loss: 47.282
# Epoch: 939 Train loss: 0.0033719 Validation loss: 47.284
# Epoch: 940 Train loss: 0.0033717 Validation loss: 47.286
# Epoch: 941 Train loss: 0.0033715 Validation loss: 47.288
# Epoch: 942 Train loss: 0.0033713 Validation loss: 47.29
# Epoch: 943 Train loss: 0.0033711 Validation loss: 47.292
# Epoch: 944 Train loss: 0.0033709 Validation loss: 47.294
# Epoch: 945 Train loss: 0.0033707 Validation loss: 47.296
# Epoch: 946 Train loss: 0.0033705 Validation loss: 47.297
# Epoch: 947 Train loss: 0.0033703 Validation loss: 47.299
# Epoch: 948 Train loss: 0.0033701 Validation loss: 47.301
# Epoch: 949 Train loss: 0.0033699 Validation loss: 47.303
# Epoch: 950 Train loss: 0.0033697 Validation loss: 47.305
# Epoch: 951 Train loss: 0.0033695 Validation loss: 47.307
# Epoch: 952 Train loss: 0.0033693 Validation loss: 47.309
# Epoch: 953 Train loss: 0.0033691 Validation loss: 47.311
# Epoch: 954 Train loss: 0.0033689 Validation loss: 47.313
# Epoch: 955 Train loss: 0.0033687 Validation loss: 47.314
# Epoch: 956 Train loss: 0.0033685 Validation loss: 47.316
# Epoch: 957 Train loss: 0.0033684 Validation loss: 47.318
# Epoch: 958 Train loss: 0.0033682 Validation loss: 47.32
# Epoch: 959 Train loss: 0.003368 Validation loss: 47.322
# Epoch: 960 Train loss: 0.0033678 Validation loss: 47.324
# Epoch: 961 Train loss: 0.0033676 Validation loss: 47.326
# Epoch: 962 Train loss: 0.0033674 Validation loss: 47.328
# Epoch: 963 Train loss: 0.0033672 Validation loss: 47.329
# Epoch: 964 Train loss: 0.003367 Validation loss: 47.331
# Epoch: 965 Train loss: 0.0033668 Validation loss: 47.333
# Epoch: 966 Train loss: 0.0033667 Validation loss: 47.335
# Epoch: 967 Train loss: 0.0033665 Validation loss: 47.337
# Epoch: 968 Train loss: 0.0033663 Validation loss: 47.339
# Epoch: 969 Train loss: 0.0033661 Validation loss: 47.341
# Epoch: 970 Train loss: 0.0033659 Validation loss: 47.343
# Epoch: 971 Train loss: 0.0033657 Validation loss: 47.344
# Epoch: 972 Train loss: 0.0033655 Validation loss: 47.346
# Epoch: 973 Train loss: 0.0033653 Validation loss: 47.348
# Epoch: 974 Train loss: 0.0033651 Validation loss: 47.35
# Epoch: 975 Train loss: 0.003365 Validation loss: 47.352
# Epoch: 976 Train loss: 0.0033648 Validation loss: 47.354
# Epoch: 977 Train loss: 0.0033646 Validation loss: 47.356
# Epoch: 978 Train loss: 0.0033644 Validation loss: 47.357
# Epoch: 979 Train loss: 0.0033642 Validation loss: 47.359
# Epoch: 980 Train loss: 0.003364 Validation loss: 47.361
# Epoch: 981 Train loss: 0.0033639 Validation loss: 47.363
# Epoch: 982 Train loss: 0.0033637 Validation loss: 47.365
# Epoch: 983 Train loss: 0.0033635 Validation loss: 47.367
# Epoch: 984 Train loss: 0.0033633 Validation loss: 47.369
# Epoch: 985 Train loss: 0.0033631 Validation loss: 47.37
# Epoch: 986 Train loss: 0.003363 Validation loss: 47.372
# Epoch: 987 Train loss: 0.0033628 Validation loss: 47.374
# Epoch: 988 Train loss: 0.0033626 Validation loss: 47.376
# Epoch: 989 Train loss: 0.0033624 Validation loss: 47.378
# Epoch: 990 Train loss: 0.0033622 Validation loss: 47.38
# Epoch: 991 Train loss: 0.0033621 Validation loss: 47.382
# Epoch: 992 Train loss: 0.0033619 Validation loss: 47.384
# Epoch: 993 Train loss: 0.0033617 Validation loss: 47.386
# Epoch: 994 Train loss: 0.0033615 Validation loss: 47.388
# Epoch: 995 Train loss: 0.0033613 Validation loss: 47.389
# Epoch: 996 Train loss: 0.0033612 Validation loss: 47.391
# Epoch: 997 Train loss: 0.003361 Validation loss: 47.393
# Epoch: 998 Train loss: 0.0033608 Validation loss: 47.395
# Epoch: 999 Train loss: 0.0033606 Validation loss: 47.397

# %% [markdown]
# Predicting with this model shows overfitting. For recognizing overfitting a comparison of the validation and training loss is very useful. If the training loss decreases during training while the validation loss consistently increases, the model you are training is probably overfitting. Plotting the models prediction and the target also shows that there is a significant discrepancy between the target and the prediction of the model.

# %%
y_pred = big_mdl.__call__(x) # Predict on x with "big_mdl"
plt.scatter(x_train_overfit, y_train_overfit)
plt.plot(x, y_true)
plt.plot(x, y_pred.numpy())
plt.legend(["Target", "Prediction", "Training samples"])
plt.show()

# %% [markdown]
# In order to implement a regularization we need to modify the loss function. Since the loss function in this exercise is computed during the training step, we define a new training step with a regularization.

# %%
""" In order to avoid overfitting we implement a training step that also includes a regularization on the weights of our big model. For this we use the Frobenius/squared l2-norm of each weight matrix/vector. 
Hint: Use the tf.reduce_sum() function on a list of individual regularization terms for each matrix/vector of the network."""

def regularized_train_step(model, optimizer, x, y, lmbd):
    with tf.GradientTape() as tape:
        tape.watch(model.trainable_variables)
        y_pred = model.__call__(x) # Compute a prediction with "model" on the input "x"
        loss_val = tf.reduce_sum(tf.pow(y_pred-y, 2)) / (2 * y_pred.shape[0])# Compute the Mean Squared Error (MSE) for the prediction "y_pred" and the targets "y"
        regul_val = tf.reduce_sum([tf.reduce_sum(tf.square(d)) for d in model.trainable_variables]) # Compute the regularization based on the list "model.trainable_variables"
        total_loss = loss_val + lmbd * regul_val# Add the loss with a the regularization term weighted by "lmbd"
    grads = tape.gradient(total_loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))
    return loss_val

# %% [markdown]
# We can now set the strength of the regularization and retrain the big model with a regularization. We create another instance of the big model in order to compare the big model with and without regularization.

# %%
""" Implement the training for the bigger model with the regularized_train_step function. Note: We are plotting the MSE loss without the regularization in order to compare it with the unregularized model. """

lmbd = 0.005

big_reg_mdl = MyBigModel()
big_opt = tf.optimizers.SGD(learning_rate)

epoch = 0
train_iters = 0
train_loss = 0.0
# while True:
for x_t, y_t in train_overfit_ds:
  # print(x_t.shape)
  # print(y_t.shape)
  train_loss += regularized_train_step(big_reg_mdl,big_opt, x_t,y_t, lmbd)# Perform a regularized training step with the model "big_mdl" and the optimizer "big_opt" on the inputs "x_t" and the corresponding targets "y_t" with the regularization parameter being "lmbd"
  train_iters += 1
  # print(train_iters)
  if train_iters == batch_size: # An epoch is completed
    for x_v, y_v in validation_ds:
        y_pred = big_reg_mdl.__call__(x_v)# Compute a prediction with "big_mdl" on the input "x_v"
        validation_loss = tf.reduce_sum(tf.pow(y_pred-y_v, 2)) / (2 * y_pred.shape[0]) # Compute the Mean Squared Error (MSE) for the prediction "y_pred" and the targets "y_v"
    print("Epoch: {} Train loss: {:.5} Validation loss: {:.5}".format(epoch, train_loss/train_iters, validation_loss))
    train_iters = 0
    train_loss = 0.0
    train_reg = 0.0
    epoch += 1
  if (epoch == N_epochs):
        break
# Out:
# Epoch: 0 Train loss: 0.70953 Validation loss: 50.426
# Epoch: 1 Train loss: 0.1077 Validation loss: 39.057
# Epoch: 2 Train loss: 0.051984 Validation loss: 37.704
# Epoch: 3 Train loss: 0.06875 Validation loss: 37.331
# Epoch: 4 Train loss: 0.056806 Validation loss: 37.687
# Epoch: 5 Train loss: 0.051622 Validation loss: 37.667
# Epoch: 6 Train loss: 0.049966 Validation loss: 37.447
# Epoch: 7 Train loss: 0.047616 Validation loss: 37.438
# Epoch: 8 Train loss: 0.045226 Validation loss: 37.483
# Epoch: 9 Train loss: 0.043387 Validation loss: 37.512
# Epoch: 10 Train loss: 0.041797 Validation loss: 37.557
# Epoch: 11 Train loss: 0.040303 Validation loss: 37.615
# Epoch: 12 Train loss: 0.038989 Validation loss: 37.672
# Epoch: 13 Train loss: 0.037815 Validation loss: 37.73
# Epoch: 14 Train loss: 0.03674 Validation loss: 37.789
# Epoch: 15 Train loss: 0.035772 Validation loss: 37.846
# Epoch: 16 Train loss: 0.034889 Validation loss: 37.902
# Epoch: 17 Train loss: 0.034082 Validation loss: 37.955
# Epoch: 18 Train loss: 0.033346 Validation loss: 38.006
# Epoch: 19 Train loss: 0.032669 Validation loss: 38.055
# Epoch: 20 Train loss: 0.032048 Validation loss: 38.101
# Epoch: 21 Train loss: 0.031475 Validation loss: 38.144
# Epoch: 22 Train loss: 0.030948 Validation loss: 38.185
# Epoch: 23 Train loss: 0.03046 Validation loss: 38.223
# Epoch: 24 Train loss: 0.03001 Validation loss: 38.26
# Epoch: 25 Train loss: 0.029592 Validation loss: 38.293
# Epoch: 26 Train loss: 0.029205 Validation loss: 38.325
# Epoch: 27 Train loss: 0.028845 Validation loss: 38.355
# Epoch: 28 Train loss: 0.028511 Validation loss: 38.383
# Epoch: 29 Train loss: 0.0282 Validation loss: 38.409
# Epoch: 30 Train loss: 0.027911 Validation loss: 38.434
# Epoch: 31 Train loss: 0.027641 Validation loss: 38.457
# Epoch: 32 Train loss: 0.02739 Validation loss: 38.479
# Epoch: 33 Train loss: 0.027155 Validation loss: 38.499
# Epoch: 34 Train loss: 0.026936 Validation loss: 38.518
# Epoch: 35 Train loss: 0.026732 Validation loss: 38.536
# Epoch: 36 Train loss: 0.02654 Validation loss: 38.553
# Epoch: 37 Train loss: 0.026361 Validation loss: 38.57
# Epoch: 38 Train loss: 0.026194 Validation loss: 38.585
# Epoch: 39 Train loss: 0.026037 Validation loss: 38.599
# Epoch: 40 Train loss: 0.025891 Validation loss: 38.613
# Epoch: 41 Train loss: 0.025753 Validation loss: 38.626
# Epoch: 42 Train loss: 0.025625 Validation loss: 38.638
# Epoch: 43 Train loss: 0.025505 Validation loss: 38.65
# Epoch: 44 Train loss: 0.025392 Validation loss: 38.661
# Epoch: 45 Train loss: 0.025287 Validation loss: 38.672
# Epoch: 46 Train loss: 0.025188 Validation loss: 38.683
# Epoch: 47 Train loss: 0.025095 Validation loss: 38.693
# Epoch: 48 Train loss: 0.025009 Validation loss: 38.703
# Epoch: 49 Train loss: 0.024928 Validation loss: 38.712
# Epoch: 50 Train loss: 0.024851 Validation loss: 38.721
# Epoch: 51 Train loss: 0.02478 Validation loss: 38.73
# Epoch: 52 Train loss: 0.024714 Validation loss: 38.739
# Epoch: 53 Train loss: 0.024652 Validation loss: 38.747
# Epoch: 54 Train loss: 0.024594 Validation loss: 38.756
# Epoch: 55 Train loss: 0.02454 Validation loss: 38.764
# Epoch: 56 Train loss: 0.024489 Validation loss: 38.773
# Epoch: 57 Train loss: 0.024442 Validation loss: 38.781
# Epoch: 58 Train loss: 0.024398 Validation loss: 38.789
# Epoch: 59 Train loss: 0.024357 Validation loss: 38.797
# Epoch: 60 Train loss: 0.024319 Validation loss: 38.805
# Epoch: 61 Train loss: 0.024284 Validation loss: 38.813
# Epoch: 62 Train loss: 0.024251 Validation loss: 38.822
# Epoch: 63 Train loss: 0.024221 Validation loss: 38.83
# Epoch: 64 Train loss: 0.024193 Validation loss: 38.838
# Epoch: 65 Train loss: 0.024167 Validation loss: 38.846
# Epoch: 66 Train loss: 0.024143 Validation loss: 38.855
# Epoch: 67 Train loss: 0.024121 Validation loss: 38.863
# Epoch: 68 Train loss: 0.024101 Validation loss: 38.872
# Epoch: 69 Train loss: 0.024083 Validation loss: 38.881
# Epoch: 70 Train loss: 0.024067 Validation loss: 38.89
# Epoch: 71 Train loss: 0.024052 Validation loss: 38.898
# Epoch: 72 Train loss: 0.024038 Validation loss: 38.908
# Epoch: 73 Train loss: 0.024026 Validation loss: 38.917
# Epoch: 74 Train loss: 0.024015 Validation loss: 38.926
# Epoch: 75 Train loss: 0.024006 Validation loss: 38.936
# Epoch: 76 Train loss: 0.023998 Validation loss: 38.946
# Epoch: 77 Train loss: 0.023991 Validation loss: 38.955
# Epoch: 78 Train loss: 0.023984 Validation loss: 38.966
# Epoch: 79 Train loss: 0.02398 Validation loss: 38.976
# Epoch: 80 Train loss: 0.023976 Validation loss: 38.986
# Epoch: 81 Train loss: 0.023973 Validation loss: 38.997
# Epoch: 82 Train loss: 0.02397 Validation loss: 39.007
# Epoch: 83 Train loss: 0.023969 Validation loss: 39.018
# Epoch: 84 Train loss: 0.023969 Validation loss: 39.029
# Epoch: 85 Train loss: 0.02397 Validation loss: 39.041
# Epoch: 86 Train loss: 0.02397 Validation loss: 39.052
# Epoch: 87 Train loss: 0.023972 Validation loss: 39.064
# Epoch: 88 Train loss: 0.023974 Validation loss: 39.075
# Epoch: 89 Train loss: 0.023977 Validation loss: 39.087
# Epoch: 90 Train loss: 0.023981 Validation loss: 39.099
# Epoch: 91 Train loss: 0.023985 Validation loss: 39.111
# Epoch: 92 Train loss: 0.02399 Validation loss: 39.124
# Epoch: 93 Train loss: 0.023995 Validation loss: 39.136
# Epoch: 94 Train loss: 0.024001 Validation loss: 39.149
# Epoch: 95 Train loss: 0.024008 Validation loss: 39.161
# Epoch: 96 Train loss: 0.024014 Validation loss: 39.174
# Epoch: 97 Train loss: 0.024022 Validation loss: 39.187
# Epoch: 98 Train loss: 0.024029 Validation loss: 39.2
# Epoch: 99 Train loss: 0.024037 Validation loss: 39.213
# Epoch: 100 Train loss: 0.024045 Validation loss: 39.226
# Epoch: 101 Train loss: 0.024054 Validation loss: 39.24
# Epoch: 102 Train loss: 0.024063 Validation loss: 39.253
# Epoch: 103 Train loss: 0.024072 Validation loss: 39.266
# Epoch: 104 Train loss: 0.024081 Validation loss: 39.28
# Epoch: 105 Train loss: 0.024091 Validation loss: 39.293
# Epoch: 106 Train loss: 0.024101 Validation loss: 39.307
# Epoch: 107 Train loss: 0.024111 Validation loss: 39.32
# Epoch: 108 Train loss: 0.024122 Validation loss: 39.334
# Epoch: 109 Train loss: 0.024132 Validation loss: 39.348
# Epoch: 110 Train loss: 0.024142 Validation loss: 39.361
# Epoch: 111 Train loss: 0.024153 Validation loss: 39.375
# Epoch: 112 Train loss: 0.024164 Validation loss: 39.388
# Epoch: 113 Train loss: 0.024174 Validation loss: 39.402
# Epoch: 114 Train loss: 0.024185 Validation loss: 39.415
# Epoch: 115 Train loss: 0.024196 Validation loss: 39.428
# Epoch: 116 Train loss: 0.024206 Validation loss: 39.442
# Epoch: 117 Train loss: 0.024216 Validation loss: 39.455
# Epoch: 118 Train loss: 0.024226 Validation loss: 39.468
# Epoch: 119 Train loss: 0.024236 Validation loss: 39.481
# Epoch: 120 Train loss: 0.024246 Validation loss: 39.494
# Epoch: 121 Train loss: 0.024256 Validation loss: 39.507
# Epoch: 122 Train loss: 0.024265 Validation loss: 39.52
# Epoch: 123 Train loss: 0.024274 Validation loss: 39.533
# Epoch: 124 Train loss: 0.024282 Validation loss: 39.546
# Epoch: 125 Train loss: 0.02429 Validation loss: 39.559
# Epoch: 126 Train loss: 0.024297 Validation loss: 39.571
# Epoch: 127 Train loss: 0.024304 Validation loss: 39.584
# Epoch: 128 Train loss: 0.024311 Validation loss: 39.596
# Epoch: 129 Train loss: 0.024317 Validation loss: 39.609
# Epoch: 130 Train loss: 0.024323 Validation loss: 39.621
# Epoch: 131 Train loss: 0.024328 Validation loss: 39.634
# Epoch: 132 Train loss: 0.024333 Validation loss: 39.646
# Epoch: 133 Train loss: 0.024337 Validation loss: 39.659
# Epoch: 134 Train loss: 0.024341 Validation loss: 39.671
# Epoch: 135 Train loss: 0.024345 Validation loss: 39.684
# Epoch: 136 Train loss: 0.024349 Validation loss: 39.697
# Epoch: 137 Train loss: 0.024353 Validation loss: 39.709
# Epoch: 138 Train loss: 0.024358 Validation loss: 39.722
# Epoch: 139 Train loss: 0.024363 Validation loss: 39.735
# Epoch: 140 Train loss: 0.024369 Validation loss: 39.748
# Epoch: 141 Train loss: 0.024376 Validation loss: 39.761
# Epoch: 142 Train loss: 0.024385 Validation loss: 39.773
# Epoch: 143 Train loss: 0.024395 Validation loss: 39.786
# Epoch: 144 Train loss: 0.024408 Validation loss: 39.798
# Epoch: 145 Train loss: 0.024421 Validation loss: 39.81
# Epoch: 146 Train loss: 0.024437 Validation loss: 39.822
# Epoch: 147 Train loss: 0.024453 Validation loss: 39.833
# Epoch: 148 Train loss: 0.024471 Validation loss: 39.843
# Epoch: 149 Train loss: 0.024488 Validation loss: 39.852
# Epoch: 150 Train loss: 0.024505 Validation loss: 39.861
# Epoch: 151 Train loss: 0.024522 Validation loss: 39.87
# Epoch: 152 Train loss: 0.024539 Validation loss: 39.878
# Epoch: 153 Train loss: 0.024554 Validation loss: 39.887
# Epoch: 154 Train loss: 0.024569 Validation loss: 39.896
# Epoch: 155 Train loss: 0.024584 Validation loss: 39.905
# Epoch: 156 Train loss: 0.024597 Validation loss: 39.914
# Epoch: 157 Train loss: 0.02461 Validation loss: 39.924
# Epoch: 158 Train loss: 0.024622 Validation loss: 39.934
# Epoch: 159 Train loss: 0.024633 Validation loss: 39.945
# Epoch: 160 Train loss: 0.024643 Validation loss: 39.956
# Epoch: 161 Train loss: 0.024653 Validation loss: 39.968
# Epoch: 162 Train loss: 0.024661 Validation loss: 39.981
# Epoch: 163 Train loss: 0.024669 Validation loss: 39.994
# Epoch: 164 Train loss: 0.024675 Validation loss: 40.009
# Epoch: 165 Train loss: 0.02468 Validation loss: 40.024
# Epoch: 166 Train loss: 0.024685 Validation loss: 40.041
# Epoch: 167 Train loss: 0.024688 Validation loss: 40.058
# Epoch: 168 Train loss: 0.02469 Validation loss: 40.077
# Epoch: 169 Train loss: 0.02469 Validation loss: 40.097
# Epoch: 170 Train loss: 0.02469 Validation loss: 40.118
# Epoch: 171 Train loss: 0.024688 Validation loss: 40.14
# Epoch: 172 Train loss: 0.024684 Validation loss: 40.164
# Epoch: 173 Train loss: 0.024679 Validation loss: 40.189
# Epoch: 174 Train loss: 0.024673 Validation loss: 40.215
# Epoch: 175 Train loss: 0.024665 Validation loss: 40.243
# Epoch: 176 Train loss: 0.024655 Validation loss: 40.273
# Epoch: 177 Train loss: 0.024644 Validation loss: 40.304
# Epoch: 178 Train loss: 0.024631 Validation loss: 40.336
# Epoch: 179 Train loss: 0.024616 Validation loss: 40.371
# Epoch: 180 Train loss: 0.024599 Validation loss: 40.406
# Epoch: 181 Train loss: 0.024581 Validation loss: 40.443
# Epoch: 182 Train loss: 0.02456 Validation loss: 40.482
# Epoch: 183 Train loss: 0.024538 Validation loss: 40.522
# Epoch: 184 Train loss: 0.024513 Validation loss: 40.562
# Epoch: 185 Train loss: 0.024487 Validation loss: 40.604
# Epoch: 186 Train loss: 0.024459 Validation loss: 40.647
# Epoch: 187 Train loss: 0.024429 Validation loss: 40.69
# Epoch: 188 Train loss: 0.024397 Validation loss: 40.734
# Epoch: 189 Train loss: 0.024363 Validation loss: 40.777
# Epoch: 190 Train loss: 0.024328 Validation loss: 40.82
# Epoch: 191 Train loss: 0.024292 Validation loss: 40.863
# Epoch: 192 Train loss: 0.024254 Validation loss: 40.904
# Epoch: 193 Train loss: 0.024215 Validation loss: 40.944
# Epoch: 194 Train loss: 0.024175 Validation loss: 40.982
# Epoch: 195 Train loss: 0.024135 Validation loss: 41.018
# Epoch: 196 Train loss: 0.024093 Validation loss: 41.052
# Epoch: 197 Train loss: 0.024052 Validation loss: 41.083
# Epoch: 198 Train loss: 0.02401 Validation loss: 41.111
# Epoch: 199 Train loss: 0.023969 Validation loss: 41.135
# Epoch: 200 Train loss: 0.023927 Validation loss: 41.156
# Epoch: 201 Train loss: 0.023886 Validation loss: 41.174
# Epoch: 202 Train loss: 0.023846 Validation loss: 41.188
# Epoch: 203 Train loss: 0.023806 Validation loss: 41.198
# Epoch: 204 Train loss: 0.023766 Validation loss: 41.204
# Epoch: 205 Train loss: 0.023727 Validation loss: 41.207
# Epoch: 206 Train loss: 0.023689 Validation loss: 41.206
# Epoch: 207 Train loss: 0.023651 Validation loss: 41.201
# Epoch: 208 Train loss: 0.023614 Validation loss: 41.193
# Epoch: 209 Train loss: 0.023578 Validation loss: 41.182
# Epoch: 210 Train loss: 0.023542 Validation loss: 41.167
# Epoch: 211 Train loss: 0.023506 Validation loss: 41.15
# Epoch: 212 Train loss: 0.023471 Validation loss: 41.13
# Epoch: 213 Train loss: 0.023436 Validation loss: 41.106
# Epoch: 214 Train loss: 0.023401 Validation loss: 41.081
# Epoch: 215 Train loss: 0.023367 Validation loss: 41.052
# Epoch: 216 Train loss: 0.023332 Validation loss: 41.022
# Epoch: 217 Train loss: 0.023297 Validation loss: 40.989
# Epoch: 218 Train loss: 0.023262 Validation loss: 40.954
# Epoch: 219 Train loss: 0.023227 Validation loss: 40.917
# Epoch: 220 Train loss: 0.023191 Validation loss: 40.878
# Epoch: 221 Train loss: 0.023155 Validation loss: 40.838
# Epoch: 222 Train loss: 0.023118 Validation loss: 40.796
# Epoch: 223 Train loss: 0.023081 Validation loss: 40.752
# Epoch: 224 Train loss: 0.023043 Validation loss: 40.707
# Epoch: 225 Train loss: 0.023005 Validation loss: 40.661
# Epoch: 226 Train loss: 0.022966 Validation loss: 40.614
# Epoch: 227 Train loss: 0.022926 Validation loss: 40.566
# Epoch: 228 Train loss: 0.022886 Validation loss: 40.518
# Epoch: 229 Train loss: 0.022846 Validation loss: 40.469
# Epoch: 230 Train loss: 0.022805 Validation loss: 40.421
# Epoch: 231 Train loss: 0.022764 Validation loss: 40.372
# Epoch: 232 Train loss: 0.022722 Validation loss: 40.324
# Epoch: 233 Train loss: 0.022681 Validation loss: 40.276
# Epoch: 234 Train loss: 0.02264 Validation loss: 40.229
# Epoch: 235 Train loss: 0.022598 Validation loss: 40.184
# Epoch: 236 Train loss: 0.022558 Validation loss: 40.14
# Epoch: 237 Train loss: 0.022517 Validation loss: 40.097
# Epoch: 238 Train loss: 0.022478 Validation loss: 40.057
# Epoch: 239 Train loss: 0.022439 Validation loss: 40.018
# Epoch: 240 Train loss: 0.022401 Validation loss: 39.982
# Epoch: 241 Train loss: 0.022363 Validation loss: 39.948
# Epoch: 242 Train loss: 0.022327 Validation loss: 39.916
# Epoch: 243 Train loss: 0.022291 Validation loss: 39.886
# Epoch: 244 Train loss: 0.022256 Validation loss: 39.859
# Epoch: 245 Train loss: 0.022223 Validation loss: 39.834
# Epoch: 246 Train loss: 0.02219 Validation loss: 39.812
# Epoch: 247 Train loss: 0.022158 Validation loss: 39.791
# Epoch: 248 Train loss: 0.022127 Validation loss: 39.773
# Epoch: 249 Train loss: 0.022097 Validation loss: 39.757
# Epoch: 250 Train loss: 0.022067 Validation loss: 39.743
# Epoch: 251 Train loss: 0.022039 Validation loss: 39.73
# Epoch: 252 Train loss: 0.022011 Validation loss: 39.719
# Epoch: 253 Train loss: 0.021985 Validation loss: 39.71
# Epoch: 254 Train loss: 0.021959 Validation loss: 39.703
# Epoch: 255 Train loss: 0.021933 Validation loss: 39.697
# Epoch: 256 Train loss: 0.021909 Validation loss: 39.693
# Epoch: 257 Train loss: 0.021885 Validation loss: 39.689
# Epoch: 258 Train loss: 0.021862 Validation loss: 39.688
# Epoch: 259 Train loss: 0.02184 Validation loss: 39.687
# Epoch: 260 Train loss: 0.021819 Validation loss: 39.687
# Epoch: 261 Train loss: 0.021798 Validation loss: 39.689
# Epoch: 262 Train loss: 0.021777 Validation loss: 39.692
# Epoch: 263 Train loss: 0.021758 Validation loss: 39.696
# Epoch: 264 Train loss: 0.021738 Validation loss: 39.701
# Epoch: 265 Train loss: 0.02172 Validation loss: 39.707
# Epoch: 266 Train loss: 0.021702 Validation loss: 39.715
# Epoch: 267 Train loss: 0.021684 Validation loss: 39.723
# Epoch: 268 Train loss: 0.021667 Validation loss: 39.732
# Epoch: 269 Train loss: 0.02165 Validation loss: 39.742
# Epoch: 270 Train loss: 0.021633 Validation loss: 39.753
# Epoch: 271 Train loss: 0.021617 Validation loss: 39.765
# Epoch: 272 Train loss: 0.021601 Validation loss: 39.778
# Epoch: 273 Train loss: 0.021585 Validation loss: 39.792
# Epoch: 274 Train loss: 0.021569 Validation loss: 39.806
# Epoch: 275 Train loss: 0.021553 Validation loss: 39.822
# Epoch: 276 Train loss: 0.021538 Validation loss: 39.838
# Epoch: 277 Train loss: 0.021522 Validation loss: 39.854
# Epoch: 278 Train loss: 0.021507 Validation loss: 39.872
# Epoch: 279 Train loss: 0.021492 Validation loss: 39.89
# Epoch: 280 Train loss: 0.021476 Validation loss: 39.909
# Epoch: 281 Train loss: 0.021461 Validation loss: 39.928
# Epoch: 282 Train loss: 0.021446 Validation loss: 39.948
# Epoch: 283 Train loss: 0.02143 Validation loss: 39.969
# Epoch: 284 Train loss: 0.021415 Validation loss: 39.99
# Epoch: 285 Train loss: 0.021399 Validation loss: 40.011
# Epoch: 286 Train loss: 0.021383 Validation loss: 40.032
# Epoch: 287 Train loss: 0.021368 Validation loss: 40.055
# Epoch: 288 Train loss: 0.021352 Validation loss: 40.077
# Epoch: 289 Train loss: 0.021336 Validation loss: 40.099
# Epoch: 290 Train loss: 0.02132 Validation loss: 40.122
# Epoch: 291 Train loss: 0.021304 Validation loss: 40.145
# Epoch: 292 Train loss: 0.021288 Validation loss: 40.168
# Epoch: 293 Train loss: 0.021271 Validation loss: 40.191
# Epoch: 294 Train loss: 0.021255 Validation loss: 40.215
# Epoch: 295 Train loss: 0.021239 Validation loss: 40.238
# Epoch: 296 Train loss: 0.021222 Validation loss: 40.261
# Epoch: 297 Train loss: 0.021206 Validation loss: 40.284
# Epoch: 298 Train loss: 0.021189 Validation loss: 40.307
# Epoch: 299 Train loss: 0.021173 Validation loss: 40.33
# Epoch: 300 Train loss: 0.021156 Validation loss: 40.353
# Epoch: 301 Train loss: 0.02114 Validation loss: 40.376
# Epoch: 302 Train loss: 0.021123 Validation loss: 40.398
# Epoch: 303 Train loss: 0.021107 Validation loss: 40.42
# Epoch: 304 Train loss: 0.021091 Validation loss: 40.442
# Epoch: 305 Train loss: 0.021074 Validation loss: 40.463
# Epoch: 306 Train loss: 0.021058 Validation loss: 40.484
# Epoch: 307 Train loss: 0.021042 Validation loss: 40.505
# Epoch: 308 Train loss: 0.021026 Validation loss: 40.525
# Epoch: 309 Train loss: 0.02101 Validation loss: 40.545
# Epoch: 310 Train loss: 0.020994 Validation loss: 40.564
# Epoch: 311 Train loss: 0.020978 Validation loss: 40.583
# Epoch: 312 Train loss: 0.020962 Validation loss: 40.601
# Epoch: 313 Train loss: 0.020947 Validation loss: 40.619
# Epoch: 314 Train loss: 0.020932 Validation loss: 40.636
# Epoch: 315 Train loss: 0.020916 Validation loss: 40.653
# Epoch: 316 Train loss: 0.020901 Validation loss: 40.669
# Epoch: 317 Train loss: 0.020886 Validation loss: 40.684
# Epoch: 318 Train loss: 0.020872 Validation loss: 40.699
# Epoch: 319 Train loss: 0.020857 Validation loss: 40.714
# Epoch: 320 Train loss: 0.020843 Validation loss: 40.727
# Epoch: 321 Train loss: 0.020829 Validation loss: 40.74
# Epoch: 322 Train loss: 0.020815 Validation loss: 40.752
# Epoch: 323 Train loss: 0.020801 Validation loss: 40.764
# Epoch: 324 Train loss: 0.020787 Validation loss: 40.775
# Epoch: 325 Train loss: 0.020773 Validation loss: 40.785
# Epoch: 326 Train loss: 0.02076 Validation loss: 40.795
# Epoch: 327 Train loss: 0.020747 Validation loss: 40.803
# Epoch: 328 Train loss: 0.020734 Validation loss: 40.812
# Epoch: 329 Train loss: 0.020721 Validation loss: 40.819
# Epoch: 330 Train loss: 0.020708 Validation loss: 40.826
# Epoch: 331 Train loss: 0.020696 Validation loss: 40.832
# Epoch: 332 Train loss: 0.020684 Validation loss: 40.838
# Epoch: 333 Train loss: 0.020671 Validation loss: 40.843
# Epoch: 334 Train loss: 0.02066 Validation loss: 40.847
# Epoch: 335 Train loss: 0.020648 Validation loss: 40.851
# Epoch: 336 Train loss: 0.020636 Validation loss: 40.854
# Epoch: 337 Train loss: 0.020625 Validation loss: 40.856
# Epoch: 338 Train loss: 0.020613 Validation loss: 40.857
# Epoch: 339 Train loss: 0.020602 Validation loss: 40.859
# Epoch: 340 Train loss: 0.020591 Validation loss: 40.859
# Epoch: 341 Train loss: 0.020581 Validation loss: 40.859
# Epoch: 342 Train loss: 0.02057 Validation loss: 40.858
# Epoch: 343 Train loss: 0.02056 Validation loss: 40.857
# Epoch: 344 Train loss: 0.02055 Validation loss: 40.855
# Epoch: 345 Train loss: 0.02054 Validation loss: 40.853
# Epoch: 346 Train loss: 0.02053 Validation loss: 40.85
# Epoch: 347 Train loss: 0.020521 Validation loss: 40.847
# Epoch: 348 Train loss: 0.020511 Validation loss: 40.843
# Epoch: 349 Train loss: 0.020502 Validation loss: 40.839
# Epoch: 350 Train loss: 0.020493 Validation loss: 40.834
# Epoch: 351 Train loss: 0.020485 Validation loss: 40.829
# Epoch: 352 Train loss: 0.020476 Validation loss: 40.824
# Epoch: 353 Train loss: 0.020468 Validation loss: 40.818
# Epoch: 354 Train loss: 0.02046 Validation loss: 40.811
# Epoch: 355 Train loss: 0.020452 Validation loss: 40.805
# Epoch: 356 Train loss: 0.020444 Validation loss: 40.797
# Epoch: 357 Train loss: 0.020437 Validation loss: 40.79
# Epoch: 358 Train loss: 0.020429 Validation loss: 40.782
# Epoch: 359 Train loss: 0.020422 Validation loss: 40.774
# Epoch: 360 Train loss: 0.020415 Validation loss: 40.766
# Epoch: 361 Train loss: 0.020408 Validation loss: 40.757
# Epoch: 362 Train loss: 0.020401 Validation loss: 40.748
# Epoch: 363 Train loss: 0.020394 Validation loss: 40.739
# Epoch: 364 Train loss: 0.020388 Validation loss: 40.73
# Epoch: 365 Train loss: 0.020381 Validation loss: 40.72
# Epoch: 366 Train loss: 0.020375 Validation loss: 40.71
# Epoch: 367 Train loss: 0.020368 Validation loss: 40.7
# Epoch: 368 Train loss: 0.020362 Validation loss: 40.69
# Epoch: 369 Train loss: 0.020356 Validation loss: 40.679
# Epoch: 370 Train loss: 0.02035 Validation loss: 40.668
# Epoch: 371 Train loss: 0.020344 Validation loss: 40.657
# Epoch: 372 Train loss: 0.020338 Validation loss: 40.646
# Epoch: 373 Train loss: 0.020332 Validation loss: 40.635
# Epoch: 374 Train loss: 0.020326 Validation loss: 40.624
# Epoch: 375 Train loss: 0.02032 Validation loss: 40.613
# Epoch: 376 Train loss: 0.020315 Validation loss: 40.602
# Epoch: 377 Train loss: 0.020309 Validation loss: 40.59
# Epoch: 378 Train loss: 0.020303 Validation loss: 40.579
# Epoch: 379 Train loss: 0.020298 Validation loss: 40.568
# Epoch: 380 Train loss: 0.020292 Validation loss: 40.556
# Epoch: 381 Train loss: 0.020287 Validation loss: 40.545
# Epoch: 382 Train loss: 0.020282 Validation loss: 40.534
# Epoch: 383 Train loss: 0.020276 Validation loss: 40.523
# Epoch: 384 Train loss: 0.020271 Validation loss: 40.512
# Epoch: 385 Train loss: 0.020266 Validation loss: 40.501
# Epoch: 386 Train loss: 0.02026 Validation loss: 40.49
# Epoch: 387 Train loss: 0.020255 Validation loss: 40.48
# Epoch: 388 Train loss: 0.02025 Validation loss: 40.47
# Epoch: 389 Train loss: 0.020244 Validation loss: 40.459
# Epoch: 390 Train loss: 0.020239 Validation loss: 40.45
# Epoch: 391 Train loss: 0.020233 Validation loss: 40.44
# Epoch: 392 Train loss: 0.020227 Validation loss: 40.43
# Epoch: 393 Train loss: 0.020221 Validation loss: 40.421
# Epoch: 394 Train loss: 0.020215 Validation loss: 40.412
# Epoch: 395 Train loss: 0.020209 Validation loss: 40.403
# Epoch: 396 Train loss: 0.020202 Validation loss: 40.395
# Epoch: 397 Train loss: 0.020196 Validation loss: 40.386
# Epoch: 398 Train loss: 0.020189 Validation loss: 40.378
# Epoch: 399 Train loss: 0.020182 Validation loss: 40.37
# Epoch: 400 Train loss: 0.020175 Validation loss: 40.362
# Epoch: 401 Train loss: 0.020167 Validation loss: 40.355
# Epoch: 402 Train loss: 0.02016 Validation loss: 40.347
# Epoch: 403 Train loss: 0.020152 Validation loss: 40.34
# Epoch: 404 Train loss: 0.020143 Validation loss: 40.333
# Epoch: 405 Train loss: 0.020135 Validation loss: 40.326
# Epoch: 406 Train loss: 0.020126 Validation loss: 40.319
# Epoch: 407 Train loss: 0.020117 Validation loss: 40.312
# Epoch: 408 Train loss: 0.020108 Validation loss: 40.305
# Epoch: 409 Train loss: 0.020099 Validation loss: 40.299
# Epoch: 410 Train loss: 0.020089 Validation loss: 40.292
# Epoch: 411 Train loss: 0.020079 Validation loss: 40.286
# Epoch: 412 Train loss: 0.020069 Validation loss: 40.28
# Epoch: 413 Train loss: 0.020058 Validation loss: 40.273
# Epoch: 414 Train loss: 0.020048 Validation loss: 40.267
# Epoch: 415 Train loss: 0.020037 Validation loss: 40.261
# Epoch: 416 Train loss: 0.020026 Validation loss: 40.255
# Epoch: 417 Train loss: 0.020015 Validation loss: 40.249
# Epoch: 418 Train loss: 0.020003 Validation loss: 40.243
# Epoch: 419 Train loss: 0.019992 Validation loss: 40.236
# Epoch: 420 Train loss: 0.01998 Validation loss: 40.23
# Epoch: 421 Train loss: 0.019968 Validation loss: 40.224
# Epoch: 422 Train loss: 0.019956 Validation loss: 40.218
# Epoch: 423 Train loss: 0.019944 Validation loss: 40.212
# Epoch: 424 Train loss: 0.019931 Validation loss: 40.205
# Epoch: 425 Train loss: 0.019919 Validation loss: 40.199
# Epoch: 426 Train loss: 0.019906 Validation loss: 40.193
# Epoch: 427 Train loss: 0.019894 Validation loss: 40.186
# Epoch: 428 Train loss: 0.019881 Validation loss: 40.18
# Epoch: 429 Train loss: 0.019868 Validation loss: 40.173
# Epoch: 430 Train loss: 0.019856 Validation loss: 40.167
# Epoch: 431 Train loss: 0.019843 Validation loss: 40.16
# Epoch: 432 Train loss: 0.01983 Validation loss: 40.154
# Epoch: 433 Train loss: 0.019817 Validation loss: 40.147
# Epoch: 434 Train loss: 0.019804 Validation loss: 40.14
# Epoch: 435 Train loss: 0.019791 Validation loss: 40.134
# Epoch: 436 Train loss: 0.019778 Validation loss: 40.127
# Epoch: 437 Train loss: 0.019765 Validation loss: 40.12
# Epoch: 438 Train loss: 0.019752 Validation loss: 40.113
# Epoch: 439 Train loss: 0.019739 Validation loss: 40.106
# Epoch: 440 Train loss: 0.019726 Validation loss: 40.099
# Epoch: 441 Train loss: 0.019713 Validation loss: 40.092
# Epoch: 442 Train loss: 0.0197 Validation loss: 40.085
# Epoch: 443 Train loss: 0.019687 Validation loss: 40.078
# Epoch: 444 Train loss: 0.019674 Validation loss: 40.07
# Epoch: 445 Train loss: 0.019661 Validation loss: 40.063
# Epoch: 446 Train loss: 0.019649 Validation loss: 40.056
# Epoch: 447 Train loss: 0.019636 Validation loss: 40.048
# Epoch: 448 Train loss: 0.019623 Validation loss: 40.041
# Epoch: 449 Train loss: 0.019611 Validation loss: 40.034
# Epoch: 450 Train loss: 0.019598 Validation loss: 40.026
# Epoch: 451 Train loss: 0.019586 Validation loss: 40.019
# Epoch: 452 Train loss: 0.019573 Validation loss: 40.011
# Epoch: 453 Train loss: 0.019561 Validation loss: 40.004
# Epoch: 454 Train loss: 0.019549 Validation loss: 39.996
# Epoch: 455 Train loss: 0.019537 Validation loss: 39.989
# Epoch: 456 Train loss: 0.019525 Validation loss: 39.981
# Epoch: 457 Train loss: 0.019513 Validation loss: 39.974
# Epoch: 458 Train loss: 0.019501 Validation loss: 39.966
# Epoch: 459 Train loss: 0.019489 Validation loss: 39.959
# Epoch: 460 Train loss: 0.019477 Validation loss: 39.951
# Epoch: 461 Train loss: 0.019465 Validation loss: 39.944
# Epoch: 462 Train loss: 0.019454 Validation loss: 39.936
# Epoch: 463 Train loss: 0.019442 Validation loss: 39.928
# Epoch: 464 Train loss: 0.019431 Validation loss: 39.921
# Epoch: 465 Train loss: 0.01942 Validation loss: 39.913
# Epoch: 466 Train loss: 0.019409 Validation loss: 39.906
# Epoch: 467 Train loss: 0.019397 Validation loss: 39.898
# Epoch: 468 Train loss: 0.019387 Validation loss: 39.89
# Epoch: 469 Train loss: 0.019376 Validation loss: 39.883
# Epoch: 470 Train loss: 0.019365 Validation loss: 39.875
# Epoch: 471 Train loss: 0.019354 Validation loss: 39.868
# Epoch: 472 Train loss: 0.019344 Validation loss: 39.86
# Epoch: 473 Train loss: 0.019333 Validation loss: 39.853
# Epoch: 474 Train loss: 0.019323 Validation loss: 39.845
# Epoch: 475 Train loss: 0.019313 Validation loss: 39.838
# Epoch: 476 Train loss: 0.019303 Validation loss: 39.83
# Epoch: 477 Train loss: 0.019293 Validation loss: 39.823
# Epoch: 478 Train loss: 0.019283 Validation loss: 39.815
# Epoch: 479 Train loss: 0.019273 Validation loss: 39.808
# Epoch: 480 Train loss: 0.019264 Validation loss: 39.8
# Epoch: 481 Train loss: 0.019254 Validation loss: 39.793
# Epoch: 482 Train loss: 0.019245 Validation loss: 39.785
# Epoch: 483 Train loss: 0.019236 Validation loss: 39.778
# Epoch: 484 Train loss: 0.019227 Validation loss: 39.77
# Epoch: 485 Train loss: 0.019218 Validation loss: 39.763
# Epoch: 486 Train loss: 0.019209 Validation loss: 39.755
# Epoch: 487 Train loss: 0.0192 Validation loss: 39.748
# Epoch: 488 Train loss: 0.019192 Validation loss: 39.741
# Epoch: 489 Train loss: 0.019184 Validation loss: 39.733
# Epoch: 490 Train loss: 0.019175 Validation loss: 39.726
# Epoch: 491 Train loss: 0.019167 Validation loss: 39.719
# Epoch: 492 Train loss: 0.019159 Validation loss: 39.711
# Epoch: 493 Train loss: 0.019151 Validation loss: 39.704
# Epoch: 494 Train loss: 0.019144 Validation loss: 39.697
# Epoch: 495 Train loss: 0.019136 Validation loss: 39.689
# Epoch: 496 Train loss: 0.019129 Validation loss: 39.682
# Epoch: 497 Train loss: 0.019121 Validation loss: 39.675
# Epoch: 498 Train loss: 0.019114 Validation loss: 39.668
# Epoch: 499 Train loss: 0.019107 Validation loss: 39.66
# Epoch: 500 Train loss: 0.0191 Validation loss: 39.653
# Epoch: 501 Train loss: 0.019093 Validation loss: 39.646
# Epoch: 502 Train loss: 0.019087 Validation loss: 39.639
# Epoch: 503 Train loss: 0.01908 Validation loss: 39.632
# Epoch: 504 Train loss: 0.019074 Validation loss: 39.625
# Epoch: 505 Train loss: 0.019068 Validation loss: 39.617
# Epoch: 506 Train loss: 0.019062 Validation loss: 39.61
# Epoch: 507 Train loss: 0.019055 Validation loss: 39.603
# Epoch: 508 Train loss: 0.01905 Validation loss: 39.596
# Epoch: 509 Train loss: 0.019044 Validation loss: 39.589
# Epoch: 510 Train loss: 0.019038 Validation loss: 39.582
# Epoch: 511 Train loss: 0.019033 Validation loss: 39.575
# Epoch: 512 Train loss: 0.019027 Validation loss: 39.568
# Epoch: 513 Train loss: 0.019022 Validation loss: 39.561
# Epoch: 514 Train loss: 0.019017 Validation loss: 39.554
# Epoch: 515 Train loss: 0.019012 Validation loss: 39.547
# Epoch: 516 Train loss: 0.019007 Validation loss: 39.54
# Epoch: 517 Train loss: 0.019002 Validation loss: 39.533
# Epoch: 518 Train loss: 0.018997 Validation loss: 39.526
# Epoch: 519 Train loss: 0.018992 Validation loss: 39.519
# Epoch: 520 Train loss: 0.018988 Validation loss: 39.512
# Epoch: 521 Train loss: 0.018983 Validation loss: 39.505
# Epoch: 522 Train loss: 0.018979 Validation loss: 39.498
# Epoch: 523 Train loss: 0.018975 Validation loss: 39.492
# Epoch: 524 Train loss: 0.018971 Validation loss: 39.485
# Epoch: 525 Train loss: 0.018966 Validation loss: 39.478
# Epoch: 526 Train loss: 0.018962 Validation loss: 39.471
# Epoch: 527 Train loss: 0.018958 Validation loss: 39.464
# Epoch: 528 Train loss: 0.018955 Validation loss: 39.458
# Epoch: 529 Train loss: 0.018951 Validation loss: 39.451
# Epoch: 530 Train loss: 0.018947 Validation loss: 39.444
# Epoch: 531 Train loss: 0.018943 Validation loss: 39.437
# Epoch: 532 Train loss: 0.01894 Validation loss: 39.431
# Epoch: 533 Train loss: 0.018936 Validation loss: 39.424
# Epoch: 534 Train loss: 0.018933 Validation loss: 39.417
# Epoch: 535 Train loss: 0.01893 Validation loss: 39.411
# Epoch: 536 Train loss: 0.018926 Validation loss: 39.404
# Epoch: 537 Train loss: 0.018923 Validation loss: 39.398
# Epoch: 538 Train loss: 0.01892 Validation loss: 39.391
# Epoch: 539 Train loss: 0.018917 Validation loss: 39.384
# Epoch: 540 Train loss: 0.018914 Validation loss: 39.378
# Epoch: 541 Train loss: 0.018911 Validation loss: 39.371
# Epoch: 542 Train loss: 0.018908 Validation loss: 39.365
# Epoch: 543 Train loss: 0.018905 Validation loss: 39.358
# Epoch: 544 Train loss: 0.018902 Validation loss: 39.352
# Epoch: 545 Train loss: 0.018899 Validation loss: 39.346
# Epoch: 546 Train loss: 0.018896 Validation loss: 39.339
# Epoch: 547 Train loss: 0.018893 Validation loss: 39.333
# Epoch: 548 Train loss: 0.018891 Validation loss: 39.327
# Epoch: 549 Train loss: 0.018888 Validation loss: 39.32
# Epoch: 550 Train loss: 0.018885 Validation loss: 39.314
# Epoch: 551 Train loss: 0.018883 Validation loss: 39.308
# Epoch: 552 Train loss: 0.01888 Validation loss: 39.301
# Epoch: 553 Train loss: 0.018877 Validation loss: 39.295
# Epoch: 554 Train loss: 0.018875 Validation loss: 39.289
# Epoch: 555 Train loss: 0.018872 Validation loss: 39.283
# Epoch: 556 Train loss: 0.01887 Validation loss: 39.277
# Epoch: 557 Train loss: 0.018867 Validation loss: 39.271
# Epoch: 558 Train loss: 0.018865 Validation loss: 39.264
# Epoch: 559 Train loss: 0.018862 Validation loss: 39.258
# Epoch: 560 Train loss: 0.01886 Validation loss: 39.252
# Epoch: 561 Train loss: 0.018857 Validation loss: 39.246
# Epoch: 562 Train loss: 0.018855 Validation loss: 39.24
# Epoch: 563 Train loss: 0.018853 Validation loss: 39.234
# Epoch: 564 Train loss: 0.01885 Validation loss: 39.229
# Epoch: 565 Train loss: 0.018848 Validation loss: 39.223
# Epoch: 566 Train loss: 0.018846 Validation loss: 39.217
# Epoch: 567 Train loss: 0.018843 Validation loss: 39.211
# Epoch: 568 Train loss: 0.018841 Validation loss: 39.205
# Epoch: 569 Train loss: 0.018838 Validation loss: 39.199
# Epoch: 570 Train loss: 0.018836 Validation loss: 39.194
# Epoch: 571 Train loss: 0.018834 Validation loss: 39.188
# Epoch: 572 Train loss: 0.018831 Validation loss: 39.182
# Epoch: 573 Train loss: 0.018829 Validation loss: 39.176
# Epoch: 574 Train loss: 0.018827 Validation loss: 39.171
# Epoch: 575 Train loss: 0.018825 Validation loss: 39.165
# Epoch: 576 Train loss: 0.018822 Validation loss: 39.16
# Epoch: 577 Train loss: 0.01882 Validation loss: 39.154
# Epoch: 578 Train loss: 0.018818 Validation loss: 39.148
# Epoch: 579 Train loss: 0.018815 Validation loss: 39.143
# Epoch: 580 Train loss: 0.018813 Validation loss: 39.137
# Epoch: 581 Train loss: 0.018811 Validation loss: 39.132
# Epoch: 582 Train loss: 0.018808 Validation loss: 39.127
# Epoch: 583 Train loss: 0.018806 Validation loss: 39.121
# Epoch: 584 Train loss: 0.018803 Validation loss: 39.116
# Epoch: 585 Train loss: 0.018801 Validation loss: 39.111
# Epoch: 586 Train loss: 0.018799 Validation loss: 39.105
# Epoch: 587 Train loss: 0.018796 Validation loss: 39.1
# Epoch: 588 Train loss: 0.018794 Validation loss: 39.095
# Epoch: 589 Train loss: 0.018792 Validation loss: 39.09
# Epoch: 590 Train loss: 0.018789 Validation loss: 39.084
# Epoch: 591 Train loss: 0.018787 Validation loss: 39.079
# Epoch: 592 Train loss: 0.018784 Validation loss: 39.074
# Epoch: 593 Train loss: 0.018782 Validation loss: 39.069
# Epoch: 594 Train loss: 0.01878 Validation loss: 39.064
# Epoch: 595 Train loss: 0.018777 Validation loss: 39.059
# Epoch: 596 Train loss: 0.018775 Validation loss: 39.054
# Epoch: 597 Train loss: 0.018772 Validation loss: 39.049
# Epoch: 598 Train loss: 0.01877 Validation loss: 39.044
# Epoch: 599 Train loss: 0.018767 Validation loss: 39.039
# Epoch: 600 Train loss: 0.018765 Validation loss: 39.034
# Epoch: 601 Train loss: 0.018762 Validation loss: 39.03
# Epoch: 602 Train loss: 0.01876 Validation loss: 39.025
# Epoch: 603 Train loss: 0.018757 Validation loss: 39.02
# Epoch: 604 Train loss: 0.018755 Validation loss: 39.015
# Epoch: 605 Train loss: 0.018752 Validation loss: 39.011
# Epoch: 606 Train loss: 0.01875 Validation loss: 39.006
# Epoch: 607 Train loss: 0.018747 Validation loss: 39.001
# Epoch: 608 Train loss: 0.018745 Validation loss: 38.997
# Epoch: 609 Train loss: 0.018742 Validation loss: 38.992
# Epoch: 610 Train loss: 0.01874 Validation loss: 38.988
# Epoch: 611 Train loss: 0.018737 Validation loss: 38.983
# Epoch: 612 Train loss: 0.018735 Validation loss: 38.979
# Epoch: 613 Train loss: 0.018732 Validation loss: 38.974
# Epoch: 614 Train loss: 0.018729 Validation loss: 38.97
# Epoch: 615 Train loss: 0.018727 Validation loss: 38.965
# Epoch: 616 Train loss: 0.018724 Validation loss: 38.961
# Epoch: 617 Train loss: 0.018721 Validation loss: 38.957
# Epoch: 618 Train loss: 0.018719 Validation loss: 38.952
# Epoch: 619 Train loss: 0.018716 Validation loss: 38.948
# Epoch: 620 Train loss: 0.018714 Validation loss: 38.944
# Epoch: 621 Train loss: 0.018711 Validation loss: 38.94
# Epoch: 622 Train loss: 0.018708 Validation loss: 38.936
# Epoch: 623 Train loss: 0.018705 Validation loss: 38.931
# Epoch: 624 Train loss: 0.018703 Validation loss: 38.927
# Epoch: 625 Train loss: 0.0187 Validation loss: 38.923
# Epoch: 626 Train loss: 0.018697 Validation loss: 38.919
# Epoch: 627 Train loss: 0.018695 Validation loss: 38.915
# Epoch: 628 Train loss: 0.018692 Validation loss: 38.911
# Epoch: 629 Train loss: 0.018689 Validation loss: 38.907
# Epoch: 630 Train loss: 0.018687 Validation loss: 38.903
# Epoch: 631 Train loss: 0.018684 Validation loss: 38.899
# Epoch: 632 Train loss: 0.018681 Validation loss: 38.896
# Epoch: 633 Train loss: 0.018678 Validation loss: 38.892
# Epoch: 634 Train loss: 0.018676 Validation loss: 38.888
# Epoch: 635 Train loss: 0.018673 Validation loss: 38.884
# Epoch: 636 Train loss: 0.01867 Validation loss: 38.88
# Epoch: 637 Train loss: 0.018668 Validation loss: 38.877
# Epoch: 638 Train loss: 0.018665 Validation loss: 38.873
# Epoch: 639 Train loss: 0.018662 Validation loss: 38.869
# Epoch: 640 Train loss: 0.018659 Validation loss: 38.866
# Epoch: 641 Train loss: 0.018657 Validation loss: 38.862
# Epoch: 642 Train loss: 0.018654 Validation loss: 38.859
# Epoch: 643 Train loss: 0.018651 Validation loss: 38.855
# Epoch: 644 Train loss: 0.018648 Validation loss: 38.852
# Epoch: 645 Train loss: 0.018646 Validation loss: 38.848
# Epoch: 646 Train loss: 0.018643 Validation loss: 38.845
# Epoch: 647 Train loss: 0.01864 Validation loss: 38.841
# Epoch: 648 Train loss: 0.018637 Validation loss: 38.838
# Epoch: 649 Train loss: 0.018635 Validation loss: 38.835
# Epoch: 650 Train loss: 0.018632 Validation loss: 38.831
# Epoch: 651 Train loss: 0.018629 Validation loss: 38.828
# Epoch: 652 Train loss: 0.018627 Validation loss: 38.825
# Epoch: 653 Train loss: 0.018624 Validation loss: 38.822
# Epoch: 654 Train loss: 0.018621 Validation loss: 38.818
# Epoch: 655 Train loss: 0.018619 Validation loss: 38.815
# Epoch: 656 Train loss: 0.018616 Validation loss: 38.812
# Epoch: 657 Train loss: 0.018613 Validation loss: 38.809
# Epoch: 658 Train loss: 0.018611 Validation loss: 38.806
# Epoch: 659 Train loss: 0.018608 Validation loss: 38.803
# Epoch: 660 Train loss: 0.018605 Validation loss: 38.8
# Epoch: 661 Train loss: 0.018603 Validation loss: 38.797
# Epoch: 662 Train loss: 0.0186 Validation loss: 38.794
# Epoch: 663 Train loss: 0.018597 Validation loss: 38.791
# Epoch: 664 Train loss: 0.018595 Validation loss: 38.788
# Epoch: 665 Train loss: 0.018592 Validation loss: 38.785
# Epoch: 666 Train loss: 0.018589 Validation loss: 38.782
# Epoch: 667 Train loss: 0.018587 Validation loss: 38.779
# Epoch: 668 Train loss: 0.018584 Validation loss: 38.777
# Epoch: 669 Train loss: 0.018582 Validation loss: 38.774
# Epoch: 670 Train loss: 0.018579 Validation loss: 38.771
# Epoch: 671 Train loss: 0.018577 Validation loss: 38.768
# Epoch: 672 Train loss: 0.018574 Validation loss: 38.766
# Epoch: 673 Train loss: 0.018572 Validation loss: 38.763
# Epoch: 674 Train loss: 0.018569 Validation loss: 38.76
# Epoch: 675 Train loss: 0.018567 Validation loss: 38.758
# Epoch: 676 Train loss: 0.018564 Validation loss: 38.755
# Epoch: 677 Train loss: 0.018562 Validation loss: 38.752
# Epoch: 678 Train loss: 0.018559 Validation loss: 38.75
# Epoch: 679 Train loss: 0.018557 Validation loss: 38.747
# Epoch: 680 Train loss: 0.018555 Validation loss: 38.745
# Epoch: 681 Train loss: 0.018552 Validation loss: 38.742
# Epoch: 682 Train loss: 0.01855 Validation loss: 38.74
# Epoch: 683 Train loss: 0.018547 Validation loss: 38.737
# Epoch: 684 Train loss: 0.018545 Validation loss: 38.735
# Epoch: 685 Train loss: 0.018543 Validation loss: 38.733
# Epoch: 686 Train loss: 0.018541 Validation loss: 38.73
# Epoch: 687 Train loss: 0.018538 Validation loss: 38.728
# Epoch: 688 Train loss: 0.018536 Validation loss: 38.726
# Epoch: 689 Train loss: 0.018534 Validation loss: 38.723
# Epoch: 690 Train loss: 0.018532 Validation loss: 38.721
# Epoch: 691 Train loss: 0.018529 Validation loss: 38.719
# Epoch: 692 Train loss: 0.018527 Validation loss: 38.717
# Epoch: 693 Train loss: 0.018525 Validation loss: 38.714
# Epoch: 694 Train loss: 0.018523 Validation loss: 38.712
# Epoch: 695 Train loss: 0.018521 Validation loss: 38.71
# Epoch: 696 Train loss: 0.018519 Validation loss: 38.708
# Epoch: 697 Train loss: 0.018517 Validation loss: 38.706
# Epoch: 698 Train loss: 0.018515 Validation loss: 38.704
# Epoch: 699 Train loss: 0.018513 Validation loss: 38.702
# Epoch: 700 Train loss: 0.018511 Validation loss: 38.7
# Epoch: 701 Train loss: 0.018509 Validation loss: 38.698
# Epoch: 702 Train loss: 0.018507 Validation loss: 38.696
# Epoch: 703 Train loss: 0.018505 Validation loss: 38.694
# Epoch: 704 Train loss: 0.018503 Validation loss: 38.692
# Epoch: 705 Train loss: 0.018501 Validation loss: 38.69
# Epoch: 706 Train loss: 0.018499 Validation loss: 38.688
# Epoch: 707 Train loss: 0.018497 Validation loss: 38.686
# Epoch: 708 Train loss: 0.018496 Validation loss: 38.684
# Epoch: 709 Train loss: 0.018494 Validation loss: 38.682
# Epoch: 710 Train loss: 0.018492 Validation loss: 38.68
# Epoch: 711 Train loss: 0.01849 Validation loss: 38.678
# Epoch: 712 Train loss: 0.018489 Validation loss: 38.676
# Epoch: 713 Train loss: 0.018487 Validation loss: 38.675
# Epoch: 714 Train loss: 0.018485 Validation loss: 38.673
# Epoch: 715 Train loss: 0.018484 Validation loss: 38.671
# Epoch: 716 Train loss: 0.018482 Validation loss: 38.669
# Epoch: 717 Train loss: 0.018481 Validation loss: 38.668
# Epoch: 718 Train loss: 0.018479 Validation loss: 38.666
# Epoch: 719 Train loss: 0.018478 Validation loss: 38.664
# Epoch: 720 Train loss: 0.018476 Validation loss: 38.663
# Epoch: 721 Train loss: 0.018475 Validation loss: 38.661
# Epoch: 722 Train loss: 0.018473 Validation loss: 38.659
# Epoch: 723 Train loss: 0.018472 Validation loss: 38.658
# Epoch: 724 Train loss: 0.01847 Validation loss: 38.656
# Epoch: 725 Train loss: 0.018469 Validation loss: 38.654
# Epoch: 726 Train loss: 0.018468 Validation loss: 38.653
# Epoch: 727 Train loss: 0.018466 Validation loss: 38.651
# Epoch: 728 Train loss: 0.018465 Validation loss: 38.65
# Epoch: 729 Train loss: 0.018464 Validation loss: 38.648
# Epoch: 730 Train loss: 0.018463 Validation loss: 38.647
# Epoch: 731 Train loss: 0.018462 Validation loss: 38.645
# Epoch: 732 Train loss: 0.01846 Validation loss: 38.644
# Epoch: 733 Train loss: 0.018459 Validation loss: 38.642
# Epoch: 734 Train loss: 0.018458 Validation loss: 38.641
# Epoch: 735 Train loss: 0.018457 Validation loss: 38.639
# Epoch: 736 Train loss: 0.018456 Validation loss: 38.638
# Epoch: 737 Train loss: 0.018455 Validation loss: 38.637
# Epoch: 738 Train loss: 0.018454 Validation loss: 38.635
# Epoch: 739 Train loss: 0.018453 Validation loss: 38.634
# Epoch: 740 Train loss: 0.018452 Validation loss: 38.632
# Epoch: 741 Train loss: 0.018451 Validation loss: 38.631
# Epoch: 742 Train loss: 0.01845 Validation loss: 38.63
# Epoch: 743 Train loss: 0.018449 Validation loss: 38.628
# Epoch: 744 Train loss: 0.018449 Validation loss: 38.627
# Epoch: 745 Train loss: 0.018448 Validation loss: 38.626
# Epoch: 746 Train loss: 0.018447 Validation loss: 38.625
# Epoch: 747 Train loss: 0.018446 Validation loss: 38.623
# Epoch: 748 Train loss: 0.018446 Validation loss: 38.622
# Epoch: 749 Train loss: 0.018445 Validation loss: 38.621
# Epoch: 750 Train loss: 0.018444 Validation loss: 38.62
# Epoch: 751 Train loss: 0.018444 Validation loss: 38.618
# Epoch: 752 Train loss: 0.018443 Validation loss: 38.617
# Epoch: 753 Train loss: 0.018442 Validation loss: 38.616
# Epoch: 754 Train loss: 0.018442 Validation loss: 38.615
# Epoch: 755 Train loss: 0.018441 Validation loss: 38.614
# Epoch: 756 Train loss: 0.018441 Validation loss: 38.613
# Epoch: 757 Train loss: 0.01844 Validation loss: 38.611
# Epoch: 758 Train loss: 0.01844 Validation loss: 38.61
# Epoch: 759 Train loss: 0.018439 Validation loss: 38.609
# Epoch: 760 Train loss: 0.018439 Validation loss: 38.608
# Epoch: 761 Train loss: 0.018439 Validation loss: 38.607
# Epoch: 762 Train loss: 0.018438 Validation loss: 38.606
# Epoch: 763 Train loss: 0.018438 Validation loss: 38.605
# Epoch: 764 Train loss: 0.018438 Validation loss: 38.604
# Epoch: 765 Train loss: 0.018437 Validation loss: 38.603
# Epoch: 766 Train loss: 0.018437 Validation loss: 38.602
# Epoch: 767 Train loss: 0.018437 Validation loss: 38.601
# Epoch: 768 Train loss: 0.018437 Validation loss: 38.6
# Epoch: 769 Train loss: 0.018437 Validation loss: 38.599
# Epoch: 770 Train loss: 0.018437 Validation loss: 38.598
# Epoch: 771 Train loss: 0.018437 Validation loss: 38.597
# Epoch: 772 Train loss: 0.018437 Validation loss: 38.596
# Epoch: 773 Train loss: 0.018436 Validation loss: 38.595
# Epoch: 774 Train loss: 0.018436 Validation loss: 38.594
# Epoch: 775 Train loss: 0.018437 Validation loss: 38.593
# Epoch: 776 Train loss: 0.018437 Validation loss: 38.592
# Epoch: 777 Train loss: 0.018437 Validation loss: 38.591
# Epoch: 778 Train loss: 0.018437 Validation loss: 38.59
# Epoch: 779 Train loss: 0.018437 Validation loss: 38.589
# Epoch: 780 Train loss: 0.018437 Validation loss: 38.588
# Epoch: 781 Train loss: 0.018437 Validation loss: 38.587
# Epoch: 782 Train loss: 0.018437 Validation loss: 38.586
# Epoch: 783 Train loss: 0.018438 Validation loss: 38.585
# Epoch: 784 Train loss: 0.018438 Validation loss: 38.585
# Epoch: 785 Train loss: 0.018438 Validation loss: 38.584
# Epoch: 786 Train loss: 0.018439 Validation loss: 38.583
# Epoch: 787 Train loss: 0.018439 Validation loss: 38.582
# Epoch: 788 Train loss: 0.018439 Validation loss: 38.581
# Epoch: 789 Train loss: 0.01844 Validation loss: 38.58
# Epoch: 790 Train loss: 0.01844 Validation loss: 38.58
# Epoch: 791 Train loss: 0.01844 Validation loss: 38.579
# Epoch: 792 Train loss: 0.018441 Validation loss: 38.578
# Epoch: 793 Train loss: 0.018441 Validation loss: 38.577
# Epoch: 794 Train loss: 0.018442 Validation loss: 38.576
# Epoch: 795 Train loss: 0.018442 Validation loss: 38.576
# Epoch: 796 Train loss: 0.018443 Validation loss: 38.575
# Epoch: 797 Train loss: 0.018444 Validation loss: 38.574
# Epoch: 798 Train loss: 0.018444 Validation loss: 38.573
# Epoch: 799 Train loss: 0.018445 Validation loss: 38.573
# Epoch: 800 Train loss: 0.018446 Validation loss: 38.572
# Epoch: 801 Train loss: 0.018446 Validation loss: 38.571
# Epoch: 802 Train loss: 0.018447 Validation loss: 38.57
# Epoch: 803 Train loss: 0.018448 Validation loss: 38.57
# Epoch: 804 Train loss: 0.018449 Validation loss: 38.569
# Epoch: 805 Train loss: 0.018449 Validation loss: 38.568
# Epoch: 806 Train loss: 0.01845 Validation loss: 38.568
# Epoch: 807 Train loss: 0.018451 Validation loss: 38.567
# Epoch: 808 Train loss: 0.018452 Validation loss: 38.566
# Epoch: 809 Train loss: 0.018453 Validation loss: 38.566
# Epoch: 810 Train loss: 0.018454 Validation loss: 38.565
# Epoch: 811 Train loss: 0.018455 Validation loss: 38.564
# Epoch: 812 Train loss: 0.018456 Validation loss: 38.564
# Epoch: 813 Train loss: 0.018457 Validation loss: 38.563
# Epoch: 814 Train loss: 0.018458 Validation loss: 38.562
# Epoch: 815 Train loss: 0.018459 Validation loss: 38.562
# Epoch: 816 Train loss: 0.01846 Validation loss: 38.561
# Epoch: 817 Train loss: 0.018461 Validation loss: 38.561
# Epoch: 818 Train loss: 0.018462 Validation loss: 38.56
# Epoch: 819 Train loss: 0.018463 Validation loss: 38.559
# Epoch: 820 Train loss: 0.018464 Validation loss: 38.559
# Epoch: 821 Train loss: 0.018465 Validation loss: 38.558
# Epoch: 822 Train loss: 0.018467 Validation loss: 38.558
# Epoch: 823 Train loss: 0.018468 Validation loss: 38.557
# Epoch: 824 Train loss: 0.018469 Validation loss: 38.556
# Epoch: 825 Train loss: 0.01847 Validation loss: 38.556
# Epoch: 826 Train loss: 0.018472 Validation loss: 38.555
# Epoch: 827 Train loss: 0.018473 Validation loss: 38.555
# Epoch: 828 Train loss: 0.018474 Validation loss: 38.554
# Epoch: 829 Train loss: 0.018476 Validation loss: 38.554
# Epoch: 830 Train loss: 0.018477 Validation loss: 38.553
# Epoch: 831 Train loss: 0.018479 Validation loss: 38.553
# Epoch: 832 Train loss: 0.01848 Validation loss: 38.552
# Epoch: 833 Train loss: 0.018481 Validation loss: 38.552
# Epoch: 834 Train loss: 0.018483 Validation loss: 38.551
# Epoch: 835 Train loss: 0.018484 Validation loss: 38.551
# Epoch: 836 Train loss: 0.018486 Validation loss: 38.55
# Epoch: 837 Train loss: 0.018488 Validation loss: 38.55
# Epoch: 838 Train loss: 0.018489 Validation loss: 38.549
# Epoch: 839 Train loss: 0.018491 Validation loss: 38.549
# Epoch: 840 Train loss: 0.018492 Validation loss: 38.548
# Epoch: 841 Train loss: 0.018494 Validation loss: 38.548
# Epoch: 842 Train loss: 0.018496 Validation loss: 38.547
# Epoch: 843 Train loss: 0.018497 Validation loss: 38.547
# Epoch: 844 Train loss: 0.018499 Validation loss: 38.546
# Epoch: 845 Train loss: 0.018501 Validation loss: 38.546
# Epoch: 846 Train loss: 0.018502 Validation loss: 38.545
# Epoch: 847 Train loss: 0.018504 Validation loss: 38.545
# Epoch: 848 Train loss: 0.018506 Validation loss: 38.544
# Epoch: 849 Train loss: 0.018508 Validation loss: 38.544
# Epoch: 850 Train loss: 0.01851 Validation loss: 38.543
# Epoch: 851 Train loss: 0.018512 Validation loss: 38.543
# Epoch: 852 Train loss: 0.018513 Validation loss: 38.543
# Epoch: 853 Train loss: 0.018515 Validation loss: 38.542
# Epoch: 854 Train loss: 0.018517 Validation loss: 38.542
# Epoch: 855 Train loss: 0.018519 Validation loss: 38.541
# Epoch: 856 Train loss: 0.018521 Validation loss: 38.541
# Epoch: 857 Train loss: 0.018523 Validation loss: 38.54
# Epoch: 858 Train loss: 0.018525 Validation loss: 38.54
# Epoch: 859 Train loss: 0.018527 Validation loss: 38.54
# Epoch: 860 Train loss: 0.018529 Validation loss: 38.539
# Epoch: 861 Train loss: 0.018531 Validation loss: 38.539
# Epoch: 862 Train loss: 0.018533 Validation loss: 38.538
# Epoch: 863 Train loss: 0.018535 Validation loss: 38.538
# Epoch: 864 Train loss: 0.018537 Validation loss: 38.538
# Epoch: 865 Train loss: 0.018539 Validation loss: 38.537
# Epoch: 866 Train loss: 0.018542 Validation loss: 38.537
# Epoch: 867 Train loss: 0.018544 Validation loss: 38.537
# Epoch: 868 Train loss: 0.018546 Validation loss: 38.536
# Epoch: 869 Train loss: 0.018548 Validation loss: 38.536
# Epoch: 870 Train loss: 0.01855 Validation loss: 38.535
# Epoch: 871 Train loss: 0.018553 Validation loss: 38.535
# Epoch: 872 Train loss: 0.018555 Validation loss: 38.535
# Epoch: 873 Train loss: 0.018557 Validation loss: 38.534
# Epoch: 874 Train loss: 0.018559 Validation loss: 38.534
# Epoch: 875 Train loss: 0.018562 Validation loss: 38.534
# Epoch: 876 Train loss: 0.018564 Validation loss: 38.533
# Epoch: 877 Train loss: 0.018566 Validation loss: 38.533
# Epoch: 878 Train loss: 0.018569 Validation loss: 38.533
# Epoch: 879 Train loss: 0.018571 Validation loss: 38.532
# Epoch: 880 Train loss: 0.018574 Validation loss: 38.532
# Epoch: 881 Train loss: 0.018576 Validation loss: 38.532
# Epoch: 882 Train loss: 0.018578 Validation loss: 38.531
# Epoch: 883 Train loss: 0.018581 Validation loss: 38.531
# Epoch: 884 Train loss: 0.018583 Validation loss: 38.531
# Epoch: 885 Train loss: 0.018586 Validation loss: 38.53
# Epoch: 886 Train loss: 0.018588 Validation loss: 38.53
# Epoch: 887 Train loss: 0.018591 Validation loss: 38.53
# Epoch: 888 Train loss: 0.018593 Validation loss: 38.529
# Epoch: 889 Train loss: 0.018596 Validation loss: 38.529
# Epoch: 890 Train loss: 0.018598 Validation loss: 38.529
# Epoch: 891 Train loss: 0.018601 Validation loss: 38.528
# Epoch: 892 Train loss: 0.018603 Validation loss: 38.528
# Epoch: 893 Train loss: 0.018606 Validation loss: 38.528
# Epoch: 894 Train loss: 0.018609 Validation loss: 38.527
# Epoch: 895 Train loss: 0.018611 Validation loss: 38.527
# Epoch: 896 Train loss: 0.018614 Validation loss: 38.527
# Epoch: 897 Train loss: 0.018616 Validation loss: 38.526
# Epoch: 898 Train loss: 0.018619 Validation loss: 38.526
# Epoch: 899 Train loss: 0.018622 Validation loss: 38.526
# Epoch: 900 Train loss: 0.018624 Validation loss: 38.525
# Epoch: 901 Train loss: 0.018627 Validation loss: 38.525
# Epoch: 902 Train loss: 0.01863 Validation loss: 38.525
# Epoch: 903 Train loss: 0.018633 Validation loss: 38.525
# Epoch: 904 Train loss: 0.018635 Validation loss: 38.524
# Epoch: 905 Train loss: 0.018638 Validation loss: 38.524
# Epoch: 906 Train loss: 0.018641 Validation loss: 38.524
# Epoch: 907 Train loss: 0.018644 Validation loss: 38.523
# Epoch: 908 Train loss: 0.018646 Validation loss: 38.523
# Epoch: 909 Train loss: 0.018649 Validation loss: 38.523
# Epoch: 910 Train loss: 0.018652 Validation loss: 38.522
# Epoch: 911 Train loss: 0.018655 Validation loss: 38.522
# Epoch: 912 Train loss: 0.018658 Validation loss: 38.522
# Epoch: 913 Train loss: 0.01866 Validation loss: 38.522
# Epoch: 914 Train loss: 0.018663 Validation loss: 38.521
# Epoch: 915 Train loss: 0.018666 Validation loss: 38.521
# Epoch: 916 Train loss: 0.018669 Validation loss: 38.521
# Epoch: 917 Train loss: 0.018672 Validation loss: 38.521
# Epoch: 918 Train loss: 0.018674 Validation loss: 38.52
# Epoch: 919 Train loss: 0.018677 Validation loss: 38.52
# Epoch: 920 Train loss: 0.01868 Validation loss: 38.52
# Epoch: 921 Train loss: 0.018683 Validation loss: 38.519
# Epoch: 922 Train loss: 0.018686 Validation loss: 38.519
# Epoch: 923 Train loss: 0.018689 Validation loss: 38.519
# Epoch: 924 Train loss: 0.018692 Validation loss: 38.519
# Epoch: 925 Train loss: 0.018695 Validation loss: 38.518
# Epoch: 926 Train loss: 0.018698 Validation loss: 38.518
# Epoch: 927 Train loss: 0.0187 Validation loss: 38.518
# Epoch: 928 Train loss: 0.018703 Validation loss: 38.517
# Epoch: 929 Train loss: 0.018706 Validation loss: 38.517
# Epoch: 930 Train loss: 0.018709 Validation loss: 38.517
# Epoch: 931 Train loss: 0.018712 Validation loss: 38.517
# Epoch: 932 Train loss: 0.018715 Validation loss: 38.516
# Epoch: 933 Train loss: 0.018718 Validation loss: 38.516
# Epoch: 934 Train loss: 0.018721 Validation loss: 38.516
# Epoch: 935 Train loss: 0.018724 Validation loss: 38.515
# Epoch: 936 Train loss: 0.018727 Validation loss: 38.515
# Epoch: 937 Train loss: 0.01873 Validation loss: 38.515
# Epoch: 938 Train loss: 0.018733 Validation loss: 38.515
# Epoch: 939 Train loss: 0.018736 Validation loss: 38.514
# Epoch: 940 Train loss: 0.018739 Validation loss: 38.514
# Epoch: 941 Train loss: 0.018742 Validation loss: 38.514
# Epoch: 942 Train loss: 0.018745 Validation loss: 38.513
# Epoch: 943 Train loss: 0.018748 Validation loss: 38.513
# Epoch: 944 Train loss: 0.018751 Validation loss: 38.513
# Epoch: 945 Train loss: 0.018754 Validation loss: 38.513
# Epoch: 946 Train loss: 0.018757 Validation loss: 38.512
# Epoch: 947 Train loss: 0.01876 Validation loss: 38.512
# Epoch: 948 Train loss: 0.018763 Validation loss: 38.512
# Epoch: 949 Train loss: 0.018766 Validation loss: 38.511
# Epoch: 950 Train loss: 0.018769 Validation loss: 38.511
# Epoch: 951 Train loss: 0.018772 Validation loss: 38.511
# Epoch: 952 Train loss: 0.018775 Validation loss: 38.51
# Epoch: 953 Train loss: 0.018778 Validation loss: 38.51
# Epoch: 954 Train loss: 0.018781 Validation loss: 38.51
# Epoch: 955 Train loss: 0.018784 Validation loss: 38.51
# Epoch: 956 Train loss: 0.018787 Validation loss: 38.509
# Epoch: 957 Train loss: 0.01879 Validation loss: 38.509
# Epoch: 958 Train loss: 0.018793 Validation loss: 38.509
# Epoch: 959 Train loss: 0.018796 Validation loss: 38.508
# Epoch: 960 Train loss: 0.018799 Validation loss: 38.508
# Epoch: 961 Train loss: 0.018802 Validation loss: 38.508
# Epoch: 962 Train loss: 0.018805 Validation loss: 38.507
# Epoch: 963 Train loss: 0.018808 Validation loss: 38.507
# Epoch: 964 Train loss: 0.018811 Validation loss: 38.507
# Epoch: 965 Train loss: 0.018814 Validation loss: 38.507
# Epoch: 966 Train loss: 0.018817 Validation loss: 38.506
# Epoch: 967 Train loss: 0.01882 Validation loss: 38.506
# Epoch: 968 Train loss: 0.018823 Validation loss: 38.506
# Epoch: 969 Train loss: 0.018826 Validation loss: 38.505
# Epoch: 970 Train loss: 0.018829 Validation loss: 38.505
# Epoch: 971 Train loss: 0.018832 Validation loss: 38.505
# Epoch: 972 Train loss: 0.018835 Validation loss: 38.504
# Epoch: 973 Train loss: 0.018838 Validation loss: 38.504
# Epoch: 974 Train loss: 0.018841 Validation loss: 38.504
# Epoch: 975 Train loss: 0.018844 Validation loss: 38.503
# Epoch: 976 Train loss: 0.018847 Validation loss: 38.503
# Epoch: 977 Train loss: 0.01885 Validation loss: 38.503
# Epoch: 978 Train loss: 0.018853 Validation loss: 38.502
# Epoch: 979 Train loss: 0.018856 Validation loss: 38.502
# Epoch: 980 Train loss: 0.018859 Validation loss: 38.502
# Epoch: 981 Train loss: 0.018861 Validation loss: 38.501
# Epoch: 982 Train loss: 0.018864 Validation loss: 38.501
# Epoch: 983 Train loss: 0.018867 Validation loss: 38.501
# Epoch: 984 Train loss: 0.01887 Validation loss: 38.5
# Epoch: 985 Train loss: 0.018873 Validation loss: 38.5
# Epoch: 986 Train loss: 0.018876 Validation loss: 38.5
# Epoch: 987 Train loss: 0.018879 Validation loss: 38.499
# Epoch: 988 Train loss: 0.018882 Validation loss: 38.499
# Epoch: 989 Train loss: 0.018885 Validation loss: 38.499
# Epoch: 990 Train loss: 0.018888 Validation loss: 38.498
# Epoch: 991 Train loss: 0.018891 Validation loss: 38.498
# Epoch: 992 Train loss: 0.018893 Validation loss: 38.498
# Epoch: 993 Train loss: 0.018896 Validation loss: 38.497
# Epoch: 994 Train loss: 0.018899 Validation loss: 38.497
# Epoch: 995 Train loss: 0.018902 Validation loss: 38.497
# Epoch: 996 Train loss: 0.018905 Validation loss: 38.496
# Epoch: 997 Train loss: 0.018908 Validation loss: 38.496
# Epoch: 998 Train loss: 0.01891 Validation loss: 38.496
# Epoch: 999 Train loss: 0.018913 Validation loss: 38.495

# %% [markdown]
# During the training of the regularized model we can already notice, that, although there is still a difference between training and validation loss, the validation loss decreases as the training loss dreases. The effect of the regularization becomes even more evident if we plot the predictions of the regularized model and the overfitting model.

# %%
""" We now want to plot the prediction of the regularized and unregularized big model. """

y_pred = big_reg_mdl(x)# Predict with "big_reg_mdl" on "x"
y_pred_overfit = big_mdl(x)# Predict with "reg_mdl" on "x"
plt.scatter(x_train_overfit, y_train_overfit)
plt.plot(x, y_true)
plt.plot(x, y_pred.numpy())
plt.plot(x, y_pred_overfit.numpy())
plt.legend(["Target", "Regularization", "No regularization", "Training samples"])
plt.show()

# %% [markdown]
# The model with regularization seems to follow the overall trend of the data, while the model without any regularization very precisely fits the training samples. This is espacilly evident in the interval $\left[0,0.5\right]$, where the prediction of the unregularized model shows an oscillating behavior. Such oscillations are however not present in the ground truth and therefore undesirable. The regularized model on the other hand is not as flexible as the unregularized model and therefore does not fit the target function well in the interval $\left[2.25, 3.0\right]$.
#
# ## Conclusion
# In this exercise we revisited the mathematical background for a simple regression task and covered it's practical implementation in Tensorflow 2. We also explored the phenomenon of overfitting and derived different regularizations from a probabilistic perspective. This exercise covers a very simple task with a very basic neural architecture and is intended as a primer for the second part of the regression exercise, which is dealing with a bigger and more realistic problem. In this second part we will consider the problem of estimating the age of a person from a potrait picture.

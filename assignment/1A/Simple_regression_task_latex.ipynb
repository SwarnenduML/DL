# %% [markdown]
# # Deep learning programming I-A: Regression
# Felix Wiewel, Institute of Signal Processing and System Theory, University of Stuttgart, 08.02.2021
# ###  Implementation
#
# In the following we consider a simple regression task, implement a neural network and train it based on the mathematical fomrulation above. For this we first need to create a set of input-output pairs, which then needs to be partitioned into a training, validation and test set. We also define some constants to be used for partitioning the data and the hyperparameters for our neural network.
#
# But before we can start, we need to import the necessary packages tensorflow, numpy and matplotlib.

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# Next we define our constants and set the random seeds of tensorflow and numpy in order to get reproducable results.

# %%
N_train_samples = 600
N_validation_samples = 100
N_test_samples = 100
N_samples = N_train_samples + N_validation_samples + N_test_samples
noise_sig = 0.1
N_epochs = 150
batch_size = 8
learning_rate = 0.01

tf.random.set_seed(0)
np.random.seed(0)

# %% [markdown]
# We create $600$ training samples, $100$ validation samples to optimize our hyperparameters and $100$ test samples, which are used to check if our model can generalize to unseen data. Furthermore we set the level of noise added to the observations. For training the model we plan to train it for $150$ epochs with a batch size of $8$ and a learning rate of $0.01$. Next we create the actual input-output pairs $\mathbf{x},\mathbf{y}$ for which we want to learn the regression model and plot them. In this simple example we choose scalar inputs as well as output but in general $\mathbf{x}$ and $\mathbf{y}$ can be vectors.

# %%
x = np.linspace(0.0, 3.0, N_samples, dtype=np.float32)
y = np.expand_dims(np.sin(1.0+x*x) + noise_sig*np.random.randn(N_samples).astype(np.float32), axis=-1)
y_true = np.sin(1.0+x*x)

plt.plot(x, y)
plt.plot(x, y_true)
plt.legend(["Observation", "Ground truth"])
plt.show()

# %% [markdown]
# With the input-output pairs created, your first task is now to partition the data in the training, validation and test sets. Keep in mind that we have created the data in a structured way, i.e. the input-output pairs are ordered. This means you need to shuffle the data before partitioning it.

# %%
""" Shuffle and partition the data set accordingly. you can use the predefined constants "N_train_samples", "N_validation_samples" and "N_test_samples". Use the variable names that are already in the below code 
to store the final shuffled and partitioned data. Hint: Shuffle the data and the labels in such a way that the pairing between an image and it's label is preserved."""
# Shuffle the data
tmp_var = np.arange(N_samples)
np.random.shuffle(tmp_var)
ind_train = tmp_var[:N_train_samples]
ind_test = tmp_var[N_train_samples:N_train_samples+N_test_samples]
ind_val = tmp_var[N_train_samples + N_test_samples:]
#print(ind_train)
# Partition the data
x_train = x[ind_train]#.reshape([1,N_train_samples,])
y_train = y[ind_train]#.reshape([1,N_train_samples,])
x_validation = x[ind_val].reshape([1,N_validation_samples])
y_validation = y[ind_val].reshape([1,N_validation_samples])
x_test = x[ind_test].reshape([1,N_test_samples])
y_test = y[ind_test].reshape([1,N_test_samples])

# %% [markdown]
# In order to feed the data to our model, we will use the Dataset class provided by Tensorflow. This class is simple to use and provides all the functionality we need for shuffling, batching and feeding the data to our model. It is also tightly integrated into the Tensorflow framework, which makes it very performant. Performance is not an aspect we need to worry about in this exercise, but it is important in more demanding applications.
#
# In this exercise we instantiate a separate Dataset object for the training, validation and test data sets, where we shuffle and repeat just the training data set. Shuffling the validation and test data sets is not necessary, since we only evaluate the loss on those data sets and do not perform SGD on it. Please fill in the missing part of the code.

# %%
""" Create three tensorflow Dataset objects that can be used to feed the training test and validation data to a neural network. Hint: For the training data set use shuffling, batching with the size according to
the predefined constant "batch_size" and repeat the data set indefinetly. For the validation and test data sets no shuffling or batching is needed."""

train_ds = tf.data.Dataset.zip((tf.data.Dataset.from_tensor_slices(x_train),tf.data.Dataset.from_tensor_slices(y_train)))
train_ds = train_ds.batch(N_train_samples//batch_size)

validation_ds = tf.data.Dataset.zip((tf.data.Dataset.from_tensor_slices(x_validation),tf.data.Dataset.from_tensor_slices(y_validation)))
test_ds = tf.data.Dataset.zip((tf.data.Dataset.from_tensor_slices(x_test),tf.data.Dataset.from_tensor_slices(y_test)))

# %% [markdown]
# In this exercise we will create a a simple neural network with two hidden layers containing $10$ neurons. For creating a model and keeping track of its weights a class called MyModel is used. When initializing an instance of this class the necessary variables are created and stored in a list called "trainable_variables". This makes it easy to get all trainable variables of the model. We also override the \__call__ method of this class in order to implement the forward pass of the neural network. This method should accept the inputs to the neural network and should return the result of the forward pass as an output. Please fill in the missing part of the code and select suitable activation functions for the different layers.

# %%
""" Implement a neural network with two hidden dense layers containing 10 neurons each. As an activation function use the tangens hyperbolicus (tf.nn.tanh()). Since we are not using Keras, we need to create and 
manage all the variables that we need ourselves. The varaibles are created in the constructor of our model class. Since we want to be able to just call the class with some inputs in order to make a prediction, 
we implement a __call__ method which computes the forward pass and returns the output of the network."""

class MyModel(object):
    def __init__(self):
        # Create model variables
        self.W0 = tf.Variable(tf.random.normal(([1,10])))
        self.b0 = tf.Variable(tf.random.normal(()))
        self.W1 = tf.Variable(tf.random.normal(([10,10])))
        self.b1 = tf.Variable(tf.random.normal(([10])))
        self.W2 = tf.Variable(tf.random.normal(([10,1])))
        self.b2 = tf.Variable(tf.random.normal(()))
        self.trainable_variables = [self.W0, self.b0, self.W1, self.b1, self.W2, self.b2]

    def __call__(self, inputs):
        # Compute forward pass
        output = tf.reshape(inputs, [-1, 1])
#        print(output.numpy().shape)
        output = tf.nn.tanh(tf.add(tf.matmul(output, self.W0), self.b0))
#        print(output.numpy().shape)
#        print(output.numpy())
        output = tf.nn.tanh(tf.add(tf.matmul(output, self.W1), self.b1))
#        print(output.numpy().shape)
#        print(output.numpy())
        output = tf.add(tf.matmul(output, self.W2), self.b2)
#        print(output.numpy().shape)
#        print(output.numpy())
        return output

# %% [markdown]
# Now after the model class is defined we can instantiate a MyModel object by running

# %%
mdl = MyModel()

# %% [markdown]
# We can now use the model to make predictions by calling it. In the following we predict on the inputs an plot the result.

# %%
""" We want to plot a prediction on the complete data set with a model before training. For this make a prediction on the variable "x". """

y_pred = mdl.__call__(x) # Compute a prediction on the variable "x"
plt.plot(x, y)
plt.plot(x, y_true)
plt.plot(x, y_pred.numpy())
plt.legend(["Observation", "Target", "Prediction"])
plt.show()

# %% [markdown]
# Since we have initialized the variables of the neural network randomly, it's prediction is also random. In order to fit the model we need to minimize the expected mean squared error over all input-ouput pairs in our training data set. For this we need to create a function, that performs a training step when provided with the model, an optimizer and a batch of input-ouput pairs.

# %%
""" For training we need to implement a function that executes one training step. Fill in the missing code pieces for this function."""

def train_step(model, optimizer, x, y):
    with tf.GradientTape() as tape:
        tape.watch(model.trainable_variables)
        y_pred = model.__call__(x) # Compute a prediction with "model" on the input "x"
        loss_val = tf.reduce_sum(tf.pow(y_pred-y, 2)) / (2 * y_pred.shape[0])# Compute the Mean Squared Error (MSE) for the prediction "y_pred" and the targets "y"
    grads = tape.gradient(loss_val, model.trainable_variables)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))
    return loss_val

# %% [markdown]
# This function uses the GradientTape to record the operations for which gradients have to be calculated. In our case this is the forward pass through our model and the computation of the loss function. After these operations are recoded we can get their gradients and apply these through the use of an optimizer. Finally we return the loss value in order to print it.
#
# With the training step function defined we now need to choose a suitable optimizer. Tensorflow offers a wide variety of optimizers but in this exercise we will use the RMSprop optimizer.

# %%
opt = tf.optimizers.RMSprop(learning_rate)

# %% [markdown]
# We now have everything we need to start training the model. For this we repeatedly sample a batch of input-output pairs from our training data set and use the train_step function to minimize the loss function over this batch. We repeat this until we have iterated over the complete training data set once. After this we compute the loss on the validation data set, print it and repeat with another epoch until we have reached $N\_epochs$ epochs.

# %%
for x_t, y_t in test_ds:
    y_pred = mdl.__call__(x_t) # Compute a prediction with "mdl" on the input "x_v"
    test_loss = tf.reduce_sum(tf.pow(y_pred-y_t, 2)) / (2 * y_pred.shape[0])
print("Test loss: {:.5}".format(test_loss))
# Out:
# Test loss: 1220.0

# %%
""" We can now use the train_step function to perform the training. Fill in the missing code parts."""

epoch = 0
train_iters = 0
train_loss = 0.0
while True:
    for x_t, y_t in train_ds:
      train_loss += train_step(mdl,opt,x_t,y_t)# Perform a training step with the model "mdl" and the optimizer "opt" on the inputs "x_t" and the corresponding targets "y_t"
      train_iters += 1
#    print(train_iters)
    if train_iters == batch_size:# An epoch is completed
        for x_v, y_v in validation_ds:
            y_pred = mdl.__call__(x_v) # Compute a prediction with "mdl" on the input "x_v"
            validation_loss = tf.reduce_sum(tf.pow(y_pred-y_v, 2)) / (2 * y_pred.shape[0])# Compute the Mean Squared Error (MSE) for the prediction "y_pred" and the targets "y_v"
        print("Epoch: {} Train loss: {:.5} Validation loss: {:.5}".format(epoch, train_loss/train_iters, validation_loss))
        train_iters = 0
        train_loss = 0.0
        epoch += 1
    if (epoch == N_epochs):
        break
# Out:
# Epoch: 0 Train loss: 3.5141 Validation loss: 43.277
# Epoch: 1 Train loss: 0.33401 Validation loss: 25.334
# Epoch: 2 Train loss: 0.19177 Validation loss: 27.603
# Epoch: 3 Train loss: 0.15936 Validation loss: 30.211
# Epoch: 4 Train loss: 0.14018 Validation loss: 31.705
# Epoch: 5 Train loss: 0.13658 Validation loss: 31.544
# Epoch: 6 Train loss: 0.1339 Validation loss: 32.049
# Epoch: 7 Train loss: 0.1297 Validation loss: 32.539
# Epoch: 8 Train loss: 0.12516 Validation loss: 33.022
# Epoch: 9 Train loss: 0.12049 Validation loss: 33.446
# Epoch: 10 Train loss: 0.11602 Validation loss: 33.824
# Epoch: 11 Train loss: 0.11184 Validation loss: 34.177
# Epoch: 12 Train loss: 0.10794 Validation loss: 34.517
# Epoch: 13 Train loss: 0.1043 Validation loss: 34.848
# Epoch: 14 Train loss: 0.10088 Validation loss: 35.17
# Epoch: 15 Train loss: 0.097648 Validation loss: 35.479
# Epoch: 16 Train loss: 0.094587 Validation loss: 35.771
# Epoch: 17 Train loss: 0.091671 Validation loss: 36.043
# Epoch: 18 Train loss: 0.088878 Validation loss: 36.293
# Epoch: 19 Train loss: 0.086194 Validation loss: 36.52
# Epoch: 20 Train loss: 0.083608 Validation loss: 36.723
# Epoch: 21 Train loss: 0.081111 Validation loss: 36.905
# Epoch: 22 Train loss: 0.078699 Validation loss: 37.068
# Epoch: 23 Train loss: 0.076368 Validation loss: 37.215
# Epoch: 24 Train loss: 0.074118 Validation loss: 37.35
# Epoch: 25 Train loss: 0.071947 Validation loss: 37.475
# Epoch: 26 Train loss: 0.069855 Validation loss: 37.592
# Epoch: 27 Train loss: 0.067843 Validation loss: 37.706
# Epoch: 28 Train loss: 0.06591 Validation loss: 37.815
# Epoch: 29 Train loss: 0.064059 Validation loss: 37.923
# Epoch: 30 Train loss: 0.062289 Validation loss: 38.031
# Epoch: 31 Train loss: 0.060602 Validation loss: 38.14
# Epoch: 32 Train loss: 0.058998 Validation loss: 38.251
# Epoch: 33 Train loss: 0.057476 Validation loss: 38.36
# Epoch: 34 Train loss: 0.056039 Validation loss: 38.46
# Epoch: 35 Train loss: 0.054682 Validation loss: 38.544
# Epoch: 36 Train loss: 0.053392 Validation loss: 38.609
# Epoch: 37 Train loss: 0.052149 Validation loss: 38.655
# Epoch: 38 Train loss: 0.050921 Validation loss: 38.682
# Epoch: 39 Train loss: 0.049678 Validation loss: 38.684
# Epoch: 40 Train loss: 0.048328 Validation loss: 38.645
# Epoch: 41 Train loss: 0.046838 Validation loss: 38.58
# Epoch: 42 Train loss: 0.045137 Validation loss: 38.511
# Epoch: 43 Train loss: 0.043493 Validation loss: 38.496
# Epoch: 44 Train loss: 0.041673 Validation loss: 38.473
# Epoch: 45 Train loss: 0.040383 Validation loss: 38.552
# Epoch: 46 Train loss: 0.038258 Validation loss: 38.492
# Epoch: 47 Train loss: 0.038092 Validation loss: 38.746
# Epoch: 48 Train loss: 0.034151 Validation loss: 38.451
# Epoch: 49 Train loss: 0.037748 Validation loss: 39.113
# Epoch: 50 Train loss: 0.028328 Validation loss: 38.897
# Epoch: 51 Train loss: 0.03849 Validation loss: 39.145
# Epoch: 52 Train loss: 0.026033 Validation loss: 39.531
# Epoch: 53 Train loss: 0.03406 Validation loss: 42.08
# Epoch: 54 Train loss: 0.029178 Validation loss: 39.617
# Epoch: 55 Train loss: 0.027639 Validation loss: 41.4
# Epoch: 56 Train loss: 0.03 Validation loss: 39.861
# Epoch: 57 Train loss: 0.026784 Validation loss: 40.886
# Epoch: 58 Train loss: 0.027908 Validation loss: 40.069
# Epoch: 59 Train loss: 0.025897 Validation loss: 40.716
# Epoch: 60 Train loss: 0.026315 Validation loss: 40.229
# Epoch: 61 Train loss: 0.024934 Validation loss: 40.657
# Epoch: 62 Train loss: 0.025039 Validation loss: 40.363
# Epoch: 63 Train loss: 0.024008 Validation loss: 40.652
# Epoch: 64 Train loss: 0.023954 Validation loss: 40.482
# Epoch: 65 Train loss: 0.023152 Validation loss: 40.679
# Epoch: 66 Train loss: 0.023006 Validation loss: 40.591
# Epoch: 67 Train loss: 0.022369 Validation loss: 40.728
# Epoch: 68 Train loss: 0.022168 Validation loss: 40.693
# Epoch: 69 Train loss: 0.021651 Validation loss: 40.791
# Epoch: 70 Train loss: 0.02142 Validation loss: 40.791
# Epoch: 71 Train loss: 0.020993 Validation loss: 40.864
# Epoch: 72 Train loss: 0.020748 Validation loss: 40.886
# Epoch: 73 Train loss: 0.020388 Validation loss: 40.945
# Epoch: 74 Train loss: 0.020141 Validation loss: 40.979
# Epoch: 75 Train loss: 0.019833 Validation loss: 41.031
# Epoch: 76 Train loss: 0.01959 Validation loss: 41.072
# Epoch: 77 Train loss: 0.019321 Validation loss: 41.121
# Epoch: 78 Train loss: 0.019089 Validation loss: 41.166
# Epoch: 79 Train loss: 0.018849 Validation loss: 41.213
# Epoch: 80 Train loss: 0.01863 Validation loss: 41.26
# Epoch: 81 Train loss: 0.018414 Validation loss: 41.306
# Epoch: 82 Train loss: 0.018209 Validation loss: 41.354
# Epoch: 83 Train loss: 0.018012 Validation loss: 41.401
# Epoch: 84 Train loss: 0.017823 Validation loss: 41.448
# Epoch: 85 Train loss: 0.017642 Validation loss: 41.494
# Epoch: 86 Train loss: 0.017467 Validation loss: 41.541
# Epoch: 87 Train loss: 0.0173 Validation loss: 41.586
# Epoch: 88 Train loss: 0.017139 Validation loss: 41.631
# Epoch: 89 Train loss: 0.016985 Validation loss: 41.676
# Epoch: 90 Train loss: 0.016837 Validation loss: 41.719
# Epoch: 91 Train loss: 0.016695 Validation loss: 41.761
# Epoch: 92 Train loss: 0.016558 Validation loss: 41.802
# Epoch: 93 Train loss: 0.016426 Validation loss: 41.842
# Epoch: 94 Train loss: 0.016299 Validation loss: 41.881
# Epoch: 95 Train loss: 0.016175 Validation loss: 41.918
# Epoch: 96 Train loss: 0.016055 Validation loss: 41.955
# Epoch: 97 Train loss: 0.015937 Validation loss: 41.991
# Epoch: 98 Train loss: 0.015823 Validation loss: 42.026
# Epoch: 99 Train loss: 0.015711 Validation loss: 42.061
# Epoch: 100 Train loss: 0.015601 Validation loss: 42.095
# Epoch: 101 Train loss: 0.015493 Validation loss: 42.129
# Epoch: 102 Train loss: 0.015388 Validation loss: 42.162
# Epoch: 103 Train loss: 0.015284 Validation loss: 42.195
# Epoch: 104 Train loss: 0.015181 Validation loss: 42.227
# Epoch: 105 Train loss: 0.01508 Validation loss: 42.259
# Epoch: 106 Train loss: 0.014982 Validation loss: 42.291
# Epoch: 107 Train loss: 0.014884 Validation loss: 42.322
# Epoch: 108 Train loss: 0.014789 Validation loss: 42.353
# Epoch: 109 Train loss: 0.014695 Validation loss: 42.384
# Epoch: 110 Train loss: 0.014603 Validation loss: 42.415
# Epoch: 111 Train loss: 0.014512 Validation loss: 42.445
# Epoch: 112 Train loss: 0.014422 Validation loss: 42.476
# Epoch: 113 Train loss: 0.014332 Validation loss: 42.505
# Epoch: 114 Train loss: 0.014241 Validation loss: 42.535
# Epoch: 115 Train loss: 0.014147 Validation loss: 42.564
# Epoch: 116 Train loss: 0.014043 Validation loss: 42.59
# Epoch: 117 Train loss: 0.013915 Validation loss: 42.61
# Epoch: 118 Train loss: 0.013714 Validation loss: 42.575
# Epoch: 119 Train loss: 0.014469 Validation loss: 41.781
# Epoch: 120 Train loss: 0.018898 Validation loss: 42.004
# Epoch: 121 Train loss: 0.010884 Validation loss: 42.879
# Epoch: 122 Train loss: 0.012772 Validation loss: 43.547
# Epoch: 123 Train loss: 0.015031 Validation loss: 42.546
# Epoch: 124 Train loss: 0.012979 Validation loss: 42.127
# Epoch: 125 Train loss: 0.016147 Validation loss: 41.861
# Epoch: 126 Train loss: 0.013873 Validation loss: 42.561
# Epoch: 127 Train loss: 0.010776 Validation loss: 43.155
# Epoch: 128 Train loss: 0.014656 Validation loss: 43.588
# Epoch: 129 Train loss: 0.013763 Validation loss: 42.525
# Epoch: 130 Train loss: 0.014866 Validation loss: 42.134
# Epoch: 131 Train loss: 0.014372 Validation loss: 42.324
# Epoch: 132 Train loss: 0.0112 Validation loss: 42.964
# Epoch: 133 Train loss: 0.012334 Validation loss: 44.755
# Epoch: 134 Train loss: 0.015503 Validation loss: 42.51
# Epoch: 135 Train loss: 0.014767 Validation loss: 42.278
# Epoch: 136 Train loss: 0.012003 Validation loss: 42.355
# Epoch: 137 Train loss: 0.014359 Validation loss: 42.547
# Epoch: 138 Train loss: 0.010538 Validation loss: 43.305
# Epoch: 139 Train loss: 0.013628 Validation loss: 44.275
# Epoch: 140 Train loss: 0.013939 Validation loss: 42.598
# Epoch: 141 Train loss: 0.015607 Validation loss: 42.259
# Epoch: 142 Train loss: 0.011324 Validation loss: 42.6
# Epoch: 143 Train loss: 0.012134 Validation loss: 42.48
# Epoch: 144 Train loss: 0.015525 Validation loss: 42.718
# Epoch: 145 Train loss: 0.010373 Validation loss: 43.559
# Epoch: 146 Train loss: 0.012516 Validation loss: 43.452
# Epoch: 147 Train loss: 0.012912 Validation loss: 42.942
# Epoch: 148 Train loss: 0.015462 Validation loss: 42.295
# Epoch: 149 Train loss: 0.012382 Validation loss: 42.585

# %% [markdown]
# After completion of the training process we use the test data set to test the models generalization to unseen data.

# %%
for x_t, y_t in test_ds:
    y_pred = mdl.__call__(x_t) # Compute a prediction with "mdl" on the input "x_v"
    test_loss = tf.reduce_sum(tf.pow(y_pred-y_t, 2)) / (2 * y_pred.shape[0])
print("Test loss: {:.5}".format(test_loss))
# Out:
# Test loss: 45.519

# %% [markdown]
# After we have verified that our model achieves a similar loss on the test as on the validation and training data set, we can conclude that our model is not overfitting or underfitting and generalizes to unseen data. We can now predict on the inputs again and plot the results.

# %%
""" Now we want to plot the prediction after training. Predict on the variable "x" again. """

y_pred = mdl.__call__(x)# Compute a prediction on the variable "x"
plt.plot(x, y)
plt.plot(x, y_true)
plt.plot(x, y_pred.numpy())
plt.legend(["Observation", "Target", "Prediction"])
plt.show()

# %% [markdown]
# Now our model has learned to approximate the function mapping from the input to the output. The capability of neural networks to learn from input-ouput pairs alone and approximate an arbitrary function, see universal approximation theorem, can be very useful if the mapping between the input and output is too complex to be captured with model based approaches. But learning from input-ouput pairs alone implies that the model will only be able to make accurate predictions over input ranges it has seen during training. In order to demonstrate this we will predict on an interval that exeeds the $\left[0,3\right]$ interval the model was trained on, i.e. we will predict on the interval $\left[-2,5\right]$.

# %%
x_generalize = np.linspace(-2.0, 5.0, N_samples, dtype=np.float32)
y_generalize = np.sin(1.0+x_generalize*x_generalize) + noise_sig*np.random.randn(N_samples).astype(np.float32)
y_truey_generalize = np.sin(1.0+x_generalize*x_generalize)
y_pred = mdl(x_generalize)
plt.plot(x_generalize, y_generalize)
plt.plot(x_generalize, y_truey_generalize)
plt.plot(x_generalize, y_pred.numpy())
plt.legend(["Observation", "Target", "Prediction"])
plt.show()

# %% [markdown]
# As expected, the model is able to make farely accurate predictions on the interval it was trained on but makes unreliable predictions outside this interval.
#
# ### Regularization
# With the theoretical background on regularization we can now implement it and observe it's effects on the regression problem covered in this exercise. For this we will define a model with a high capacity and train it for a extended time to provoke overfitting. For this, we will increase the number of hidden neurons in both hidden layers to $100$ and $50$.

# %%
""" Implement a bigger model with again two hidden layers contatining 100 and 50 neurons. As an activation use the tangens hyperbolicus function where it is appropiate. """

class MyBigModel(object):
    def __init__(self):
        # Create model variables
        self.W0 = tf.Variable(tf.random.normal(([1,100])))
        self.b0 = tf.Variable(tf.random.normal(()))
        self.W1 = tf.Variable(tf.random.normal(([100,50])))
        self.b1 = tf.Variable(tf.random.normal(([50])))
        self.W2 = tf.Variable(tf.random.normal(([50,1])))
        self.b2 = tf.Variable(tf.random.normal(()))
        self.trainable_variables = [self.W0, self.b0, self.W1, self.b1, self.W2, self.b2]

    def __call__(self, inputs):
        # Compute forward pass
        output = tf.reshape(inputs, [-1, 1])
        output = tf.nn.tanh(tf.add(tf.matmul(output, self.W0), self.b0))
        output = tf.nn.tanh(tf.add(tf.matmul(output, self.W1), self.b1))
        output = tf.add(tf.matmul(output, self.W2), self.b2)
        # self.W0 = self.W0 - 0.01*self.W0
        # self.b0 = self.b0 - 0.01*self.b0
        # self.W1 = self.W1 - 0.01*self.W1
        # self.b1 = self.b1 - 0.01*self.b1
        # self.W2 = self.W2 - 0.01*self.W2
        # self.b2 = self.b2 - 0.01*self.b2
        return output

# %% [markdown]
# After creating one instance of this class we can again train it on our data set. We will also create a new optimizer for training this bigger model, since some optimizers adapt the learning rates for individual parameters during a training process and we do not want to train our bigger model with learning rates adopted from an earlier training run.

# %%
big_mdl = MyBigModel()
big_opt = tf.optimizers.SGD(0.001)

# %% [markdown]
# Now we are ready to train this bigger model using the same training step and training loop. In order to provoke overfitting we also reduce the number of samples in the training data set a lot, increase the batch size and train for a more epochs.

# %%
""" Implement the training for the bigger model similar to the training of the small model before. """

N_train_samples_overfit = 30
N_epochs = 1000
batch_size = 30

sel_idx = np.arange(0, N_train_samples)
sel_idx = np.random.choice(sel_idx, N_train_samples_overfit)
x_train_overfit = x_train[sel_idx]
y_train_overfit = y_train[sel_idx]
print(type(x_train_overfit))

train_overfit_ds = tf.data.Dataset.from_tensor_slices((x_train_overfit, y_train_overfit)).shuffle(N_train_samples_overfit).batch(batch_size).repeat()

epoch = 0
train_iters = 0
train_loss = 0.0
for x_t, y_t in train_overfit_ds:
    # print(x_t.shape)
    train_loss += train_step(big_mdl,big_opt,x_t,y_t)# Perform a training step with the model "big_mdl" and the optimizer "big_opt" on the inputs "x_t" and the corresponding targets "y_t"
    train_iters += 1
    if train_iters == batch_size:# An epoch is completed
        for x_v, y_v in validation_ds:
            y_pred = big_mdl(x_v)# Compute a prediction with "big_mdl" on the input "x_v"
            validation_loss = tf.reduce_sum(tf.pow(y_pred-y_v, 2)) / (2 * y_pred.shape[0])# Compute the Mean Squared Error (MSE) for the prediction "y_pred" and the targets "y_v"
        print("Epoch: {} Train loss: {:.5} Validation loss: {:.5}".format(epoch, train_loss/train_iters, validation_loss))
        train_iters = 0
        train_loss = 0.0
        epoch += 1
    if (epoch == N_epochs):
        break
# Out:
# <class 'numpy.ndarray'>
# Epoch: 0 Train loss: 4.2862 Validation loss: 132.3
# Epoch: 1 Train loss: 1.1578 Validation loss: 62.697
# Epoch: 2 Train loss: 0.48865 Validation loss: 45.8
# Epoch: 3 Train loss: 0.26428 Validation loss: 41.669
# Epoch: 4 Train loss: 0.1659 Validation loss: 41.157
# Epoch: 5 Train loss: 0.11162 Validation loss: 41.682
# Epoch: 6 Train loss: 0.079106 Validation loss: 42.322
# Epoch: 7 Train loss: 0.059958 Validation loss: 42.812
# Epoch: 8 Train loss: 0.048388 Validation loss: 43.153
# Epoch: 9 Train loss: 0.040878 Validation loss: 43.403
# Epoch: 10 Train loss: 0.035674 Validation loss: 43.606
# Epoch: 11 Train loss: 0.031899 Validation loss: 43.786
# Epoch: 12 Train loss: 0.029073 Validation loss: 43.955
# Epoch: 13 Train loss: 0.026907 Validation loss: 44.117
# Epoch: 14 Train loss: 0.025215 Validation loss: 44.275
# Epoch: 15 Train loss: 0.023873 Validation loss: 44.429
# Epoch: 16 Train loss: 0.022794 Validation loss: 44.577
# Epoch: 17 Train loss: 0.021915 Validation loss: 44.721
# Epoch: 18 Train loss: 0.021193 Validation loss: 44.859
# Epoch: 19 Train loss: 0.020592 Validation loss: 44.992
# Epoch: 20 Train loss: 0.020089 Validation loss: 45.118
# Epoch: 21 Train loss: 0.019662 Validation loss: 45.238
# Epoch: 22 Train loss: 0.019298 Validation loss: 45.352
# Epoch: 23 Train loss: 0.018984 Validation loss: 45.459
# Epoch: 24 Train loss: 0.018712 Validation loss: 45.56
# Epoch: 25 Train loss: 0.018473 Validation loss: 45.655
# Epoch: 26 Train loss: 0.018263 Validation loss: 45.744
# Epoch: 27 Train loss: 0.018076 Validation loss: 45.828
# Epoch: 28 Train loss: 0.017908 Validation loss: 45.906
# Epoch: 29 Train loss: 0.017758 Validation loss: 45.979
# Epoch: 30 Train loss: 0.017621 Validation loss: 46.047
# Epoch: 31 Train loss: 0.017497 Validation loss: 46.11
# Epoch: 32 Train loss: 0.017383 Validation loss: 46.169
# Epoch: 33 Train loss: 0.017278 Validation loss: 46.223
# Epoch: 34 Train loss: 0.017181 Validation loss: 46.273
# Epoch: 35 Train loss: 0.017091 Validation loss: 46.32
# Epoch: 36 Train loss: 0.017007 Validation loss: 46.362
# Epoch: 37 Train loss: 0.016929 Validation loss: 46.402
# Epoch: 38 Train loss: 0.016856 Validation loss: 46.438
# Epoch: 39 Train loss: 0.016786 Validation loss: 46.471
# Epoch: 40 Train loss: 0.016721 Validation loss: 46.5
# Epoch: 41 Train loss: 0.016659 Validation loss: 46.527
# Epoch: 42 Train loss: 0.016601 Validation loss: 46.552
# Epoch: 43 Train loss: 0.016545 Validation loss: 46.574
# Epoch: 44 Train loss: 0.016491 Validation loss: 46.594
# Epoch: 45 Train loss: 0.01644 Validation loss: 46.612
# Epoch: 46 Train loss: 0.016392 Validation loss: 46.628
# Epoch: 47 Train loss: 0.016345 Validation loss: 46.642
# Epoch: 48 Train loss: 0.0163 Validation loss: 46.654
# Epoch: 49 Train loss: 0.016256 Validation loss: 46.665
# Epoch: 50 Train loss: 0.016214 Validation loss: 46.674
# Epoch: 51 Train loss: 0.016174 Validation loss: 46.682
# Epoch: 52 Train loss: 0.016134 Validation loss: 46.689
# Epoch: 53 Train loss: 0.016096 Validation loss: 46.694
# Epoch: 54 Train loss: 0.016059 Validation loss: 46.698
# Epoch: 55 Train loss: 0.016023 Validation loss: 46.701
# Epoch: 56 Train loss: 0.015988 Validation loss: 46.703
# Epoch: 57 Train loss: 0.015953 Validation loss: 46.704
# Epoch: 58 Train loss: 0.01592 Validation loss: 46.705
# Epoch: 59 Train loss: 0.015887 Validation loss: 46.705
# Epoch: 60 Train loss: 0.015855 Validation loss: 46.704
# Epoch: 61 Train loss: 0.015823 Validation loss: 46.702
# Epoch: 62 Train loss: 0.015792 Validation loss: 46.699
# Epoch: 63 Train loss: 0.015762 Validation loss: 46.696
# Epoch: 64 Train loss: 0.015732 Validation loss: 46.693
# Epoch: 65 Train loss: 0.015703 Validation loss: 46.689
# Epoch: 66 Train loss: 0.015674 Validation loss: 46.685
# Epoch: 67 Train loss: 0.015645 Validation loss: 46.68
# Epoch: 68 Train loss: 0.015617 Validation loss: 46.675
# Epoch: 69 Train loss: 0.01559 Validation loss: 46.669
# Epoch: 70 Train loss: 0.015563 Validation loss: 46.663
# Epoch: 71 Train loss: 0.015536 Validation loss: 46.657
# Epoch: 72 Train loss: 0.015509 Validation loss: 46.65
# Epoch: 73 Train loss: 0.015483 Validation loss: 46.643
# Epoch: 74 Train loss: 0.015458 Validation loss: 46.636
# Epoch: 75 Train loss: 0.015432 Validation loss: 46.629
# Epoch: 76 Train loss: 0.015407 Validation loss: 46.621
# Epoch: 77 Train loss: 0.015382 Validation loss: 46.613
# Epoch: 78 Train loss: 0.015357 Validation loss: 46.606
# Epoch: 79 Train loss: 0.015333 Validation loss: 46.598
# Epoch: 80 Train loss: 0.015309 Validation loss: 46.59
# Epoch: 81 Train loss: 0.015285 Validation loss: 46.582
# Epoch: 82 Train loss: 0.015261 Validation loss: 46.574
# Epoch: 83 Train loss: 0.015238 Validation loss: 46.566
# Epoch: 84 Train loss: 0.015215 Validation loss: 46.557
# Epoch: 85 Train loss: 0.015192 Validation loss: 46.549
# Epoch: 86 Train loss: 0.015169 Validation loss: 46.54
# Epoch: 87 Train loss: 0.015147 Validation loss: 46.531
# Epoch: 88 Train loss: 0.015124 Validation loss: 46.523
# Epoch: 89 Train loss: 0.015102 Validation loss: 46.514
# Epoch: 90 Train loss: 0.01508 Validation loss: 46.505
# Epoch: 91 Train loss: 0.015059 Validation loss: 46.496
# Epoch: 92 Train loss: 0.015037 Validation loss: 46.487
# Epoch: 93 Train loss: 0.015016 Validation loss: 46.479
# Epoch: 94 Train loss: 0.014995 Validation loss: 46.47
# Epoch: 95 Train loss: 0.014974 Validation loss: 46.461
# Epoch: 96 Train loss: 0.014953 Validation loss: 46.452
# Epoch: 97 Train loss: 0.014932 Validation loss: 46.443
# Epoch: 98 Train loss: 0.014911 Validation loss: 46.434
# Epoch: 99 Train loss: 0.014891 Validation loss: 46.425
# Epoch: 100 Train loss: 0.014871 Validation loss: 46.417
# Epoch: 101 Train loss: 0.014851 Validation loss: 46.408
# Epoch: 102 Train loss: 0.014831 Validation loss: 46.399
# Epoch: 103 Train loss: 0.014811 Validation loss: 46.39
# Epoch: 104 Train loss: 0.014791 Validation loss: 46.381
# Epoch: 105 Train loss: 0.014772 Validation loss: 46.373
# Epoch: 106 Train loss: 0.014752 Validation loss: 46.364
# Epoch: 107 Train loss: 0.014733 Validation loss: 46.355
# Epoch: 108 Train loss: 0.014714 Validation loss: 46.347
# Epoch: 109 Train loss: 0.014695 Validation loss: 46.338
# Epoch: 110 Train loss: 0.014676 Validation loss: 46.33
# Epoch: 111 Train loss: 0.014657 Validation loss: 46.321
# Epoch: 112 Train loss: 0.014638 Validation loss: 46.313
# Epoch: 113 Train loss: 0.01462 Validation loss: 46.304
# Epoch: 114 Train loss: 0.014601 Validation loss: 46.296
# Epoch: 115 Train loss: 0.014583 Validation loss: 46.287
# Epoch: 116 Train loss: 0.014565 Validation loss: 46.279
# Epoch: 117 Train loss: 0.014547 Validation loss: 46.271
# Epoch: 118 Train loss: 0.014529 Validation loss: 46.263
# Epoch: 119 Train loss: 0.014511 Validation loss: 46.255
# Epoch: 120 Train loss: 0.014493 Validation loss: 46.246
# Epoch: 121 Train loss: 0.014476 Validation loss: 46.238
# Epoch: 122 Train loss: 0.014458 Validation loss: 46.23
# Epoch: 123 Train loss: 0.014441 Validation loss: 46.222
# Epoch: 124 Train loss: 0.014423 Validation loss: 46.214
# Epoch: 125 Train loss: 0.014406 Validation loss: 46.206
# Epoch: 126 Train loss: 0.014389 Validation loss: 46.198
# Epoch: 127 Train loss: 0.014372 Validation loss: 46.191
# Epoch: 128 Train loss: 0.014355 Validation loss: 46.183
# Epoch: 129 Train loss: 0.014338 Validation loss: 46.175
# Epoch: 130 Train loss: 0.014321 Validation loss: 46.168
# Epoch: 131 Train loss: 0.014305 Validation loss: 46.16
# Epoch: 132 Train loss: 0.014288 Validation loss: 46.153
# Epoch: 133 Train loss: 0.014272 Validation loss: 46.145
# Epoch: 134 Train loss: 0.014255 Validation loss: 46.137
# Epoch: 135 Train loss: 0.014239 Validation loss: 46.13
# Epoch: 136 Train loss: 0.014223 Validation loss: 46.123
# Epoch: 137 Train loss: 0.014206 Validation loss: 46.116
# Epoch: 138 Train loss: 0.01419 Validation loss: 46.108
# Epoch: 139 Train loss: 0.014174 Validation loss: 46.101
# Epoch: 140 Train loss: 0.014159 Validation loss: 46.094
# Epoch: 141 Train loss: 0.014143 Validation loss: 46.087
# Epoch: 142 Train loss: 0.014127 Validation loss: 46.08
# Epoch: 143 Train loss: 0.014111 Validation loss: 46.073
# Epoch: 144 Train loss: 0.014096 Validation loss: 46.066
# Epoch: 145 Train loss: 0.01408 Validation loss: 46.059
# Epoch: 146 Train loss: 0.014065 Validation loss: 46.052
# Epoch: 147 Train loss: 0.01405 Validation loss: 46.045
# Epoch: 148 Train loss: 0.014034 Validation loss: 46.038
# Epoch: 149 Train loss: 0.014019 Validation loss: 46.031
# Epoch: 150 Train loss: 0.014004 Validation loss: 46.025
# Epoch: 151 Train loss: 0.013989 Validation loss: 46.018
# Epoch: 152 Train loss: 0.013974 Validation loss: 46.011
# Epoch: 153 Train loss: 0.013959 Validation loss: 46.005
# Epoch: 154 Train loss: 0.013944 Validation loss: 45.998
# Epoch: 155 Train loss: 0.013929 Validation loss: 45.992
# Epoch: 156 Train loss: 0.013915 Validation loss: 45.985
# Epoch: 157 Train loss: 0.0139 Validation loss: 45.979
# Epoch: 158 Train loss: 0.013885 Validation loss: 45.972
# Epoch: 159 Train loss: 0.013871 Validation loss: 45.966
# Epoch: 160 Train loss: 0.013857 Validation loss: 45.959
# Epoch: 161 Train loss: 0.013842 Validation loss: 45.953
# Epoch: 162 Train loss: 0.013828 Validation loss: 45.946
# Epoch: 163 Train loss: 0.013814 Validation loss: 45.94
# Epoch: 164 Train loss: 0.013799 Validation loss: 45.934
# Epoch: 165 Train loss: 0.013785 Validation loss: 45.928
# Epoch: 166 Train loss: 0.013771 Validation loss: 45.922
# Epoch: 167 Train loss: 0.013757 Validation loss: 45.916
# Epoch: 168 Train loss: 0.013743 Validation loss: 45.91
# Epoch: 169 Train loss: 0.013729 Validation loss: 45.904
# Epoch: 170 Train loss: 0.013716 Validation loss: 45.898
# Epoch: 171 Train loss: 0.013702 Validation loss: 45.892
# Epoch: 172 Train loss: 0.013688 Validation loss: 45.886
# Epoch: 173 Train loss: 0.013674 Validation loss: 45.88
# Epoch: 174 Train loss: 0.013661 Validation loss: 45.874
# Epoch: 175 Train loss: 0.013647 Validation loss: 45.868
# Epoch: 176 Train loss: 0.013634 Validation loss: 45.862
# Epoch: 177 Train loss: 0.01362 Validation loss: 45.856
# Epoch: 178 Train loss: 0.013607 Validation loss: 45.851
# Epoch: 179 Train loss: 0.013594 Validation loss: 45.845
# Epoch: 180 Train loss: 0.013581 Validation loss: 45.839
# Epoch: 181 Train loss: 0.013567 Validation loss: 45.833
# Epoch: 182 Train loss: 0.013554 Validation loss: 45.828
# Epoch: 183 Train loss: 0.013541 Validation loss: 45.822
# Epoch: 184 Train loss: 0.013528 Validation loss: 45.816
# Epoch: 185 Train loss: 0.013515 Validation loss: 45.811
# Epoch: 186 Train loss: 0.013502 Validation loss: 45.805
# Epoch: 187 Train loss: 0.013489 Validation loss: 45.8
# Epoch: 188 Train loss: 0.013477 Validation loss: 45.794
# Epoch: 189 Train loss: 0.013464 Validation loss: 45.789
# Epoch: 190 Train loss: 0.013451 Validation loss: 45.783
# Epoch: 191 Train loss: 0.013438 Validation loss: 45.778
# Epoch: 192 Train loss: 0.013426 Validation loss: 45.773
# Epoch: 193 Train loss: 0.013413 Validation loss: 45.767
# Epoch: 194 Train loss: 0.013401 Validation loss: 45.762
# Epoch: 195 Train loss: 0.013388 Validation loss: 45.757
# Epoch: 196 Train loss: 0.013376 Validation loss: 45.751
# Epoch: 197 Train loss: 0.013364 Validation loss: 45.746
# Epoch: 198 Train loss: 0.013351 Validation loss: 45.741
# Epoch: 199 Train loss: 0.013339 Validation loss: 45.736
# Epoch: 200 Train loss: 0.013327 Validation loss: 45.731
# Epoch: 201 Train loss: 0.013315 Validation loss: 45.725
# Epoch: 202 Train loss: 0.013303 Validation loss: 45.72
# Epoch: 203 Train loss: 0.01329 Validation loss: 45.715
# Epoch: 204 Train loss: 0.013278 Validation loss: 45.71
# Epoch: 205 Train loss: 0.013266 Validation loss: 45.705
# Epoch: 206 Train loss: 0.013255 Validation loss: 45.7
# Epoch: 207 Train loss: 0.013243 Validation loss: 45.695
# Epoch: 208 Train loss: 0.013231 Validation loss: 45.69
# Epoch: 209 Train loss: 0.013219 Validation loss: 45.685
# Epoch: 210 Train loss: 0.013207 Validation loss: 45.68
# Epoch: 211 Train loss: 0.013196 Validation loss: 45.675
# Epoch: 212 Train loss: 0.013184 Validation loss: 45.67
# Epoch: 213 Train loss: 0.013172 Validation loss: 45.666
# Epoch: 214 Train loss: 0.013161 Validation loss: 45.661
# Epoch: 215 Train loss: 0.013149 Validation loss: 45.656
# Epoch: 216 Train loss: 0.013138 Validation loss: 45.651
# Epoch: 217 Train loss: 0.013126 Validation loss: 45.647
# Epoch: 218 Train loss: 0.013115 Validation loss: 45.642
# Epoch: 219 Train loss: 0.013104 Validation loss: 45.637
# Epoch: 220 Train loss: 0.013092 Validation loss: 45.632
# Epoch: 221 Train loss: 0.013081 Validation loss: 45.628
# Epoch: 222 Train loss: 0.01307 Validation loss: 45.623
# Epoch: 223 Train loss: 0.013059 Validation loss: 45.618
# Epoch: 224 Train loss: 0.013047 Validation loss: 45.614
# Epoch: 225 Train loss: 0.013036 Validation loss: 45.609
# Epoch: 226 Train loss: 0.013025 Validation loss: 45.604
# Epoch: 227 Train loss: 0.013014 Validation loss: 45.6
# Epoch: 228 Train loss: 0.013003 Validation loss: 45.595
# Epoch: 229 Train loss: 0.012992 Validation loss: 45.591
# Epoch: 230 Train loss: 0.012981 Validation loss: 45.586
# Epoch: 231 Train loss: 0.01297 Validation loss: 45.582
# Epoch: 232 Train loss: 0.01296 Validation loss: 45.577
# Epoch: 233 Train loss: 0.012949 Validation loss: 45.572
# Epoch: 234 Train loss: 0.012938 Validation loss: 45.568
# Epoch: 235 Train loss: 0.012927 Validation loss: 45.563
# Epoch: 236 Train loss: 0.012917 Validation loss: 45.559
# Epoch: 237 Train loss: 0.012906 Validation loss: 45.554
# Epoch: 238 Train loss: 0.012895 Validation loss: 45.55
# Epoch: 239 Train loss: 0.012885 Validation loss: 45.545
# Epoch: 240 Train loss: 0.012874 Validation loss: 45.541
# Epoch: 241 Train loss: 0.012864 Validation loss: 45.536
# Epoch: 242 Train loss: 0.012853 Validation loss: 45.532
# Epoch: 243 Train loss: 0.012843 Validation loss: 45.527
# Epoch: 244 Train loss: 0.012832 Validation loss: 45.523
# Epoch: 245 Train loss: 0.012822 Validation loss: 45.519
# Epoch: 246 Train loss: 0.012812 Validation loss: 45.514
# Epoch: 247 Train loss: 0.012801 Validation loss: 45.51
# Epoch: 248 Train loss: 0.012791 Validation loss: 45.506
# Epoch: 249 Train loss: 0.012781 Validation loss: 45.501
# Epoch: 250 Train loss: 0.012771 Validation loss: 45.497
# Epoch: 251 Train loss: 0.012761 Validation loss: 45.493
# Epoch: 252 Train loss: 0.012751 Validation loss: 45.488
# Epoch: 253 Train loss: 0.01274 Validation loss: 45.484
# Epoch: 254 Train loss: 0.01273 Validation loss: 45.48
# Epoch: 255 Train loss: 0.01272 Validation loss: 45.476
# Epoch: 256 Train loss: 0.01271 Validation loss: 45.471
# Epoch: 257 Train loss: 0.012701 Validation loss: 45.467
# Epoch: 258 Train loss: 0.012691 Validation loss: 45.463
# Epoch: 259 Train loss: 0.012681 Validation loss: 45.459
# Epoch: 260 Train loss: 0.012671 Validation loss: 45.455
# Epoch: 261 Train loss: 0.012661 Validation loss: 45.451
# Epoch: 262 Train loss: 0.012651 Validation loss: 45.446
# Epoch: 263 Train loss: 0.012642 Validation loss: 45.442
# Epoch: 264 Train loss: 0.012632 Validation loss: 45.438
# Epoch: 265 Train loss: 0.012622 Validation loss: 45.434
# Epoch: 266 Train loss: 0.012613 Validation loss: 45.43
# Epoch: 267 Train loss: 0.012603 Validation loss: 45.426
# Epoch: 268 Train loss: 0.012593 Validation loss: 45.422
# Epoch: 269 Train loss: 0.012584 Validation loss: 45.418
# Epoch: 270 Train loss: 0.012574 Validation loss: 45.414
# Epoch: 271 Train loss: 0.012565 Validation loss: 45.41
# Epoch: 272 Train loss: 0.012555 Validation loss: 45.406
# Epoch: 273 Train loss: 0.012546 Validation loss: 45.402
# Epoch: 274 Train loss: 0.012537 Validation loss: 45.398
# Epoch: 275 Train loss: 0.012527 Validation loss: 45.394
# Epoch: 276 Train loss: 0.012518 Validation loss: 45.39
# Epoch: 277 Train loss: 0.012509 Validation loss: 45.386
# Epoch: 278 Train loss: 0.012499 Validation loss: 45.382
# Epoch: 279 Train loss: 0.01249 Validation loss: 45.378
# Epoch: 280 Train loss: 0.012481 Validation loss: 45.374
# Epoch: 281 Train loss: 0.012472 Validation loss: 45.37
# Epoch: 282 Train loss: 0.012463 Validation loss: 45.367
# Epoch: 283 Train loss: 0.012454 Validation loss: 45.363
# Epoch: 284 Train loss: 0.012444 Validation loss: 45.359
# Epoch: 285 Train loss: 0.012435 Validation loss: 45.355
# Epoch: 286 Train loss: 0.012426 Validation loss: 45.351
# Epoch: 287 Train loss: 0.012417 Validation loss: 45.347
# Epoch: 288 Train loss: 0.012408 Validation loss: 45.343
# Epoch: 289 Train loss: 0.012399 Validation loss: 45.339
# Epoch: 290 Train loss: 0.01239 Validation loss: 45.336
# Epoch: 291 Train loss: 0.012382 Validation loss: 45.332
# Epoch: 292 Train loss: 0.012373 Validation loss: 45.328
# Epoch: 293 Train loss: 0.012364 Validation loss: 45.324
# Epoch: 294 Train loss: 0.012355 Validation loss: 45.32
# Epoch: 295 Train loss: 0.012346 Validation loss: 45.316
# Epoch: 296 Train loss: 0.012337 Validation loss: 45.312
# Epoch: 297 Train loss: 0.012329 Validation loss: 45.309
# Epoch: 298 Train loss: 0.01232 Validation loss: 45.305
# Epoch: 299 Train loss: 0.012311 Validation loss: 45.301
# Epoch: 300 Train loss: 0.012303 Validation loss: 45.297
# Epoch: 301 Train loss: 0.012294 Validation loss: 45.293
# Epoch: 302 Train loss: 0.012285 Validation loss: 45.289
# Epoch: 303 Train loss: 0.012277 Validation loss: 45.286
# Epoch: 304 Train loss: 0.012268 Validation loss: 45.282
# Epoch: 305 Train loss: 0.01226 Validation loss: 45.278
# Epoch: 306 Train loss: 0.012251 Validation loss: 45.274
# Epoch: 307 Train loss: 0.012243 Validation loss: 45.271
# Epoch: 308 Train loss: 0.012234 Validation loss: 45.267
# Epoch: 309 Train loss: 0.012226 Validation loss: 45.263
# Epoch: 310 Train loss: 0.012217 Validation loss: 45.259
# Epoch: 311 Train loss: 0.012209 Validation loss: 45.255
# Epoch: 312 Train loss: 0.012201 Validation loss: 45.252
# Epoch: 313 Train loss: 0.012192 Validation loss: 45.248
# Epoch: 314 Train loss: 0.012184 Validation loss: 45.244
# Epoch: 315 Train loss: 0.012176 Validation loss: 45.241
# Epoch: 316 Train loss: 0.012168 Validation loss: 45.237
# Epoch: 317 Train loss: 0.012159 Validation loss: 45.234
# Epoch: 318 Train loss: 0.012151 Validation loss: 45.23
# Epoch: 319 Train loss: 0.012143 Validation loss: 45.226
# Epoch: 320 Train loss: 0.012135 Validation loss: 45.223
# Epoch: 321 Train loss: 0.012127 Validation loss: 45.219
# Epoch: 322 Train loss: 0.012119 Validation loss: 45.216
# Epoch: 323 Train loss: 0.012111 Validation loss: 45.212
# Epoch: 324 Train loss: 0.012103 Validation loss: 45.208
# Epoch: 325 Train loss: 0.012095 Validation loss: 45.205
# Epoch: 326 Train loss: 0.012087 Validation loss: 45.201
# Epoch: 327 Train loss: 0.012079 Validation loss: 45.198
# Epoch: 328 Train loss: 0.012071 Validation loss: 45.194
# Epoch: 329 Train loss: 0.012063 Validation loss: 45.191
# Epoch: 330 Train loss: 0.012055 Validation loss: 45.187
# Epoch: 331 Train loss: 0.012047 Validation loss: 45.183
# Epoch: 332 Train loss: 0.012039 Validation loss: 45.18
# Epoch: 333 Train loss: 0.012032 Validation loss: 45.176
# Epoch: 334 Train loss: 0.012024 Validation loss: 45.173
# Epoch: 335 Train loss: 0.012016 Validation loss: 45.169
# Epoch: 336 Train loss: 0.012008 Validation loss: 45.166
# Epoch: 337 Train loss: 0.012 Validation loss: 45.162
# Epoch: 338 Train loss: 0.011993 Validation loss: 45.159
# Epoch: 339 Train loss: 0.011985 Validation loss: 45.155
# Epoch: 340 Train loss: 0.011977 Validation loss: 45.152
# Epoch: 341 Train loss: 0.01197 Validation loss: 45.148
# Epoch: 342 Train loss: 0.011962 Validation loss: 45.145
# Epoch: 343 Train loss: 0.011954 Validation loss: 45.141
# Epoch: 344 Train loss: 0.011947 Validation loss: 45.138
# Epoch: 345 Train loss: 0.011939 Validation loss: 45.134
# Epoch: 346 Train loss: 0.011932 Validation loss: 45.131
# Epoch: 347 Train loss: 0.011924 Validation loss: 45.127
# Epoch: 348 Train loss: 0.011917 Validation loss: 45.124
# Epoch: 349 Train loss: 0.011909 Validation loss: 45.12
# Epoch: 350 Train loss: 0.011902 Validation loss: 45.117
# Epoch: 351 Train loss: 0.011894 Validation loss: 45.113
# Epoch: 352 Train loss: 0.011887 Validation loss: 45.11
# Epoch: 353 Train loss: 0.01188 Validation loss: 45.106
# Epoch: 354 Train loss: 0.011872 Validation loss: 45.103
# Epoch: 355 Train loss: 0.011865 Validation loss: 45.099
# Epoch: 356 Train loss: 0.011858 Validation loss: 45.096
# Epoch: 357 Train loss: 0.01185 Validation loss: 45.093
# Epoch: 358 Train loss: 0.011843 Validation loss: 45.089
# Epoch: 359 Train loss: 0.011836 Validation loss: 45.086
# Epoch: 360 Train loss: 0.011828 Validation loss: 45.082
# Epoch: 361 Train loss: 0.011821 Validation loss: 45.079
# Epoch: 362 Train loss: 0.011814 Validation loss: 45.075
# Epoch: 363 Train loss: 0.011807 Validation loss: 45.072
# Epoch: 364 Train loss: 0.0118 Validation loss: 45.068
# Epoch: 365 Train loss: 0.011792 Validation loss: 45.065
# Epoch: 366 Train loss: 0.011785 Validation loss: 45.061
# Epoch: 367 Train loss: 0.011778 Validation loss: 45.058
# Epoch: 368 Train loss: 0.011771 Validation loss: 45.054
# Epoch: 369 Train loss: 0.011764 Validation loss: 45.051
# Epoch: 370 Train loss: 0.011757 Validation loss: 45.047
# Epoch: 371 Train loss: 0.01175 Validation loss: 45.044
# Epoch: 372 Train loss: 0.011743 Validation loss: 45.041
# Epoch: 373 Train loss: 0.011736 Validation loss: 45.037
# Epoch: 374 Train loss: 0.011729 Validation loss: 45.034
# Epoch: 375 Train loss: 0.011722 Validation loss: 45.031
# Epoch: 376 Train loss: 0.011715 Validation loss: 45.027
# Epoch: 377 Train loss: 0.011708 Validation loss: 45.024
# Epoch: 378 Train loss: 0.011701 Validation loss: 45.021
# Epoch: 379 Train loss: 0.011694 Validation loss: 45.017
# Epoch: 380 Train loss: 0.011687 Validation loss: 45.014
# Epoch: 381 Train loss: 0.011681 Validation loss: 45.011
# Epoch: 382 Train loss: 0.011674 Validation loss: 45.007
# Epoch: 383 Train loss: 0.011667 Validation loss: 45.004
# Epoch: 384 Train loss: 0.01166 Validation loss: 45.001
# Epoch: 385 Train loss: 0.011653 Validation loss: 44.997
# Epoch: 386 Train loss: 0.011647 Validation loss: 44.994
# Epoch: 387 Train loss: 0.01164 Validation loss: 44.991
# Epoch: 388 Train loss: 0.011633 Validation loss: 44.987
# Epoch: 389 Train loss: 0.011626 Validation loss: 44.984
# Epoch: 390 Train loss: 0.01162 Validation loss: 44.981
# Epoch: 391 Train loss: 0.011613 Validation loss: 44.977
# Epoch: 392 Train loss: 0.011606 Validation loss: 44.974
# Epoch: 393 Train loss: 0.011599 Validation loss: 44.971
# Epoch: 394 Train loss: 0.011593 Validation loss: 44.967
# Epoch: 395 Train loss: 0.011586 Validation loss: 44.964
# Epoch: 396 Train loss: 0.01158 Validation loss: 44.961
# Epoch: 397 Train loss: 0.011573 Validation loss: 44.957
# Epoch: 398 Train loss: 0.011566 Validation loss: 44.954
# Epoch: 399 Train loss: 0.01156 Validation loss: 44.951
# Epoch: 400 Train loss: 0.011553 Validation loss: 44.947
# Epoch: 401 Train loss: 0.011547 Validation loss: 44.944
# Epoch: 402 Train loss: 0.01154 Validation loss: 44.941
# Epoch: 403 Train loss: 0.011534 Validation loss: 44.937
# Epoch: 404 Train loss: 0.011527 Validation loss: 44.934
# Epoch: 405 Train loss: 0.011521 Validation loss: 44.931
# Epoch: 406 Train loss: 0.011514 Validation loss: 44.927
# Epoch: 407 Train loss: 0.011508 Validation loss: 44.924
# Epoch: 408 Train loss: 0.011501 Validation loss: 44.921
# Epoch: 409 Train loss: 0.011495 Validation loss: 44.917
# Epoch: 410 Train loss: 0.011489 Validation loss: 44.914
# Epoch: 411 Train loss: 0.011482 Validation loss: 44.911
# Epoch: 412 Train loss: 0.011476 Validation loss: 44.908
# Epoch: 413 Train loss: 0.011469 Validation loss: 44.904
# Epoch: 414 Train loss: 0.011463 Validation loss: 44.901
# Epoch: 415 Train loss: 0.011457 Validation loss: 44.898
# Epoch: 416 Train loss: 0.01145 Validation loss: 44.894
# Epoch: 417 Train loss: 0.011444 Validation loss: 44.891
# Epoch: 418 Train loss: 0.011438 Validation loss: 44.888
# Epoch: 419 Train loss: 0.011432 Validation loss: 44.884
# Epoch: 420 Train loss: 0.011425 Validation loss: 44.881
# Epoch: 421 Train loss: 0.011419 Validation loss: 44.878
# Epoch: 422 Train loss: 0.011413 Validation loss: 44.875
# Epoch: 423 Train loss: 0.011407 Validation loss: 44.871
# Epoch: 424 Train loss: 0.0114 Validation loss: 44.868
# Epoch: 425 Train loss: 0.011394 Validation loss: 44.865
# Epoch: 426 Train loss: 0.011388 Validation loss: 44.862
# Epoch: 427 Train loss: 0.011382 Validation loss: 44.858
# Epoch: 428 Train loss: 0.011376 Validation loss: 44.855
# Epoch: 429 Train loss: 0.01137 Validation loss: 44.852
# Epoch: 430 Train loss: 0.011363 Validation loss: 44.849
# Epoch: 431 Train loss: 0.011357 Validation loss: 44.845
# Epoch: 432 Train loss: 0.011351 Validation loss: 44.842
# Epoch: 433 Train loss: 0.011345 Validation loss: 44.839
# Epoch: 434 Train loss: 0.011339 Validation loss: 44.836
# Epoch: 435 Train loss: 0.011333 Validation loss: 44.833
# Epoch: 436 Train loss: 0.011327 Validation loss: 44.829
# Epoch: 437 Train loss: 0.011321 Validation loss: 44.826
# Epoch: 438 Train loss: 0.011315 Validation loss: 44.823
# Epoch: 439 Train loss: 0.011309 Validation loss: 44.82
# Epoch: 440 Train loss: 0.011303 Validation loss: 44.816
# Epoch: 441 Train loss: 0.011297 Validation loss: 44.813
# Epoch: 442 Train loss: 0.011291 Validation loss: 44.81
# Epoch: 443 Train loss: 0.011285 Validation loss: 44.806
# Epoch: 444 Train loss: 0.011279 Validation loss: 44.803
# Epoch: 445 Train loss: 0.011273 Validation loss: 44.8
# Epoch: 446 Train loss: 0.011267 Validation loss: 44.797
# Epoch: 447 Train loss: 0.011262 Validation loss: 44.793
# Epoch: 448 Train loss: 0.011256 Validation loss: 44.79
# Epoch: 449 Train loss: 0.01125 Validation loss: 44.787
# Epoch: 450 Train loss: 0.011244 Validation loss: 44.784
# Epoch: 451 Train loss: 0.011238 Validation loss: 44.781
# Epoch: 452 Train loss: 0.011232 Validation loss: 44.777
# Epoch: 453 Train loss: 0.011226 Validation loss: 44.774
# Epoch: 454 Train loss: 0.011221 Validation loss: 44.771
# Epoch: 455 Train loss: 0.011215 Validation loss: 44.768
# Epoch: 456 Train loss: 0.011209 Validation loss: 44.764
# Epoch: 457 Train loss: 0.011203 Validation loss: 44.761
# Epoch: 458 Train loss: 0.011198 Validation loss: 44.758
# Epoch: 459 Train loss: 0.011192 Validation loss: 44.755
# Epoch: 460 Train loss: 0.011186 Validation loss: 44.751
# Epoch: 461 Train loss: 0.01118 Validation loss: 44.748
# Epoch: 462 Train loss: 0.011175 Validation loss: 44.745
# Epoch: 463 Train loss: 0.011169 Validation loss: 44.742
# Epoch: 464 Train loss: 0.011163 Validation loss: 44.738
# Epoch: 465 Train loss: 0.011158 Validation loss: 44.735
# Epoch: 466 Train loss: 0.011152 Validation loss: 44.732
# Epoch: 467 Train loss: 0.011146 Validation loss: 44.729
# Epoch: 468 Train loss: 0.011141 Validation loss: 44.725
# Epoch: 469 Train loss: 0.011135 Validation loss: 44.722
# Epoch: 470 Train loss: 0.011129 Validation loss: 44.719
# Epoch: 471 Train loss: 0.011124 Validation loss: 44.716
# Epoch: 472 Train loss: 0.011118 Validation loss: 44.712
# Epoch: 473 Train loss: 0.011113 Validation loss: 44.709
# Epoch: 474 Train loss: 0.011107 Validation loss: 44.706
# Epoch: 475 Train loss: 0.011101 Validation loss: 44.703
# Epoch: 476 Train loss: 0.011096 Validation loss: 44.699
# Epoch: 477 Train loss: 0.01109 Validation loss: 44.696
# Epoch: 478 Train loss: 0.011085 Validation loss: 44.693
# Epoch: 479 Train loss: 0.011079 Validation loss: 44.69
# Epoch: 480 Train loss: 0.011074 Validation loss: 44.687
# Epoch: 481 Train loss: 0.011068 Validation loss: 44.683
# Epoch: 482 Train loss: 0.011063 Validation loss: 44.68
# Epoch: 483 Train loss: 0.011057 Validation loss: 44.677
# Epoch: 484 Train loss: 0.011052 Validation loss: 44.674
# Epoch: 485 Train loss: 0.011046 Validation loss: 44.671
# Epoch: 486 Train loss: 0.011041 Validation loss: 44.667
# Epoch: 487 Train loss: 0.011035 Validation loss: 44.664
# Epoch: 488 Train loss: 0.01103 Validation loss: 44.661
# Epoch: 489 Train loss: 0.011025 Validation loss: 44.658
# Epoch: 490 Train loss: 0.011019 Validation loss: 44.654
# Epoch: 491 Train loss: 0.011014 Validation loss: 44.651
# Epoch: 492 Train loss: 0.011008 Validation loss: 44.648
# Epoch: 493 Train loss: 0.011003 Validation loss: 44.645
# Epoch: 494 Train loss: 0.010998 Validation loss: 44.642
# Epoch: 495 Train loss: 0.010992 Validation loss: 44.638
# Epoch: 496 Train loss: 0.010987 Validation loss: 44.635
# Epoch: 497 Train loss: 0.010982 Validation loss: 44.632
# Epoch: 498 Train loss: 0.010976 Validation loss: 44.629
# Epoch: 499 Train loss: 0.010971 Validation loss: 44.626
# Epoch: 500 Train loss: 0.010966 Validation loss: 44.623
# Epoch: 501 Train loss: 0.01096 Validation loss: 44.619
# Epoch: 502 Train loss: 0.010955 Validation loss: 44.616
# Epoch: 503 Train loss: 0.01095 Validation loss: 44.613
# Epoch: 504 Train loss: 0.010944 Validation loss: 44.61
# Epoch: 505 Train loss: 0.010939 Validation loss: 44.607
# Epoch: 506 Train loss: 0.010934 Validation loss: 44.604
# Epoch: 507 Train loss: 0.010929 Validation loss: 44.6
# Epoch: 508 Train loss: 0.010923 Validation loss: 44.597
# Epoch: 509 Train loss: 0.010918 Validation loss: 44.594
# Epoch: 510 Train loss: 0.010913 Validation loss: 44.591
# Epoch: 511 Train loss: 0.010908 Validation loss: 44.587
# Epoch: 512 Train loss: 0.010902 Validation loss: 44.584
# Epoch: 513 Train loss: 0.010897 Validation loss: 44.581
# Epoch: 514 Train loss: 0.010892 Validation loss: 44.578
# Epoch: 515 Train loss: 0.010887 Validation loss: 44.575
# Epoch: 516 Train loss: 0.010882 Validation loss: 44.571
# Epoch: 517 Train loss: 0.010877 Validation loss: 44.568
# Epoch: 518 Train loss: 0.010871 Validation loss: 44.565
# Epoch: 519 Train loss: 0.010866 Validation loss: 44.562
# Epoch: 520 Train loss: 0.010861 Validation loss: 44.559
# Epoch: 521 Train loss: 0.010856 Validation loss: 44.555
# Epoch: 522 Train loss: 0.010851 Validation loss: 44.552
# Epoch: 523 Train loss: 0.010846 Validation loss: 44.549
# Epoch: 524 Train loss: 0.010841 Validation loss: 44.546
# Epoch: 525 Train loss: 0.010836 Validation loss: 44.543
# Epoch: 526 Train loss: 0.010831 Validation loss: 44.539
# Epoch: 527 Train loss: 0.010826 Validation loss: 44.536
# Epoch: 528 Train loss: 0.01082 Validation loss: 44.533
# Epoch: 529 Train loss: 0.010815 Validation loss: 44.53
# Epoch: 530 Train loss: 0.01081 Validation loss: 44.527
# Epoch: 531 Train loss: 0.010805 Validation loss: 44.523
# Epoch: 532 Train loss: 0.0108 Validation loss: 44.52
# Epoch: 533 Train loss: 0.010795 Validation loss: 44.517
# Epoch: 534 Train loss: 0.01079 Validation loss: 44.514
# Epoch: 535 Train loss: 0.010785 Validation loss: 44.511
# Epoch: 536 Train loss: 0.01078 Validation loss: 44.508
# Epoch: 537 Train loss: 0.010775 Validation loss: 44.504
# Epoch: 538 Train loss: 0.01077 Validation loss: 44.501
# Epoch: 539 Train loss: 0.010765 Validation loss: 44.498
# Epoch: 540 Train loss: 0.01076 Validation loss: 44.495
# Epoch: 541 Train loss: 0.010755 Validation loss: 44.492
# Epoch: 542 Train loss: 0.010751 Validation loss: 44.488
# Epoch: 543 Train loss: 0.010746 Validation loss: 44.485
# Epoch: 544 Train loss: 0.010741 Validation loss: 44.482
# Epoch: 545 Train loss: 0.010736 Validation loss: 44.479
# Epoch: 546 Train loss: 0.010731 Validation loss: 44.476
# Epoch: 547 Train loss: 0.010726 Validation loss: 44.473
# Epoch: 548 Train loss: 0.010721 Validation loss: 44.469
# Epoch: 549 Train loss: 0.010716 Validation loss: 44.466
# Epoch: 550 Train loss: 0.010711 Validation loss: 44.463
# Epoch: 551 Train loss: 0.010706 Validation loss: 44.46
# Epoch: 552 Train loss: 0.010702 Validation loss: 44.457
# Epoch: 553 Train loss: 0.010697 Validation loss: 44.453
# Epoch: 554 Train loss: 0.010692 Validation loss: 44.45
# Epoch: 555 Train loss: 0.010687 Validation loss: 44.447
# Epoch: 556 Train loss: 0.010682 Validation loss: 44.444
# Epoch: 557 Train loss: 0.010677 Validation loss: 44.441
# Epoch: 558 Train loss: 0.010673 Validation loss: 44.437
# Epoch: 559 Train loss: 0.010668 Validation loss: 44.434
# Epoch: 560 Train loss: 0.010663 Validation loss: 44.431
# Epoch: 561 Train loss: 0.010658 Validation loss: 44.428
# Epoch: 562 Train loss: 0.010653 Validation loss: 44.425
# Epoch: 563 Train loss: 0.010649 Validation loss: 44.421
# Epoch: 564 Train loss: 0.010644 Validation loss: 44.418
# Epoch: 565 Train loss: 0.010639 Validation loss: 44.415
# Epoch: 566 Train loss: 0.010634 Validation loss: 44.412
# Epoch: 567 Train loss: 0.01063 Validation loss: 44.409
# Epoch: 568 Train loss: 0.010625 Validation loss: 44.405
# Epoch: 569 Train loss: 0.01062 Validation loss: 44.402
# Epoch: 570 Train loss: 0.010616 Validation loss: 44.399
# Epoch: 571 Train loss: 0.010611 Validation loss: 44.396
# Epoch: 572 Train loss: 0.010606 Validation loss: 44.393
# Epoch: 573 Train loss: 0.010601 Validation loss: 44.389
# Epoch: 574 Train loss: 0.010597 Validation loss: 44.386
# Epoch: 575 Train loss: 0.010592 Validation loss: 44.383
# Epoch: 576 Train loss: 0.010587 Validation loss: 44.38
# Epoch: 577 Train loss: 0.010583 Validation loss: 44.377
# Epoch: 578 Train loss: 0.010578 Validation loss: 44.373
# Epoch: 579 Train loss: 0.010573 Validation loss: 44.37
# Epoch: 580 Train loss: 0.010569 Validation loss: 44.367
# Epoch: 581 Train loss: 0.010564 Validation loss: 44.364
# Epoch: 582 Train loss: 0.01056 Validation loss: 44.361
# Epoch: 583 Train loss: 0.010555 Validation loss: 44.358
# Epoch: 584 Train loss: 0.01055 Validation loss: 44.354
# Epoch: 585 Train loss: 0.010546 Validation loss: 44.351
# Epoch: 586 Train loss: 0.010541 Validation loss: 44.348
# Epoch: 587 Train loss: 0.010537 Validation loss: 44.345
# Epoch: 588 Train loss: 0.010532 Validation loss: 44.342
# Epoch: 589 Train loss: 0.010527 Validation loss: 44.338
# Epoch: 590 Train loss: 0.010523 Validation loss: 44.335
# Epoch: 591 Train loss: 0.010518 Validation loss: 44.332
# Epoch: 592 Train loss: 0.010514 Validation loss: 44.329
# Epoch: 593 Train loss: 0.010509 Validation loss: 44.326
# Epoch: 594 Train loss: 0.010505 Validation loss: 44.322
# Epoch: 595 Train loss: 0.0105 Validation loss: 44.319
# Epoch: 596 Train loss: 0.010496 Validation loss: 44.316
# Epoch: 597 Train loss: 0.010491 Validation loss: 44.313
# Epoch: 598 Train loss: 0.010487 Validation loss: 44.31
# Epoch: 599 Train loss: 0.010482 Validation loss: 44.307
# Epoch: 600 Train loss: 0.010478 Validation loss: 44.303
# Epoch: 601 Train loss: 0.010473 Validation loss: 44.3
# Epoch: 602 Train loss: 0.010469 Validation loss: 44.297
# Epoch: 603 Train loss: 0.010464 Validation loss: 44.294
# Epoch: 604 Train loss: 0.01046 Validation loss: 44.291
# Epoch: 605 Train loss: 0.010455 Validation loss: 44.288
# Epoch: 606 Train loss: 0.010451 Validation loss: 44.284
# Epoch: 607 Train loss: 0.010446 Validation loss: 44.281
# Epoch: 608 Train loss: 0.010442 Validation loss: 44.278
# Epoch: 609 Train loss: 0.010438 Validation loss: 44.275
# Epoch: 610 Train loss: 0.010433 Validation loss: 44.272
# Epoch: 611 Train loss: 0.010429 Validation loss: 44.268
# Epoch: 612 Train loss: 0.010424 Validation loss: 44.265
# Epoch: 613 Train loss: 0.01042 Validation loss: 44.262
# Epoch: 614 Train loss: 0.010415 Validation loss: 44.259
# Epoch: 615 Train loss: 0.010411 Validation loss: 44.256
# Epoch: 616 Train loss: 0.010407 Validation loss: 44.253
# Epoch: 617 Train loss: 0.010402 Validation loss: 44.25
# Epoch: 618 Train loss: 0.010398 Validation loss: 44.246
# Epoch: 619 Train loss: 0.010394 Validation loss: 44.243
# Epoch: 620 Train loss: 0.010389 Validation loss: 44.24
# Epoch: 621 Train loss: 0.010385 Validation loss: 44.237
# Epoch: 622 Train loss: 0.01038 Validation loss: 44.234
# Epoch: 623 Train loss: 0.010376 Validation loss: 44.231
# Epoch: 624 Train loss: 0.010372 Validation loss: 44.227
# Epoch: 625 Train loss: 0.010368 Validation loss: 44.224
# Epoch: 626 Train loss: 0.010363 Validation loss: 44.221
# Epoch: 627 Train loss: 0.010359 Validation loss: 44.218
# Epoch: 628 Train loss: 0.010355 Validation loss: 44.215
# Epoch: 629 Train loss: 0.01035 Validation loss: 44.212
# Epoch: 630 Train loss: 0.010346 Validation loss: 44.209
# Epoch: 631 Train loss: 0.010342 Validation loss: 44.206
# Epoch: 632 Train loss: 0.010337 Validation loss: 44.202
# Epoch: 633 Train loss: 0.010333 Validation loss: 44.199
# Epoch: 634 Train loss: 0.010329 Validation loss: 44.196
# Epoch: 635 Train loss: 0.010325 Validation loss: 44.193
# Epoch: 636 Train loss: 0.01032 Validation loss: 44.19
# Epoch: 637 Train loss: 0.010316 Validation loss: 44.187
# Epoch: 638 Train loss: 0.010312 Validation loss: 44.184
# Epoch: 639 Train loss: 0.010308 Validation loss: 44.18
# Epoch: 640 Train loss: 0.010303 Validation loss: 44.177
# Epoch: 641 Train loss: 0.010299 Validation loss: 44.174
# Epoch: 642 Train loss: 0.010295 Validation loss: 44.171
# Epoch: 643 Train loss: 0.010291 Validation loss: 44.168
# Epoch: 644 Train loss: 0.010287 Validation loss: 44.165
# Epoch: 645 Train loss: 0.010282 Validation loss: 44.162
# Epoch: 646 Train loss: 0.010278 Validation loss: 44.158
# Epoch: 647 Train loss: 0.010274 Validation loss: 44.155
# Epoch: 648 Train loss: 0.01027 Validation loss: 44.152
# Epoch: 649 Train loss: 0.010266 Validation loss: 44.149
# Epoch: 650 Train loss: 0.010261 Validation loss: 44.146
# Epoch: 651 Train loss: 0.010257 Validation loss: 44.143
# Epoch: 652 Train loss: 0.010253 Validation loss: 44.14
# Epoch: 653 Train loss: 0.010249 Validation loss: 44.137
# Epoch: 654 Train loss: 0.010245 Validation loss: 44.133
# Epoch: 655 Train loss: 0.010241 Validation loss: 44.13
# Epoch: 656 Train loss: 0.010236 Validation loss: 44.127
# Epoch: 657 Train loss: 0.010232 Validation loss: 44.124
# Epoch: 658 Train loss: 0.010228 Validation loss: 44.121
# Epoch: 659 Train loss: 0.010224 Validation loss: 44.118
# Epoch: 660 Train loss: 0.01022 Validation loss: 44.115
# Epoch: 661 Train loss: 0.010216 Validation loss: 44.112
# Epoch: 662 Train loss: 0.010212 Validation loss: 44.109
# Epoch: 663 Train loss: 0.010208 Validation loss: 44.105
# Epoch: 664 Train loss: 0.010203 Validation loss: 44.102
# Epoch: 665 Train loss: 0.010199 Validation loss: 44.099
# Epoch: 666 Train loss: 0.010195 Validation loss: 44.096
# Epoch: 667 Train loss: 0.010191 Validation loss: 44.093
# Epoch: 668 Train loss: 0.010187 Validation loss: 44.09
# Epoch: 669 Train loss: 0.010183 Validation loss: 44.087
# Epoch: 670 Train loss: 0.010179 Validation loss: 44.084
# Epoch: 671 Train loss: 0.010175 Validation loss: 44.08
# Epoch: 672 Train loss: 0.010171 Validation loss: 44.077
# Epoch: 673 Train loss: 0.010167 Validation loss: 44.074
# Epoch: 674 Train loss: 0.010163 Validation loss: 44.071
# Epoch: 675 Train loss: 0.010159 Validation loss: 44.068
# Epoch: 676 Train loss: 0.010155 Validation loss: 44.065
# Epoch: 677 Train loss: 0.010151 Validation loss: 44.062
# Epoch: 678 Train loss: 0.010147 Validation loss: 44.059
# Epoch: 679 Train loss: 0.010143 Validation loss: 44.056
# Epoch: 680 Train loss: 0.010139 Validation loss: 44.053
# Epoch: 681 Train loss: 0.010135 Validation loss: 44.05
# Epoch: 682 Train loss: 0.010131 Validation loss: 44.047
# Epoch: 683 Train loss: 0.010127 Validation loss: 44.044
# Epoch: 684 Train loss: 0.010123 Validation loss: 44.04
# Epoch: 685 Train loss: 0.010119 Validation loss: 44.037
# Epoch: 686 Train loss: 0.010115 Validation loss: 44.034
# Epoch: 687 Train loss: 0.010111 Validation loss: 44.031
# Epoch: 688 Train loss: 0.010107 Validation loss: 44.028
# Epoch: 689 Train loss: 0.010103 Validation loss: 44.025
# Epoch: 690 Train loss: 0.010099 Validation loss: 44.022
# Epoch: 691 Train loss: 0.010095 Validation loss: 44.019
# Epoch: 692 Train loss: 0.010091 Validation loss: 44.016
# Epoch: 693 Train loss: 0.010087 Validation loss: 44.012
# Epoch: 694 Train loss: 0.010083 Validation loss: 44.009
# Epoch: 695 Train loss: 0.010079 Validation loss: 44.006
# Epoch: 696 Train loss: 0.010075 Validation loss: 44.003
# Epoch: 697 Train loss: 0.010071 Validation loss: 44.0
# Epoch: 698 Train loss: 0.010067 Validation loss: 43.997
# Epoch: 699 Train loss: 0.010063 Validation loss: 43.994
# Epoch: 700 Train loss: 0.010059 Validation loss: 43.991
# Epoch: 701 Train loss: 0.010056 Validation loss: 43.988
# Epoch: 702 Train loss: 0.010052 Validation loss: 43.985
# Epoch: 703 Train loss: 0.010048 Validation loss: 43.982
# Epoch: 704 Train loss: 0.010044 Validation loss: 43.979
# Epoch: 705 Train loss: 0.01004 Validation loss: 43.976
# Epoch: 706 Train loss: 0.010036 Validation loss: 43.973
# Epoch: 707 Train loss: 0.010032 Validation loss: 43.97
# Epoch: 708 Train loss: 0.010028 Validation loss: 43.967
# Epoch: 709 Train loss: 0.010025 Validation loss: 43.964
# Epoch: 710 Train loss: 0.010021 Validation loss: 43.961
# Epoch: 711 Train loss: 0.010017 Validation loss: 43.958
# Epoch: 712 Train loss: 0.010013 Validation loss: 43.954
# Epoch: 713 Train loss: 0.010009 Validation loss: 43.951
# Epoch: 714 Train loss: 0.010005 Validation loss: 43.948
# Epoch: 715 Train loss: 0.010001 Validation loss: 43.945
# Epoch: 716 Train loss: 0.0099976 Validation loss: 43.942
# Epoch: 717 Train loss: 0.0099938 Validation loss: 43.939
# Epoch: 718 Train loss: 0.00999 Validation loss: 43.936
# Epoch: 719 Train loss: 0.0099862 Validation loss: 43.933
# Epoch: 720 Train loss: 0.0099824 Validation loss: 43.93
# Epoch: 721 Train loss: 0.0099786 Validation loss: 43.927
# Epoch: 722 Train loss: 0.0099748 Validation loss: 43.924
# Epoch: 723 Train loss: 0.009971 Validation loss: 43.921
# Epoch: 724 Train loss: 0.0099672 Validation loss: 43.918
# Epoch: 725 Train loss: 0.0099634 Validation loss: 43.915
# Epoch: 726 Train loss: 0.0099596 Validation loss: 43.912
# Epoch: 727 Train loss: 0.0099558 Validation loss: 43.909
# Epoch: 728 Train loss: 0.0099521 Validation loss: 43.906
# Epoch: 729 Train loss: 0.0099483 Validation loss: 43.903
# Epoch: 730 Train loss: 0.0099445 Validation loss: 43.9
# Epoch: 731 Train loss: 0.0099408 Validation loss: 43.897
# Epoch: 732 Train loss: 0.009937 Validation loss: 43.894
# Epoch: 733 Train loss: 0.0099333 Validation loss: 43.891
# Epoch: 734 Train loss: 0.0099295 Validation loss: 43.888
# Epoch: 735 Train loss: 0.0099258 Validation loss: 43.885
# Epoch: 736 Train loss: 0.009922 Validation loss: 43.882
# Epoch: 737 Train loss: 0.0099183 Validation loss: 43.879
# Epoch: 738 Train loss: 0.0099145 Validation loss: 43.876
# Epoch: 739 Train loss: 0.0099108 Validation loss: 43.873
# Epoch: 740 Train loss: 0.0099071 Validation loss: 43.87
# Epoch: 741 Train loss: 0.0099034 Validation loss: 43.867
# Epoch: 742 Train loss: 0.0098996 Validation loss: 43.864
# Epoch: 743 Train loss: 0.0098959 Validation loss: 43.861
# Epoch: 744 Train loss: 0.0098922 Validation loss: 43.858
# Epoch: 745 Train loss: 0.0098885 Validation loss: 43.855
# Epoch: 746 Train loss: 0.0098848 Validation loss: 43.852
# Epoch: 747 Train loss: 0.0098811 Validation loss: 43.849
# Epoch: 748 Train loss: 0.0098774 Validation loss: 43.846
# Epoch: 749 Train loss: 0.0098737 Validation loss: 43.843
# Epoch: 750 Train loss: 0.00987 Validation loss: 43.84
# Epoch: 751 Train loss: 0.0098663 Validation loss: 43.837
# Epoch: 752 Train loss: 0.0098626 Validation loss: 43.834
# Epoch: 753 Train loss: 0.009859 Validation loss: 43.831
# Epoch: 754 Train loss: 0.0098553 Validation loss: 43.828
# Epoch: 755 Train loss: 0.0098516 Validation loss: 43.826
# Epoch: 756 Train loss: 0.0098479 Validation loss: 43.823
# Epoch: 757 Train loss: 0.0098443 Validation loss: 43.82
# Epoch: 758 Train loss: 0.0098406 Validation loss: 43.817
# Epoch: 759 Train loss: 0.009837 Validation loss: 43.814
# Epoch: 760 Train loss: 0.0098333 Validation loss: 43.811
# Epoch: 761 Train loss: 0.0098297 Validation loss: 43.808
# Epoch: 762 Train loss: 0.009826 Validation loss: 43.805
# Epoch: 763 Train loss: 0.0098224 Validation loss: 43.802
# Epoch: 764 Train loss: 0.0098188 Validation loss: 43.799
# Epoch: 765 Train loss: 0.0098151 Validation loss: 43.796
# Epoch: 766 Train loss: 0.0098115 Validation loss: 43.793
# Epoch: 767 Train loss: 0.0098079 Validation loss: 43.79
# Epoch: 768 Train loss: 0.0098043 Validation loss: 43.787
# Epoch: 769 Train loss: 0.0098007 Validation loss: 43.784
# Epoch: 770 Train loss: 0.009797 Validation loss: 43.781
# Epoch: 771 Train loss: 0.0097934 Validation loss: 43.778
# Epoch: 772 Train loss: 0.0097898 Validation loss: 43.775
# Epoch: 773 Train loss: 0.0097862 Validation loss: 43.772
# Epoch: 774 Train loss: 0.0097826 Validation loss: 43.769
# Epoch: 775 Train loss: 0.009779 Validation loss: 43.766
# Epoch: 776 Train loss: 0.0097754 Validation loss: 43.763
# Epoch: 777 Train loss: 0.0097718 Validation loss: 43.76
# Epoch: 778 Train loss: 0.0097683 Validation loss: 43.757
# Epoch: 779 Train loss: 0.0097647 Validation loss: 43.754
# Epoch: 780 Train loss: 0.0097611 Validation loss: 43.751
# Epoch: 781 Train loss: 0.0097575 Validation loss: 43.748
# Epoch: 782 Train loss: 0.009754 Validation loss: 43.745
# Epoch: 783 Train loss: 0.0097504 Validation loss: 43.742
# Epoch: 784 Train loss: 0.0097469 Validation loss: 43.739
# Epoch: 785 Train loss: 0.0097433 Validation loss: 43.736
# Epoch: 786 Train loss: 0.0097397 Validation loss: 43.734
# Epoch: 787 Train loss: 0.0097362 Validation loss: 43.731
# Epoch: 788 Train loss: 0.0097327 Validation loss: 43.728
# Epoch: 789 Train loss: 0.0097291 Validation loss: 43.725
# Epoch: 790 Train loss: 0.0097256 Validation loss: 43.722
# Epoch: 791 Train loss: 0.0097221 Validation loss: 43.719
# Epoch: 792 Train loss: 0.0097185 Validation loss: 43.716
# Epoch: 793 Train loss: 0.009715 Validation loss: 43.713
# Epoch: 794 Train loss: 0.0097115 Validation loss: 43.71
# Epoch: 795 Train loss: 0.009708 Validation loss: 43.707
# Epoch: 796 Train loss: 0.0097044 Validation loss: 43.704
# Epoch: 797 Train loss: 0.0097009 Validation loss: 43.701
# Epoch: 798 Train loss: 0.0096974 Validation loss: 43.698
# Epoch: 799 Train loss: 0.0096939 Validation loss: 43.695
# Epoch: 800 Train loss: 0.0096904 Validation loss: 43.692
# Epoch: 801 Train loss: 0.0096869 Validation loss: 43.69
# Epoch: 802 Train loss: 0.0096834 Validation loss: 43.687
# Epoch: 803 Train loss: 0.0096799 Validation loss: 43.684
# Epoch: 804 Train loss: 0.0096764 Validation loss: 43.681
# Epoch: 805 Train loss: 0.0096729 Validation loss: 43.678
# Epoch: 806 Train loss: 0.0096695 Validation loss: 43.675
# Epoch: 807 Train loss: 0.009666 Validation loss: 43.672
# Epoch: 808 Train loss: 0.0096625 Validation loss: 43.669
# Epoch: 809 Train loss: 0.009659 Validation loss: 43.666
# Epoch: 810 Train loss: 0.0096556 Validation loss: 43.664
# Epoch: 811 Train loss: 0.0096521 Validation loss: 43.661
# Epoch: 812 Train loss: 0.0096486 Validation loss: 43.658
# Epoch: 813 Train loss: 0.0096451 Validation loss: 43.655
# Epoch: 814 Train loss: 0.0096417 Validation loss: 43.652
# Epoch: 815 Train loss: 0.0096382 Validation loss: 43.649
# Epoch: 816 Train loss: 0.0096348 Validation loss: 43.646
# Epoch: 817 Train loss: 0.0096313 Validation loss: 43.644
# Epoch: 818 Train loss: 0.0096279 Validation loss: 43.641
# Epoch: 819 Train loss: 0.0096244 Validation loss: 43.638
# Epoch: 820 Train loss: 0.009621 Validation loss: 43.635
# Epoch: 821 Train loss: 0.0096175 Validation loss: 43.632
# Epoch: 822 Train loss: 0.0096141 Validation loss: 43.629
# Epoch: 823 Train loss: 0.0096107 Validation loss: 43.626
# Epoch: 824 Train loss: 0.0096072 Validation loss: 43.624
# Epoch: 825 Train loss: 0.0096038 Validation loss: 43.621
# Epoch: 826 Train loss: 0.0096004 Validation loss: 43.618
# Epoch: 827 Train loss: 0.009597 Validation loss: 43.615
# Epoch: 828 Train loss: 0.0095935 Validation loss: 43.612
# Epoch: 829 Train loss: 0.0095901 Validation loss: 43.61
# Epoch: 830 Train loss: 0.0095867 Validation loss: 43.607
# Epoch: 831 Train loss: 0.0095833 Validation loss: 43.604
# Epoch: 832 Train loss: 0.0095799 Validation loss: 43.601
# Epoch: 833 Train loss: 0.0095765 Validation loss: 43.598
# Epoch: 834 Train loss: 0.0095731 Validation loss: 43.596
# Epoch: 835 Train loss: 0.0095697 Validation loss: 43.593
# Epoch: 836 Train loss: 0.0095663 Validation loss: 43.59
# Epoch: 837 Train loss: 0.0095629 Validation loss: 43.587
# Epoch: 838 Train loss: 0.0095595 Validation loss: 43.584
# Epoch: 839 Train loss: 0.0095561 Validation loss: 43.582
# Epoch: 840 Train loss: 0.0095528 Validation loss: 43.579
# Epoch: 841 Train loss: 0.0095494 Validation loss: 43.576
# Epoch: 842 Train loss: 0.009546 Validation loss: 43.573
# Epoch: 843 Train loss: 0.0095426 Validation loss: 43.57
# Epoch: 844 Train loss: 0.0095392 Validation loss: 43.568
# Epoch: 845 Train loss: 0.0095359 Validation loss: 43.565
# Epoch: 846 Train loss: 0.0095325 Validation loss: 43.562
# Epoch: 847 Train loss: 0.0095291 Validation loss: 43.559
# Epoch: 848 Train loss: 0.0095257 Validation loss: 43.557
# Epoch: 849 Train loss: 0.0095224 Validation loss: 43.554
# Epoch: 850 Train loss: 0.009519 Validation loss: 43.551
# Epoch: 851 Train loss: 0.0095157 Validation loss: 43.548
# Epoch: 852 Train loss: 0.0095123 Validation loss: 43.546
# Epoch: 853 Train loss: 0.009509 Validation loss: 43.543
# Epoch: 854 Train loss: 0.0095056 Validation loss: 43.54
# Epoch: 855 Train loss: 0.0095023 Validation loss: 43.537
# Epoch: 856 Train loss: 0.0094989 Validation loss: 43.535
# Epoch: 857 Train loss: 0.0094956 Validation loss: 43.532
# Epoch: 858 Train loss: 0.0094922 Validation loss: 43.529
# Epoch: 859 Train loss: 0.0094889 Validation loss: 43.526
# Epoch: 860 Train loss: 0.0094856 Validation loss: 43.524
# Epoch: 861 Train loss: 0.0094822 Validation loss: 43.521
# Epoch: 862 Train loss: 0.0094789 Validation loss: 43.518
# Epoch: 863 Train loss: 0.0094756 Validation loss: 43.515
# Epoch: 864 Train loss: 0.0094723 Validation loss: 43.513
# Epoch: 865 Train loss: 0.0094689 Validation loss: 43.51
# Epoch: 866 Train loss: 0.0094656 Validation loss: 43.507
# Epoch: 867 Train loss: 0.0094623 Validation loss: 43.505
# Epoch: 868 Train loss: 0.009459 Validation loss: 43.502
# Epoch: 869 Train loss: 0.0094557 Validation loss: 43.499
# Epoch: 870 Train loss: 0.0094524 Validation loss: 43.496
# Epoch: 871 Train loss: 0.0094491 Validation loss: 43.494
# Epoch: 872 Train loss: 0.0094458 Validation loss: 43.491
# Epoch: 873 Train loss: 0.0094425 Validation loss: 43.488
# Epoch: 874 Train loss: 0.0094392 Validation loss: 43.485
# Epoch: 875 Train loss: 0.0094359 Validation loss: 43.483
# Epoch: 876 Train loss: 0.0094326 Validation loss: 43.48
# Epoch: 877 Train loss: 0.0094294 Validation loss: 43.477
# Epoch: 878 Train loss: 0.0094261 Validation loss: 43.475
# Epoch: 879 Train loss: 0.0094228 Validation loss: 43.472
# Epoch: 880 Train loss: 0.0094195 Validation loss: 43.469
# Epoch: 881 Train loss: 0.0094163 Validation loss: 43.466
# Epoch: 882 Train loss: 0.009413 Validation loss: 43.464
# Epoch: 883 Train loss: 0.0094097 Validation loss: 43.461
# Epoch: 884 Train loss: 0.0094065 Validation loss: 43.458
# Epoch: 885 Train loss: 0.0094032 Validation loss: 43.456
# Epoch: 886 Train loss: 0.0093999 Validation loss: 43.453
# Epoch: 887 Train loss: 0.0093967 Validation loss: 43.45
# Epoch: 888 Train loss: 0.0093934 Validation loss: 43.448
# Epoch: 889 Train loss: 0.0093901 Validation loss: 43.445
# Epoch: 890 Train loss: 0.0093869 Validation loss: 43.442
# Epoch: 891 Train loss: 0.0093836 Validation loss: 43.44
# Epoch: 892 Train loss: 0.0093804 Validation loss: 43.437
# Epoch: 893 Train loss: 0.0093771 Validation loss: 43.434
# Epoch: 894 Train loss: 0.0093739 Validation loss: 43.431
# Epoch: 895 Train loss: 0.0093706 Validation loss: 43.429
# Epoch: 896 Train loss: 0.0093674 Validation loss: 43.426
# Epoch: 897 Train loss: 0.0093642 Validation loss: 43.423
# Epoch: 898 Train loss: 0.0093609 Validation loss: 43.421
# Epoch: 899 Train loss: 0.0093577 Validation loss: 43.418
# Epoch: 900 Train loss: 0.0093545 Validation loss: 43.415
# Epoch: 901 Train loss: 0.0093512 Validation loss: 43.413
# Epoch: 902 Train loss: 0.009348 Validation loss: 43.41
# Epoch: 903 Train loss: 0.0093448 Validation loss: 43.408
# Epoch: 904 Train loss: 0.0093416 Validation loss: 43.405
# Epoch: 905 Train loss: 0.0093383 Validation loss: 43.402
# Epoch: 906 Train loss: 0.0093351 Validation loss: 43.4
# Epoch: 907 Train loss: 0.0093319 Validation loss: 43.397
# Epoch: 908 Train loss: 0.0093287 Validation loss: 43.394
# Epoch: 909 Train loss: 0.0093255 Validation loss: 43.392
# Epoch: 910 Train loss: 0.0093223 Validation loss: 43.389
# Epoch: 911 Train loss: 0.0093191 Validation loss: 43.386
# Epoch: 912 Train loss: 0.0093159 Validation loss: 43.384
# Epoch: 913 Train loss: 0.0093127 Validation loss: 43.381
# Epoch: 914 Train loss: 0.0093095 Validation loss: 43.379
# Epoch: 915 Train loss: 0.0093063 Validation loss: 43.376
# Epoch: 916 Train loss: 0.0093031 Validation loss: 43.373
# Epoch: 917 Train loss: 0.0092999 Validation loss: 43.371
# Epoch: 918 Train loss: 0.0092967 Validation loss: 43.368
# Epoch: 919 Train loss: 0.0092935 Validation loss: 43.366
# Epoch: 920 Train loss: 0.0092903 Validation loss: 43.363
# Epoch: 921 Train loss: 0.0092872 Validation loss: 43.36
# Epoch: 922 Train loss: 0.009284 Validation loss: 43.358
# Epoch: 923 Train loss: 0.0092808 Validation loss: 43.355
# Epoch: 924 Train loss: 0.0092776 Validation loss: 43.352
# Epoch: 925 Train loss: 0.0092744 Validation loss: 43.35
# Epoch: 926 Train loss: 0.0092713 Validation loss: 43.347
# Epoch: 927 Train loss: 0.0092681 Validation loss: 43.345
# Epoch: 928 Train loss: 0.0092649 Validation loss: 43.342
# Epoch: 929 Train loss: 0.0092618 Validation loss: 43.339
# Epoch: 930 Train loss: 0.0092586 Validation loss: 43.337
# Epoch: 931 Train loss: 0.0092555 Validation loss: 43.334
# Epoch: 932 Train loss: 0.0092523 Validation loss: 43.332
# Epoch: 933 Train loss: 0.0092491 Validation loss: 43.329
# Epoch: 934 Train loss: 0.009246 Validation loss: 43.327
# Epoch: 935 Train loss: 0.0092428 Validation loss: 43.324
# Epoch: 936 Train loss: 0.0092397 Validation loss: 43.322
# Epoch: 937 Train loss: 0.0092365 Validation loss: 43.319
# Epoch: 938 Train loss: 0.0092334 Validation loss: 43.316
# Epoch: 939 Train loss: 0.0092302 Validation loss: 43.314
# Epoch: 940 Train loss: 0.0092271 Validation loss: 43.311
# Epoch: 941 Train loss: 0.0092239 Validation loss: 43.309
# Epoch: 942 Train loss: 0.0092208 Validation loss: 43.306
# Epoch: 943 Train loss: 0.0092176 Validation loss: 43.304
# Epoch: 944 Train loss: 0.0092145 Validation loss: 43.301
# Epoch: 945 Train loss: 0.0092114 Validation loss: 43.298
# Epoch: 946 Train loss: 0.0092083 Validation loss: 43.296
# Epoch: 947 Train loss: 0.0092051 Validation loss: 43.293
# Epoch: 948 Train loss: 0.009202 Validation loss: 43.291
# Epoch: 949 Train loss: 0.0091989 Validation loss: 43.288
# Epoch: 950 Train loss: 0.0091957 Validation loss: 43.286
# Epoch: 951 Train loss: 0.0091926 Validation loss: 43.283
# Epoch: 952 Train loss: 0.0091895 Validation loss: 43.281
# Epoch: 953 Train loss: 0.0091864 Validation loss: 43.278
# Epoch: 954 Train loss: 0.0091832 Validation loss: 43.276
# Epoch: 955 Train loss: 0.0091801 Validation loss: 43.273
# Epoch: 956 Train loss: 0.009177 Validation loss: 43.271
# Epoch: 957 Train loss: 0.0091739 Validation loss: 43.268
# Epoch: 958 Train loss: 0.0091708 Validation loss: 43.266
# Epoch: 959 Train loss: 0.0091677 Validation loss: 43.263
# Epoch: 960 Train loss: 0.0091646 Validation loss: 43.26
# Epoch: 961 Train loss: 0.0091615 Validation loss: 43.258
# Epoch: 962 Train loss: 0.0091584 Validation loss: 43.255
# Epoch: 963 Train loss: 0.0091553 Validation loss: 43.253
# Epoch: 964 Train loss: 0.0091522 Validation loss: 43.25
# Epoch: 965 Train loss: 0.0091491 Validation loss: 43.248
# Epoch: 966 Train loss: 0.0091459 Validation loss: 43.245
# Epoch: 967 Train loss: 0.0091429 Validation loss: 43.243
# Epoch: 968 Train loss: 0.0091398 Validation loss: 43.24
# Epoch: 969 Train loss: 0.0091367 Validation loss: 43.238
# Epoch: 970 Train loss: 0.0091336 Validation loss: 43.235
# Epoch: 971 Train loss: 0.0091305 Validation loss: 43.233
# Epoch: 972 Train loss: 0.0091274 Validation loss: 43.23
# Epoch: 973 Train loss: 0.0091243 Validation loss: 43.228
# Epoch: 974 Train loss: 0.0091212 Validation loss: 43.225
# Epoch: 975 Train loss: 0.0091182 Validation loss: 43.223
# Epoch: 976 Train loss: 0.0091151 Validation loss: 43.22
# Epoch: 977 Train loss: 0.009112 Validation loss: 43.218
# Epoch: 978 Train loss: 0.0091089 Validation loss: 43.215
# Epoch: 979 Train loss: 0.0091058 Validation loss: 43.213
# Epoch: 980 Train loss: 0.0091028 Validation loss: 43.211
# Epoch: 981 Train loss: 0.0090997 Validation loss: 43.208
# Epoch: 982 Train loss: 0.0090966 Validation loss: 43.206
# Epoch: 983 Train loss: 0.0090936 Validation loss: 43.203
# Epoch: 984 Train loss: 0.0090905 Validation loss: 43.201
# Epoch: 985 Train loss: 0.0090875 Validation loss: 43.198
# Epoch: 986 Train loss: 0.0090844 Validation loss: 43.196
# Epoch: 987 Train loss: 0.0090813 Validation loss: 43.193
# Epoch: 988 Train loss: 0.0090783 Validation loss: 43.191
# Epoch: 989 Train loss: 0.0090752 Validation loss: 43.188
# Epoch: 990 Train loss: 0.0090722 Validation loss: 43.186
# Epoch: 991 Train loss: 0.0090691 Validation loss: 43.183
# Epoch: 992 Train loss: 0.0090661 Validation loss: 43.181
# Epoch: 993 Train loss: 0.009063 Validation loss: 43.178
# Epoch: 994 Train loss: 0.00906 Validation loss: 43.176
# Epoch: 995 Train loss: 0.0090569 Validation loss: 43.174
# Epoch: 996 Train loss: 0.0090539 Validation loss: 43.171
# Epoch: 997 Train loss: 0.0090509 Validation loss: 43.169
# Epoch: 998 Train loss: 0.0090478 Validation loss: 43.166
# Epoch: 999 Train loss: 0.0090448 Validation loss: 43.164

# %% [markdown]
# Predicting with this model shows overfitting. For recognizing overfitting a comparison of the validation and training loss is very useful. If the training loss decreases during training while the validation loss consistently increases, the model you are training is probably overfitting. Plotting the models prediction and the target also shows that there is a significant discrepancy between the target and the prediction of the model.

# %%
y_pred = big_mdl.__call__(x) # Predict on x with "big_mdl"
plt.scatter(x_train_overfit, y_train_overfit)
plt.plot(x, y_true)
plt.plot(x, y_pred.numpy())
plt.legend(["Target", "Prediction", "Training samples"])
plt.show()

# %% [markdown]
# In order to implement a regularization we need to modify the loss function. Since the loss function in this exercise is computed during the training step, we define a new training step with a regularization.

# %%
""" In order to avoid overfitting we implement a training step that also includes a regularization on the weights of our big model. For this we use the Frobenius/squared l2-norm of each weight matrix/vector. 
Hint: Use the tf.reduce_sum() function on a list of individual regularization terms for each matrix/vector of the network."""

def regularized_train_step(model, optimizer, x, y, lmbd):
    with tf.GradientTape() as tape:
        tape.watch(model.trainable_variables)
        y_pred = model.__call__(x) # Compute a prediction with "model" on the input "x"
        loss_val = tf.reduce_sum(tf.pow(y_pred-y, 2)) / (2 * y_pred.shape[0])# Compute the Mean Squared Error (MSE) for the prediction "y_pred" and the targets "y"
        regul_val = tf.reduce_sum([tf.reduce_sum(tf.square(d)) for d in model.trainable_variables]) # Compute the regularization based on the list "model.trainable_variables"
        total_loss = loss_val + lmbd * regul_val# Add the loss with a the regularization term weighted by "lmbd"
    grads = tape.gradient(total_loss, model.trainable_variables)
    optimizer.apply_gradients(zip(grads, model.trainable_variables))
    return loss_val

# %% [markdown]
# We can now set the strength of the regularization and retrain the big model with a regularization. We create another instance of the big model in order to compare the big model with and without regularization.

# %%
""" Implement the training for the bigger model with the regularized_train_step function. Note: We are plotting the MSE loss without the regularization in order to compare it with the unregularized model. """

lmbd = 0.005

big_reg_mdl = MyBigModel()
big_opt = tf.optimizers.SGD(learning_rate)

epoch = 0
train_iters = 0
train_loss = 0.0
# while True:
for x_t, y_t in train_overfit_ds:
  # print(x_t.shape)
  # print(y_t.shape)
  train_loss += regularized_train_step(big_reg_mdl,big_opt, x_t,y_t, lmbd)# Perform a regularized training step with the model "big_mdl" and the optimizer "big_opt" on the inputs "x_t" and the corresponding targets "y_t" with the regularization parameter being "lmbd"
  train_iters += 1
  # print(train_iters)
  if train_iters == batch_size: # An epoch is completed
    for x_v, y_v in validation_ds:
        y_pred = big_reg_mdl.__call__(x_v)# Compute a prediction with "big_mdl" on the input "x_v"
        validation_loss = tf.reduce_sum(tf.pow(y_pred-y_v, 2)) / (2 * y_pred.shape[0]) # Compute the Mean Squared Error (MSE) for the prediction "y_pred" and the targets "y_v"
    print("Epoch: {} Train loss: {:.5} Validation loss: {:.5}".format(epoch, train_loss/train_iters, validation_loss))
    train_iters = 0
    train_loss = 0.0
    train_reg = 0.0
    epoch += 1
  if (epoch == N_epochs):
        break
# Out:
# Epoch: 0 Train loss: 0.97684 Validation loss: 37.496
# Epoch: 1 Train loss: 0.16408 Validation loss: 35.27
# Epoch: 2 Train loss: 0.09988 Validation loss: 36.331
# Epoch: 3 Train loss: 0.073568 Validation loss: 37.158
# Epoch: 4 Train loss: 0.059515 Validation loss: 37.842
# Epoch: 5 Train loss: 0.051287 Validation loss: 38.386
# Epoch: 6 Train loss: 0.045842 Validation loss: 38.817
# Epoch: 7 Train loss: 0.041843 Validation loss: 39.163
# Epoch: 8 Train loss: 0.0387 Validation loss: 39.45
# Epoch: 9 Train loss: 0.036125 Validation loss: 39.694
# Epoch: 10 Train loss: 0.033957 Validation loss: 39.909
# Epoch: 11 Train loss: 0.0321 Validation loss: 40.102
# Epoch: 12 Train loss: 0.030489 Validation loss: 40.279
# Epoch: 13 Train loss: 0.029076 Validation loss: 40.442
# Epoch: 14 Train loss: 0.027827 Validation loss: 40.594
# Epoch: 15 Train loss: 0.026715 Validation loss: 40.735
# Epoch: 16 Train loss: 0.025719 Validation loss: 40.866
# Epoch: 17 Train loss: 0.024821 Validation loss: 40.988
# Epoch: 18 Train loss: 0.024006 Validation loss: 41.101
# Epoch: 19 Train loss: 0.023261 Validation loss: 41.205
# Epoch: 20 Train loss: 0.022576 Validation loss: 41.301
# Epoch: 21 Train loss: 0.021943 Validation loss: 41.388
# Epoch: 22 Train loss: 0.021352 Validation loss: 41.468
# Epoch: 23 Train loss: 0.020798 Validation loss: 41.539
# Epoch: 24 Train loss: 0.020274 Validation loss: 41.602
# Epoch: 25 Train loss: 0.019775 Validation loss: 41.657
# Epoch: 26 Train loss: 0.019297 Validation loss: 41.705
# Epoch: 27 Train loss: 0.018836 Validation loss: 41.746
# Epoch: 28 Train loss: 0.01839 Validation loss: 41.78
# Epoch: 29 Train loss: 0.017957 Validation loss: 41.807
# Epoch: 30 Train loss: 0.017536 Validation loss: 41.829
# Epoch: 31 Train loss: 0.017128 Validation loss: 41.845
# Epoch: 32 Train loss: 0.016734 Validation loss: 41.857
# Epoch: 33 Train loss: 0.016359 Validation loss: 41.866
# Epoch: 34 Train loss: 0.016006 Validation loss: 41.874
# Epoch: 35 Train loss: 0.015681 Validation loss: 41.885
# Epoch: 36 Train loss: 0.015388 Validation loss: 41.899
# Epoch: 37 Train loss: 0.015128 Validation loss: 41.918
# Epoch: 38 Train loss: 0.014899 Validation loss: 41.943
# Epoch: 39 Train loss: 0.014699 Validation loss: 41.973
# Epoch: 40 Train loss: 0.014523 Validation loss: 42.005
# Epoch: 41 Train loss: 0.014366 Validation loss: 42.039
# Epoch: 42 Train loss: 0.014226 Validation loss: 42.073
# Epoch: 43 Train loss: 0.0141 Validation loss: 42.106
# Epoch: 44 Train loss: 0.013987 Validation loss: 42.137
# Epoch: 45 Train loss: 0.013885 Validation loss: 42.165
# Epoch: 46 Train loss: 0.013793 Validation loss: 42.191
# Epoch: 47 Train loss: 0.013711 Validation loss: 42.215
# Epoch: 48 Train loss: 0.013637 Validation loss: 42.237
# Epoch: 49 Train loss: 0.013571 Validation loss: 42.256
# Epoch: 50 Train loss: 0.013511 Validation loss: 42.273
# Epoch: 51 Train loss: 0.013458 Validation loss: 42.288
# Epoch: 52 Train loss: 0.013409 Validation loss: 42.301
# Epoch: 53 Train loss: 0.013365 Validation loss: 42.313
# Epoch: 54 Train loss: 0.013325 Validation loss: 42.323
# Epoch: 55 Train loss: 0.013288 Validation loss: 42.332
# Epoch: 56 Train loss: 0.013253 Validation loss: 42.34
# Epoch: 57 Train loss: 0.013222 Validation loss: 42.346
# Epoch: 58 Train loss: 0.013192 Validation loss: 42.352
# Epoch: 59 Train loss: 0.013164 Validation loss: 42.357
# Epoch: 60 Train loss: 0.013138 Validation loss: 42.361
# Epoch: 61 Train loss: 0.013113 Validation loss: 42.364
# Epoch: 62 Train loss: 0.013089 Validation loss: 42.367
# Epoch: 63 Train loss: 0.013067 Validation loss: 42.369
# Epoch: 64 Train loss: 0.013045 Validation loss: 42.371
# Epoch: 65 Train loss: 0.013024 Validation loss: 42.372
# Epoch: 66 Train loss: 0.013004 Validation loss: 42.373
# Epoch: 67 Train loss: 0.012984 Validation loss: 42.373
# Epoch: 68 Train loss: 0.012965 Validation loss: 42.374
# Epoch: 69 Train loss: 0.012946 Validation loss: 42.374
# Epoch: 70 Train loss: 0.012927 Validation loss: 42.373
# Epoch: 71 Train loss: 0.012909 Validation loss: 42.373
# Epoch: 72 Train loss: 0.01289 Validation loss: 42.373
# Epoch: 73 Train loss: 0.012871 Validation loss: 42.372
# Epoch: 74 Train loss: 0.012853 Validation loss: 42.371
# Epoch: 75 Train loss: 0.012834 Validation loss: 42.371
# Epoch: 76 Train loss: 0.012816 Validation loss: 42.371
# Epoch: 77 Train loss: 0.012798 Validation loss: 42.371
# Epoch: 78 Train loss: 0.01278 Validation loss: 42.371
# Epoch: 79 Train loss: 0.012764 Validation loss: 42.372
# Epoch: 80 Train loss: 0.01275 Validation loss: 42.373
# Epoch: 81 Train loss: 0.012738 Validation loss: 42.375
# Epoch: 82 Train loss: 0.012729 Validation loss: 42.377
# Epoch: 83 Train loss: 0.012725 Validation loss: 42.379
# Epoch: 84 Train loss: 0.012725 Validation loss: 42.38
# Epoch: 85 Train loss: 0.01273 Validation loss: 42.381
# Epoch: 86 Train loss: 0.01274 Validation loss: 42.382
# Epoch: 87 Train loss: 0.012756 Validation loss: 42.381
# Epoch: 88 Train loss: 0.012776 Validation loss: 42.378
# Epoch: 89 Train loss: 0.0128 Validation loss: 42.375
# Epoch: 90 Train loss: 0.012828 Validation loss: 42.37
# Epoch: 91 Train loss: 0.012858 Validation loss: 42.364
# Epoch: 92 Train loss: 0.012891 Validation loss: 42.357
# Epoch: 93 Train loss: 0.012925 Validation loss: 42.35
# Epoch: 94 Train loss: 0.01296 Validation loss: 42.341
# Epoch: 95 Train loss: 0.012997 Validation loss: 42.333
# Epoch: 96 Train loss: 0.013034 Validation loss: 42.324
# Epoch: 97 Train loss: 0.013071 Validation loss: 42.315
# Epoch: 98 Train loss: 0.013108 Validation loss: 42.306
# Epoch: 99 Train loss: 0.013146 Validation loss: 42.297
# Epoch: 100 Train loss: 0.013183 Validation loss: 42.289
# Epoch: 101 Train loss: 0.01322 Validation loss: 42.281
# Epoch: 102 Train loss: 0.013258 Validation loss: 42.273
# Epoch: 103 Train loss: 0.013294 Validation loss: 42.267
# Epoch: 104 Train loss: 0.013331 Validation loss: 42.26
# Epoch: 105 Train loss: 0.013367 Validation loss: 42.255
# Epoch: 106 Train loss: 0.013403 Validation loss: 42.25
# Epoch: 107 Train loss: 0.013439 Validation loss: 42.245
# Epoch: 108 Train loss: 0.013474 Validation loss: 42.242
# Epoch: 109 Train loss: 0.013509 Validation loss: 42.239
# Epoch: 110 Train loss: 0.013544 Validation loss: 42.237
# Epoch: 111 Train loss: 0.013578 Validation loss: 42.235
# Epoch: 112 Train loss: 0.013612 Validation loss: 42.234
# Epoch: 113 Train loss: 0.013646 Validation loss: 42.234
# Epoch: 114 Train loss: 0.01368 Validation loss: 42.234
# Epoch: 115 Train loss: 0.013714 Validation loss: 42.235
# Epoch: 116 Train loss: 0.013748 Validation loss: 42.236
# Epoch: 117 Train loss: 0.013782 Validation loss: 42.238
# Epoch: 118 Train loss: 0.013816 Validation loss: 42.24
# Epoch: 119 Train loss: 0.01385 Validation loss: 42.242
# Epoch: 120 Train loss: 0.013884 Validation loss: 42.245
# Epoch: 121 Train loss: 0.013919 Validation loss: 42.249
# Epoch: 122 Train loss: 0.013954 Validation loss: 42.253
# Epoch: 123 Train loss: 0.013989 Validation loss: 42.257
# Epoch: 124 Train loss: 0.014025 Validation loss: 42.261
# Epoch: 125 Train loss: 0.014062 Validation loss: 42.266
# Epoch: 126 Train loss: 0.014099 Validation loss: 42.27
# Epoch: 127 Train loss: 0.014137 Validation loss: 42.276
# Epoch: 128 Train loss: 0.014176 Validation loss: 42.281
# Epoch: 129 Train loss: 0.014215 Validation loss: 42.287
# Epoch: 130 Train loss: 0.014254 Validation loss: 42.292
# Epoch: 131 Train loss: 0.014295 Validation loss: 42.298
# Epoch: 132 Train loss: 0.014335 Validation loss: 42.305
# Epoch: 133 Train loss: 0.014376 Validation loss: 42.311
# Epoch: 134 Train loss: 0.014418 Validation loss: 42.318
# Epoch: 135 Train loss: 0.014459 Validation loss: 42.324
# Epoch: 136 Train loss: 0.0145 Validation loss: 42.331
# Epoch: 137 Train loss: 0.014542 Validation loss: 42.338
# Epoch: 138 Train loss: 0.014583 Validation loss: 42.345
# Epoch: 139 Train loss: 0.014624 Validation loss: 42.351
# Epoch: 140 Train loss: 0.014664 Validation loss: 42.357
# Epoch: 141 Train loss: 0.014704 Validation loss: 42.363
# Epoch: 142 Train loss: 0.014743 Validation loss: 42.368
# Epoch: 143 Train loss: 0.014781 Validation loss: 42.373
# Epoch: 144 Train loss: 0.014818 Validation loss: 42.376
# Epoch: 145 Train loss: 0.014854 Validation loss: 42.378
# Epoch: 146 Train loss: 0.014889 Validation loss: 42.379
# Epoch: 147 Train loss: 0.014922 Validation loss: 42.377
# Epoch: 148 Train loss: 0.014955 Validation loss: 42.374
# Epoch: 149 Train loss: 0.014987 Validation loss: 42.368
# Epoch: 150 Train loss: 0.015018 Validation loss: 42.36
# Epoch: 151 Train loss: 0.015048 Validation loss: 42.348
# Epoch: 152 Train loss: 0.015077 Validation loss: 42.334
# Epoch: 153 Train loss: 0.015107 Validation loss: 42.317
# Epoch: 154 Train loss: 0.015137 Validation loss: 42.298
# Epoch: 155 Train loss: 0.015167 Validation loss: 42.276
# Epoch: 156 Train loss: 0.015198 Validation loss: 42.252
# Epoch: 157 Train loss: 0.015229 Validation loss: 42.227
# Epoch: 158 Train loss: 0.015262 Validation loss: 42.202
# Epoch: 159 Train loss: 0.015296 Validation loss: 42.176
# Epoch: 160 Train loss: 0.015332 Validation loss: 42.152
# Epoch: 161 Train loss: 0.015368 Validation loss: 42.129
# Epoch: 162 Train loss: 0.015405 Validation loss: 42.107
# Epoch: 163 Train loss: 0.015443 Validation loss: 42.088
# Epoch: 164 Train loss: 0.015481 Validation loss: 42.072
# Epoch: 165 Train loss: 0.015519 Validation loss: 42.058
# Epoch: 166 Train loss: 0.015557 Validation loss: 42.046
# Epoch: 167 Train loss: 0.015594 Validation loss: 42.036
# Epoch: 168 Train loss: 0.015632 Validation loss: 42.029
# Epoch: 169 Train loss: 0.015669 Validation loss: 42.024
# Epoch: 170 Train loss: 0.015705 Validation loss: 42.02
# Epoch: 171 Train loss: 0.015741 Validation loss: 42.018
# Epoch: 172 Train loss: 0.015776 Validation loss: 42.017
# Epoch: 173 Train loss: 0.015811 Validation loss: 42.017
# Epoch: 174 Train loss: 0.015845 Validation loss: 42.018
# Epoch: 175 Train loss: 0.015879 Validation loss: 42.019
# Epoch: 176 Train loss: 0.015912 Validation loss: 42.021
# Epoch: 177 Train loss: 0.015945 Validation loss: 42.023
# Epoch: 178 Train loss: 0.015978 Validation loss: 42.025
# Epoch: 179 Train loss: 0.01601 Validation loss: 42.028
# Epoch: 180 Train loss: 0.016043 Validation loss: 42.03
# Epoch: 181 Train loss: 0.016074 Validation loss: 42.033
# Epoch: 182 Train loss: 0.016106 Validation loss: 42.035
# Epoch: 183 Train loss: 0.016138 Validation loss: 42.037
# Epoch: 184 Train loss: 0.016169 Validation loss: 42.038
# Epoch: 185 Train loss: 0.0162 Validation loss: 42.04
# Epoch: 186 Train loss: 0.016231 Validation loss: 42.041
# Epoch: 187 Train loss: 0.016262 Validation loss: 42.041
# Epoch: 188 Train loss: 0.016293 Validation loss: 42.041
# Epoch: 189 Train loss: 0.016324 Validation loss: 42.041
# Epoch: 190 Train loss: 0.016355 Validation loss: 42.04
# Epoch: 191 Train loss: 0.016386 Validation loss: 42.039
# Epoch: 192 Train loss: 0.016417 Validation loss: 42.037
# Epoch: 193 Train loss: 0.016448 Validation loss: 42.034
# Epoch: 194 Train loss: 0.016479 Validation loss: 42.032
# Epoch: 195 Train loss: 0.01651 Validation loss: 42.028
# Epoch: 196 Train loss: 0.016541 Validation loss: 42.025
# Epoch: 197 Train loss: 0.016573 Validation loss: 42.021
# Epoch: 198 Train loss: 0.016604 Validation loss: 42.016
# Epoch: 199 Train loss: 0.016635 Validation loss: 42.011
# Epoch: 200 Train loss: 0.016666 Validation loss: 42.006
# Epoch: 201 Train loss: 0.016697 Validation loss: 42.0
# Epoch: 202 Train loss: 0.016728 Validation loss: 41.994
# Epoch: 203 Train loss: 0.016759 Validation loss: 41.987
# Epoch: 204 Train loss: 0.01679 Validation loss: 41.98
# Epoch: 205 Train loss: 0.016821 Validation loss: 41.973
# Epoch: 206 Train loss: 0.016852 Validation loss: 41.965
# Epoch: 207 Train loss: 0.016883 Validation loss: 41.957
# Epoch: 208 Train loss: 0.016914 Validation loss: 41.949
# Epoch: 209 Train loss: 0.016945 Validation loss: 41.94
# Epoch: 210 Train loss: 0.016976 Validation loss: 41.932
# Epoch: 211 Train loss: 0.017007 Validation loss: 41.923
# Epoch: 212 Train loss: 0.017037 Validation loss: 41.913
# Epoch: 213 Train loss: 0.017068 Validation loss: 41.904
# Epoch: 214 Train loss: 0.017098 Validation loss: 41.894
# Epoch: 215 Train loss: 0.017128 Validation loss: 41.884
# Epoch: 216 Train loss: 0.017158 Validation loss: 41.874
# Epoch: 217 Train loss: 0.017188 Validation loss: 41.864
# Epoch: 218 Train loss: 0.017217 Validation loss: 41.853
# Epoch: 219 Train loss: 0.017247 Validation loss: 41.843
# Epoch: 220 Train loss: 0.017276 Validation loss: 41.832
# Epoch: 221 Train loss: 0.017304 Validation loss: 41.821
# Epoch: 222 Train loss: 0.017333 Validation loss: 41.81
# Epoch: 223 Train loss: 0.017361 Validation loss: 41.799
# Epoch: 224 Train loss: 0.017389 Validation loss: 41.788
# Epoch: 225 Train loss: 0.017416 Validation loss: 41.777
# Epoch: 226 Train loss: 0.017443 Validation loss: 41.766
# Epoch: 227 Train loss: 0.01747 Validation loss: 41.755
# Epoch: 228 Train loss: 0.017496 Validation loss: 41.743
# Epoch: 229 Train loss: 0.017522 Validation loss: 41.732
# Epoch: 230 Train loss: 0.017547 Validation loss: 41.721
# Epoch: 231 Train loss: 0.017572 Validation loss: 41.709
# Epoch: 232 Train loss: 0.017596 Validation loss: 41.698
# Epoch: 233 Train loss: 0.01762 Validation loss: 41.687
# Epoch: 234 Train loss: 0.017644 Validation loss: 41.676
# Epoch: 235 Train loss: 0.017666 Validation loss: 41.664
# Epoch: 236 Train loss: 0.017689 Validation loss: 41.653
# Epoch: 237 Train loss: 0.01771 Validation loss: 41.642
# Epoch: 238 Train loss: 0.017732 Validation loss: 41.631
# Epoch: 239 Train loss: 0.017752 Validation loss: 41.62
# Epoch: 240 Train loss: 0.017772 Validation loss: 41.61
# Epoch: 241 Train loss: 0.017792 Validation loss: 41.599
# Epoch: 242 Train loss: 0.017811 Validation loss: 41.589
# Epoch: 243 Train loss: 0.017829 Validation loss: 41.578
# Epoch: 244 Train loss: 0.017847 Validation loss: 41.568
# Epoch: 245 Train loss: 0.017864 Validation loss: 41.558
# Epoch: 246 Train loss: 0.017881 Validation loss: 41.548
# Epoch: 247 Train loss: 0.017897 Validation loss: 41.539
# Epoch: 248 Train loss: 0.017912 Validation loss: 41.529
# Epoch: 249 Train loss: 0.017927 Validation loss: 41.52
# Epoch: 250 Train loss: 0.017942 Validation loss: 41.511
# Epoch: 251 Train loss: 0.017956 Validation loss: 41.502
# Epoch: 252 Train loss: 0.017969 Validation loss: 41.493
# Epoch: 253 Train loss: 0.017983 Validation loss: 41.485
# Epoch: 254 Train loss: 0.017995 Validation loss: 41.477
# Epoch: 255 Train loss: 0.018008 Validation loss: 41.469
# Epoch: 256 Train loss: 0.01802 Validation loss: 41.461
# Epoch: 257 Train loss: 0.018032 Validation loss: 41.453
# Epoch: 258 Train loss: 0.018043 Validation loss: 41.446
# Epoch: 259 Train loss: 0.018054 Validation loss: 41.439
# Epoch: 260 Train loss: 0.018065 Validation loss: 41.432
# Epoch: 261 Train loss: 0.018076 Validation loss: 41.425
# Epoch: 262 Train loss: 0.018086 Validation loss: 41.418
# Epoch: 263 Train loss: 0.018097 Validation loss: 41.412
# Epoch: 264 Train loss: 0.018107 Validation loss: 41.406
# Epoch: 265 Train loss: 0.018117 Validation loss: 41.4
# Epoch: 266 Train loss: 0.018127 Validation loss: 41.394
# Epoch: 267 Train loss: 0.018137 Validation loss: 41.388
# Epoch: 268 Train loss: 0.018147 Validation loss: 41.382
# Epoch: 269 Train loss: 0.018157 Validation loss: 41.377
# Epoch: 270 Train loss: 0.018167 Validation loss: 41.371
# Epoch: 271 Train loss: 0.018177 Validation loss: 41.366
# Epoch: 272 Train loss: 0.018187 Validation loss: 41.36
# Epoch: 273 Train loss: 0.018197 Validation loss: 41.355
# Epoch: 274 Train loss: 0.018207 Validation loss: 41.35
# Epoch: 275 Train loss: 0.018217 Validation loss: 41.345
# Epoch: 276 Train loss: 0.018227 Validation loss: 41.34
# Epoch: 277 Train loss: 0.018238 Validation loss: 41.335
# Epoch: 278 Train loss: 0.018248 Validation loss: 41.331
# Epoch: 279 Train loss: 0.018259 Validation loss: 41.326
# Epoch: 280 Train loss: 0.018269 Validation loss: 41.321
# Epoch: 281 Train loss: 0.01828 Validation loss: 41.317
# Epoch: 282 Train loss: 0.018291 Validation loss: 41.312
# Epoch: 283 Train loss: 0.018302 Validation loss: 41.308
# Epoch: 284 Train loss: 0.018313 Validation loss: 41.303
# Epoch: 285 Train loss: 0.018324 Validation loss: 41.299
# Epoch: 286 Train loss: 0.018335 Validation loss: 41.294
# Epoch: 287 Train loss: 0.018347 Validation loss: 41.29
# Epoch: 288 Train loss: 0.018358 Validation loss: 41.286
# Epoch: 289 Train loss: 0.018369 Validation loss: 41.281
# Epoch: 290 Train loss: 0.018381 Validation loss: 41.277
# Epoch: 291 Train loss: 0.018392 Validation loss: 41.273
# Epoch: 292 Train loss: 0.018404 Validation loss: 41.268
# Epoch: 293 Train loss: 0.018415 Validation loss: 41.264
# Epoch: 294 Train loss: 0.018426 Validation loss: 41.26
# Epoch: 295 Train loss: 0.018438 Validation loss: 41.256
# Epoch: 296 Train loss: 0.018449 Validation loss: 41.252
# Epoch: 297 Train loss: 0.01846 Validation loss: 41.248
# Epoch: 298 Train loss: 0.018472 Validation loss: 41.244
# Epoch: 299 Train loss: 0.018483 Validation loss: 41.24
# Epoch: 300 Train loss: 0.018494 Validation loss: 41.236
# Epoch: 301 Train loss: 0.018504 Validation loss: 41.232
# Epoch: 302 Train loss: 0.018515 Validation loss: 41.228
# Epoch: 303 Train loss: 0.018526 Validation loss: 41.224
# Epoch: 304 Train loss: 0.018536 Validation loss: 41.22
# Epoch: 305 Train loss: 0.018546 Validation loss: 41.216
# Epoch: 306 Train loss: 0.018556 Validation loss: 41.212
# Epoch: 307 Train loss: 0.018565 Validation loss: 41.208
# Epoch: 308 Train loss: 0.018575 Validation loss: 41.205
# Epoch: 309 Train loss: 0.018584 Validation loss: 41.201
# Epoch: 310 Train loss: 0.018593 Validation loss: 41.197
# Epoch: 311 Train loss: 0.018601 Validation loss: 41.194
# Epoch: 312 Train loss: 0.01861 Validation loss: 41.19
# Epoch: 313 Train loss: 0.018618 Validation loss: 41.186
# Epoch: 314 Train loss: 0.018625 Validation loss: 41.183
# Epoch: 315 Train loss: 0.018633 Validation loss: 41.179
# Epoch: 316 Train loss: 0.01864 Validation loss: 41.176
# Epoch: 317 Train loss: 0.018646 Validation loss: 41.172
# Epoch: 318 Train loss: 0.018652 Validation loss: 41.169
# Epoch: 319 Train loss: 0.018658 Validation loss: 41.166
# Epoch: 320 Train loss: 0.018664 Validation loss: 41.163
# Epoch: 321 Train loss: 0.018669 Validation loss: 41.16
# Epoch: 322 Train loss: 0.018674 Validation loss: 41.157
# Epoch: 323 Train loss: 0.018678 Validation loss: 41.154
# Epoch: 324 Train loss: 0.018682 Validation loss: 41.151
# Epoch: 325 Train loss: 0.018686 Validation loss: 41.148
# Epoch: 326 Train loss: 0.018689 Validation loss: 41.145
# Epoch: 327 Train loss: 0.018691 Validation loss: 41.143
# Epoch: 328 Train loss: 0.018693 Validation loss: 41.14
# Epoch: 329 Train loss: 0.018695 Validation loss: 41.138
# Epoch: 330 Train loss: 0.018696 Validation loss: 41.136
# Epoch: 331 Train loss: 0.018697 Validation loss: 41.134
# Epoch: 332 Train loss: 0.018697 Validation loss: 41.132
# Epoch: 333 Train loss: 0.018696 Validation loss: 41.13
# Epoch: 334 Train loss: 0.018695 Validation loss: 41.128
# Epoch: 335 Train loss: 0.018693 Validation loss: 41.126
# Epoch: 336 Train loss: 0.018691 Validation loss: 41.125
# Epoch: 337 Train loss: 0.018688 Validation loss: 41.123
# Epoch: 338 Train loss: 0.018684 Validation loss: 41.122
# Epoch: 339 Train loss: 0.018679 Validation loss: 41.121
# Epoch: 340 Train loss: 0.018674 Validation loss: 41.12
# Epoch: 341 Train loss: 0.018668 Validation loss: 41.119
# Epoch: 342 Train loss: 0.018661 Validation loss: 41.118
# Epoch: 343 Train loss: 0.018654 Validation loss: 41.117
# Epoch: 344 Train loss: 0.018645 Validation loss: 41.116
# Epoch: 345 Train loss: 0.018636 Validation loss: 41.115
# Epoch: 346 Train loss: 0.018626 Validation loss: 41.114
# Epoch: 347 Train loss: 0.018615 Validation loss: 41.114
# Epoch: 348 Train loss: 0.018603 Validation loss: 41.113
# Epoch: 349 Train loss: 0.018591 Validation loss: 41.112
# Epoch: 350 Train loss: 0.018577 Validation loss: 41.111
# Epoch: 351 Train loss: 0.018563 Validation loss: 41.11
# Epoch: 352 Train loss: 0.018549 Validation loss: 41.109
# Epoch: 353 Train loss: 0.018533 Validation loss: 41.108
# Epoch: 354 Train loss: 0.018517 Validation loss: 41.107
# Epoch: 355 Train loss: 0.0185 Validation loss: 41.105
# Epoch: 356 Train loss: 0.018483 Validation loss: 41.104
# Epoch: 357 Train loss: 0.018465 Validation loss: 41.102
# Epoch: 358 Train loss: 0.018447 Validation loss: 41.1
# Epoch: 359 Train loss: 0.018428 Validation loss: 41.098
# Epoch: 360 Train loss: 0.01841 Validation loss: 41.096
# Epoch: 361 Train loss: 0.018391 Validation loss: 41.094
# Epoch: 362 Train loss: 0.018371 Validation loss: 41.091
# Epoch: 363 Train loss: 0.018352 Validation loss: 41.089
# Epoch: 364 Train loss: 0.018333 Validation loss: 41.086
# Epoch: 365 Train loss: 0.018314 Validation loss: 41.083
# Epoch: 366 Train loss: 0.018295 Validation loss: 41.08
# Epoch: 367 Train loss: 0.018277 Validation loss: 41.078
# Epoch: 368 Train loss: 0.018258 Validation loss: 41.075
# Epoch: 369 Train loss: 0.01824 Validation loss: 41.072
# Epoch: 370 Train loss: 0.018223 Validation loss: 41.069
# Epoch: 371 Train loss: 0.018205 Validation loss: 41.067
# Epoch: 372 Train loss: 0.018188 Validation loss: 41.064
# Epoch: 373 Train loss: 0.018172 Validation loss: 41.062
# Epoch: 374 Train loss: 0.018156 Validation loss: 41.059
# Epoch: 375 Train loss: 0.01814 Validation loss: 41.058
# Epoch: 376 Train loss: 0.018125 Validation loss: 41.056
# Epoch: 377 Train loss: 0.01811 Validation loss: 41.054
# Epoch: 378 Train loss: 0.018095 Validation loss: 41.053
# Epoch: 379 Train loss: 0.018081 Validation loss: 41.052
# Epoch: 380 Train loss: 0.018067 Validation loss: 41.051
# Epoch: 381 Train loss: 0.018053 Validation loss: 41.051
# Epoch: 382 Train loss: 0.018039 Validation loss: 41.051
# Epoch: 383 Train loss: 0.018025 Validation loss: 41.051
# Epoch: 384 Train loss: 0.018012 Validation loss: 41.052
# Epoch: 385 Train loss: 0.017998 Validation loss: 41.053
# Epoch: 386 Train loss: 0.017985 Validation loss: 41.054
# Epoch: 387 Train loss: 0.017971 Validation loss: 41.055
# Epoch: 388 Train loss: 0.017957 Validation loss: 41.056
# Epoch: 389 Train loss: 0.017944 Validation loss: 41.058
# Epoch: 390 Train loss: 0.01793 Validation loss: 41.06
# Epoch: 391 Train loss: 0.017916 Validation loss: 41.062
# Epoch: 392 Train loss: 0.017902 Validation loss: 41.065
# Epoch: 393 Train loss: 0.017888 Validation loss: 41.067
# Epoch: 394 Train loss: 0.017873 Validation loss: 41.069
# Epoch: 395 Train loss: 0.017858 Validation loss: 41.072
# Epoch: 396 Train loss: 0.017844 Validation loss: 41.075
# Epoch: 397 Train loss: 0.017829 Validation loss: 41.077
# Epoch: 398 Train loss: 0.017814 Validation loss: 41.08
# Epoch: 399 Train loss: 0.017799 Validation loss: 41.083
# Epoch: 400 Train loss: 0.017783 Validation loss: 41.085
# Epoch: 401 Train loss: 0.017768 Validation loss: 41.088
# Epoch: 402 Train loss: 0.017753 Validation loss: 41.09
# Epoch: 403 Train loss: 0.017737 Validation loss: 41.092
# Epoch: 404 Train loss: 0.017722 Validation loss: 41.095
# Epoch: 405 Train loss: 0.017707 Validation loss: 41.097
# Epoch: 406 Train loss: 0.017692 Validation loss: 41.099
# Epoch: 407 Train loss: 0.017677 Validation loss: 41.101
# Epoch: 408 Train loss: 0.017662 Validation loss: 41.102
# Epoch: 409 Train loss: 0.017647 Validation loss: 41.104
# Epoch: 410 Train loss: 0.017633 Validation loss: 41.105
# Epoch: 411 Train loss: 0.017619 Validation loss: 41.106
# Epoch: 412 Train loss: 0.017605 Validation loss: 41.107
# Epoch: 413 Train loss: 0.017591 Validation loss: 41.108
# Epoch: 414 Train loss: 0.017577 Validation loss: 41.109
# Epoch: 415 Train loss: 0.017564 Validation loss: 41.11
# Epoch: 416 Train loss: 0.01755 Validation loss: 41.11
# Epoch: 417 Train loss: 0.017537 Validation loss: 41.111
# Epoch: 418 Train loss: 0.017524 Validation loss: 41.111
# Epoch: 419 Train loss: 0.017512 Validation loss: 41.111
# Epoch: 420 Train loss: 0.017499 Validation loss: 41.111
# Epoch: 421 Train loss: 0.017487 Validation loss: 41.111
# Epoch: 422 Train loss: 0.017475 Validation loss: 41.111
# Epoch: 423 Train loss: 0.017463 Validation loss: 41.111
# Epoch: 424 Train loss: 0.017451 Validation loss: 41.11
# Epoch: 425 Train loss: 0.017439 Validation loss: 41.11
# Epoch: 426 Train loss: 0.017427 Validation loss: 41.11
# Epoch: 427 Train loss: 0.017416 Validation loss: 41.109
# Epoch: 428 Train loss: 0.017404 Validation loss: 41.109
# Epoch: 429 Train loss: 0.017392 Validation loss: 41.108
# Epoch: 430 Train loss: 0.017381 Validation loss: 41.107
# Epoch: 431 Train loss: 0.017369 Validation loss: 41.107
# Epoch: 432 Train loss: 0.017358 Validation loss: 41.106
# Epoch: 433 Train loss: 0.017346 Validation loss: 41.105
# Epoch: 434 Train loss: 0.017334 Validation loss: 41.104
# Epoch: 435 Train loss: 0.017323 Validation loss: 41.103
# Epoch: 436 Train loss: 0.017311 Validation loss: 41.103
# Epoch: 437 Train loss: 0.017299 Validation loss: 41.102
# Epoch: 438 Train loss: 0.017287 Validation loss: 41.101
# Epoch: 439 Train loss: 0.017275 Validation loss: 41.1
# Epoch: 440 Train loss: 0.017263 Validation loss: 41.099
# Epoch: 441 Train loss: 0.017251 Validation loss: 41.098
# Epoch: 442 Train loss: 0.017239 Validation loss: 41.097
# Epoch: 443 Train loss: 0.017227 Validation loss: 41.096
# Epoch: 444 Train loss: 0.017214 Validation loss: 41.095
# Epoch: 445 Train loss: 0.017202 Validation loss: 41.094
# Epoch: 446 Train loss: 0.01719 Validation loss: 41.093
# Epoch: 447 Train loss: 0.017177 Validation loss: 41.092
# Epoch: 448 Train loss: 0.017164 Validation loss: 41.091
# Epoch: 449 Train loss: 0.017152 Validation loss: 41.089
# Epoch: 450 Train loss: 0.017139 Validation loss: 41.088
# Epoch: 451 Train loss: 0.017126 Validation loss: 41.087
# Epoch: 452 Train loss: 0.017113 Validation loss: 41.086
# Epoch: 453 Train loss: 0.0171 Validation loss: 41.085
# Epoch: 454 Train loss: 0.017087 Validation loss: 41.083
# Epoch: 455 Train loss: 0.017074 Validation loss: 41.082
# Epoch: 456 Train loss: 0.017061 Validation loss: 41.081
# Epoch: 457 Train loss: 0.017048 Validation loss: 41.08
# Epoch: 458 Train loss: 0.017035 Validation loss: 41.078
# Epoch: 459 Train loss: 0.017022 Validation loss: 41.077
# Epoch: 460 Train loss: 0.017009 Validation loss: 41.076
# Epoch: 461 Train loss: 0.016996 Validation loss: 41.074
# Epoch: 462 Train loss: 0.016983 Validation loss: 41.073
# Epoch: 463 Train loss: 0.016969 Validation loss: 41.071
# Epoch: 464 Train loss: 0.016956 Validation loss: 41.07
# Epoch: 465 Train loss: 0.016943 Validation loss: 41.068
# Epoch: 466 Train loss: 0.01693 Validation loss: 41.067
# Epoch: 467 Train loss: 0.016917 Validation loss: 41.065
# Epoch: 468 Train loss: 0.016903 Validation loss: 41.063
# Epoch: 469 Train loss: 0.01689 Validation loss: 41.062
# Epoch: 470 Train loss: 0.016877 Validation loss: 41.06
# Epoch: 471 Train loss: 0.016864 Validation loss: 41.058
# Epoch: 472 Train loss: 0.016851 Validation loss: 41.057
# Epoch: 473 Train loss: 0.016838 Validation loss: 41.055
# Epoch: 474 Train loss: 0.016825 Validation loss: 41.053
# Epoch: 475 Train loss: 0.016812 Validation loss: 41.051
# Epoch: 476 Train loss: 0.016799 Validation loss: 41.049
# Epoch: 477 Train loss: 0.016786 Validation loss: 41.048
# Epoch: 478 Train loss: 0.016773 Validation loss: 41.046
# Epoch: 479 Train loss: 0.01676 Validation loss: 41.044
# Epoch: 480 Train loss: 0.016747 Validation loss: 41.042
# Epoch: 481 Train loss: 0.016735 Validation loss: 41.04
# Epoch: 482 Train loss: 0.016722 Validation loss: 41.038
# Epoch: 483 Train loss: 0.016709 Validation loss: 41.035
# Epoch: 484 Train loss: 0.016697 Validation loss: 41.033
# Epoch: 485 Train loss: 0.016684 Validation loss: 41.031
# Epoch: 486 Train loss: 0.016672 Validation loss: 41.029
# Epoch: 487 Train loss: 0.01666 Validation loss: 41.027
# Epoch: 488 Train loss: 0.016647 Validation loss: 41.024
# Epoch: 489 Train loss: 0.016635 Validation loss: 41.022
# Epoch: 490 Train loss: 0.016623 Validation loss: 41.02
# Epoch: 491 Train loss: 0.016611 Validation loss: 41.017
# Epoch: 492 Train loss: 0.016599 Validation loss: 41.015
# Epoch: 493 Train loss: 0.016587 Validation loss: 41.013
# Epoch: 494 Train loss: 0.016575 Validation loss: 41.01
# Epoch: 495 Train loss: 0.016563 Validation loss: 41.008
# Epoch: 496 Train loss: 0.016551 Validation loss: 41.005
# Epoch: 497 Train loss: 0.016539 Validation loss: 41.003
# Epoch: 498 Train loss: 0.016528 Validation loss: 41.0
# Epoch: 499 Train loss: 0.016516 Validation loss: 40.997
# Epoch: 500 Train loss: 0.016505 Validation loss: 40.995
# Epoch: 501 Train loss: 0.016493 Validation loss: 40.992
# Epoch: 502 Train loss: 0.016482 Validation loss: 40.989
# Epoch: 503 Train loss: 0.016471 Validation loss: 40.987
# Epoch: 504 Train loss: 0.016459 Validation loss: 40.984
# Epoch: 505 Train loss: 0.016448 Validation loss: 40.981
# Epoch: 506 Train loss: 0.016437 Validation loss: 40.978
# Epoch: 507 Train loss: 0.016426 Validation loss: 40.975
# Epoch: 508 Train loss: 0.016415 Validation loss: 40.973
# Epoch: 509 Train loss: 0.016404 Validation loss: 40.97
# Epoch: 510 Train loss: 0.016394 Validation loss: 40.967
# Epoch: 511 Train loss: 0.016383 Validation loss: 40.964
# Epoch: 512 Train loss: 0.016372 Validation loss: 40.961
# Epoch: 513 Train loss: 0.016362 Validation loss: 40.958
# Epoch: 514 Train loss: 0.016351 Validation loss: 40.955
# Epoch: 515 Train loss: 0.016341 Validation loss: 40.952
# Epoch: 516 Train loss: 0.01633 Validation loss: 40.949
# Epoch: 517 Train loss: 0.01632 Validation loss: 40.946
# Epoch: 518 Train loss: 0.01631 Validation loss: 40.942
# Epoch: 519 Train loss: 0.0163 Validation loss: 40.939
# Epoch: 520 Train loss: 0.01629 Validation loss: 40.936
# Epoch: 521 Train loss: 0.01628 Validation loss: 40.933
# Epoch: 522 Train loss: 0.01627 Validation loss: 40.93
# Epoch: 523 Train loss: 0.01626 Validation loss: 40.927
# Epoch: 524 Train loss: 0.01625 Validation loss: 40.923
# Epoch: 525 Train loss: 0.016241 Validation loss: 40.92
# Epoch: 526 Train loss: 0.016231 Validation loss: 40.917
# Epoch: 527 Train loss: 0.016222 Validation loss: 40.914
# Epoch: 528 Train loss: 0.016212 Validation loss: 40.91
# Epoch: 529 Train loss: 0.016203 Validation loss: 40.907
# Epoch: 530 Train loss: 0.016193 Validation loss: 40.904
# Epoch: 531 Train loss: 0.016184 Validation loss: 40.9
# Epoch: 532 Train loss: 0.016175 Validation loss: 40.897
# Epoch: 533 Train loss: 0.016166 Validation loss: 40.893
# Epoch: 534 Train loss: 0.016157 Validation loss: 40.89
# Epoch: 535 Train loss: 0.016148 Validation loss: 40.887
# Epoch: 536 Train loss: 0.016139 Validation loss: 40.883
# Epoch: 537 Train loss: 0.01613 Validation loss: 40.88
# Epoch: 538 Train loss: 0.016121 Validation loss: 40.876
# Epoch: 539 Train loss: 0.016112 Validation loss: 40.873
# Epoch: 540 Train loss: 0.016104 Validation loss: 40.869
# Epoch: 541 Train loss: 0.016095 Validation loss: 40.866
# Epoch: 542 Train loss: 0.016087 Validation loss: 40.863
# Epoch: 543 Train loss: 0.016078 Validation loss: 40.859
# Epoch: 544 Train loss: 0.01607 Validation loss: 40.855
# Epoch: 545 Train loss: 0.016062 Validation loss: 40.852
# Epoch: 546 Train loss: 0.016053 Validation loss: 40.848
# Epoch: 547 Train loss: 0.016045 Validation loss: 40.845
# Epoch: 548 Train loss: 0.016037 Validation loss: 40.841
# Epoch: 549 Train loss: 0.016029 Validation loss: 40.838
# Epoch: 550 Train loss: 0.016021 Validation loss: 40.834
# Epoch: 551 Train loss: 0.016013 Validation loss: 40.831
# Epoch: 552 Train loss: 0.016005 Validation loss: 40.827
# Epoch: 553 Train loss: 0.015997 Validation loss: 40.824
# Epoch: 554 Train loss: 0.01599 Validation loss: 40.82
# Epoch: 555 Train loss: 0.015982 Validation loss: 40.816
# Epoch: 556 Train loss: 0.015975 Validation loss: 40.813
# Epoch: 557 Train loss: 0.015967 Validation loss: 40.809
# Epoch: 558 Train loss: 0.01596 Validation loss: 40.806
# Epoch: 559 Train loss: 0.015952 Validation loss: 40.802
# Epoch: 560 Train loss: 0.015945 Validation loss: 40.799
# Epoch: 561 Train loss: 0.015938 Validation loss: 40.795
# Epoch: 562 Train loss: 0.015931 Validation loss: 40.791
# Epoch: 563 Train loss: 0.015923 Validation loss: 40.788
# Epoch: 564 Train loss: 0.015916 Validation loss: 40.784
# Epoch: 565 Train loss: 0.015909 Validation loss: 40.781
# Epoch: 566 Train loss: 0.015902 Validation loss: 40.777
# Epoch: 567 Train loss: 0.015896 Validation loss: 40.773
# Epoch: 568 Train loss: 0.015889 Validation loss: 40.77
# Epoch: 569 Train loss: 0.015882 Validation loss: 40.766
# Epoch: 570 Train loss: 0.015875 Validation loss: 40.763
# Epoch: 571 Train loss: 0.015869 Validation loss: 40.759
# Epoch: 572 Train loss: 0.015862 Validation loss: 40.756
# Epoch: 573 Train loss: 0.015856 Validation loss: 40.752
# Epoch: 574 Train loss: 0.015849 Validation loss: 40.748
# Epoch: 575 Train loss: 0.015843 Validation loss: 40.745
# Epoch: 576 Train loss: 0.015837 Validation loss: 40.741
# Epoch: 577 Train loss: 0.015831 Validation loss: 40.738
# Epoch: 578 Train loss: 0.015824 Validation loss: 40.734
# Epoch: 579 Train loss: 0.015818 Validation loss: 40.731
# Epoch: 580 Train loss: 0.015812 Validation loss: 40.727
# Epoch: 581 Train loss: 0.015806 Validation loss: 40.724
# Epoch: 582 Train loss: 0.0158 Validation loss: 40.72
# Epoch: 583 Train loss: 0.015794 Validation loss: 40.717
# Epoch: 584 Train loss: 0.015789 Validation loss: 40.713
# Epoch: 585 Train loss: 0.015783 Validation loss: 40.709
# Epoch: 586 Train loss: 0.015777 Validation loss: 40.706
# Epoch: 587 Train loss: 0.015771 Validation loss: 40.702
# Epoch: 588 Train loss: 0.015766 Validation loss: 40.699
# Epoch: 589 Train loss: 0.01576 Validation loss: 40.695
# Epoch: 590 Train loss: 0.015755 Validation loss: 40.692
# Epoch: 591 Train loss: 0.01575 Validation loss: 40.689
# Epoch: 592 Train loss: 0.015744 Validation loss: 40.685
# Epoch: 593 Train loss: 0.015739 Validation loss: 40.682
# Epoch: 594 Train loss: 0.015734 Validation loss: 40.678
# Epoch: 595 Train loss: 0.015729 Validation loss: 40.675
# Epoch: 596 Train loss: 0.015724 Validation loss: 40.671
# Epoch: 597 Train loss: 0.015719 Validation loss: 40.668
# Epoch: 598 Train loss: 0.015714 Validation loss: 40.664
# Epoch: 599 Train loss: 0.015709 Validation loss: 40.661
# Epoch: 600 Train loss: 0.015704 Validation loss: 40.658
# Epoch: 601 Train loss: 0.015699 Validation loss: 40.654
# Epoch: 602 Train loss: 0.015694 Validation loss: 40.651
# Epoch: 603 Train loss: 0.015689 Validation loss: 40.648
# Epoch: 604 Train loss: 0.015685 Validation loss: 40.644
# Epoch: 605 Train loss: 0.01568 Validation loss: 40.641
# Epoch: 606 Train loss: 0.015676 Validation loss: 40.638
# Epoch: 607 Train loss: 0.015671 Validation loss: 40.634
# Epoch: 608 Train loss: 0.015667 Validation loss: 40.631
# Epoch: 609 Train loss: 0.015662 Validation loss: 40.628
# Epoch: 610 Train loss: 0.015658 Validation loss: 40.624
# Epoch: 611 Train loss: 0.015654 Validation loss: 40.621
# Epoch: 612 Train loss: 0.01565 Validation loss: 40.618
# Epoch: 613 Train loss: 0.015645 Validation loss: 40.615
# Epoch: 614 Train loss: 0.015641 Validation loss: 40.611
# Epoch: 615 Train loss: 0.015637 Validation loss: 40.608
# Epoch: 616 Train loss: 0.015633 Validation loss: 40.605
# Epoch: 617 Train loss: 0.015629 Validation loss: 40.602
# Epoch: 618 Train loss: 0.015625 Validation loss: 40.599
# Epoch: 619 Train loss: 0.015622 Validation loss: 40.595
# Epoch: 620 Train loss: 0.015618 Validation loss: 40.592
# Epoch: 621 Train loss: 0.015614 Validation loss: 40.589
# Epoch: 622 Train loss: 0.01561 Validation loss: 40.586
# Epoch: 623 Train loss: 0.015607 Validation loss: 40.583
# Epoch: 624 Train loss: 0.015603 Validation loss: 40.58
# Epoch: 625 Train loss: 0.0156 Validation loss: 40.577
# Epoch: 626 Train loss: 0.015596 Validation loss: 40.573
# Epoch: 627 Train loss: 0.015593 Validation loss: 40.57
# Epoch: 628 Train loss: 0.015589 Validation loss: 40.567
# Epoch: 629 Train loss: 0.015586 Validation loss: 40.564
# Epoch: 630 Train loss: 0.015583 Validation loss: 40.561
# Epoch: 631 Train loss: 0.015579 Validation loss: 40.558
# Epoch: 632 Train loss: 0.015576 Validation loss: 40.555
# Epoch: 633 Train loss: 0.015573 Validation loss: 40.552
# Epoch: 634 Train loss: 0.01557 Validation loss: 40.549
# Epoch: 635 Train loss: 0.015567 Validation loss: 40.546
# Epoch: 636 Train loss: 0.015564 Validation loss: 40.543
# Epoch: 637 Train loss: 0.015561 Validation loss: 40.54
# Epoch: 638 Train loss: 0.015558 Validation loss: 40.538
# Epoch: 639 Train loss: 0.015555 Validation loss: 40.535
# Epoch: 640 Train loss: 0.015552 Validation loss: 40.532
# Epoch: 641 Train loss: 0.015549 Validation loss: 40.529
# Epoch: 642 Train loss: 0.015547 Validation loss: 40.526
# Epoch: 643 Train loss: 0.015544 Validation loss: 40.523
# Epoch: 644 Train loss: 0.015541 Validation loss: 40.52
# Epoch: 645 Train loss: 0.015539 Validation loss: 40.517
# Epoch: 646 Train loss: 0.015536 Validation loss: 40.515
# Epoch: 647 Train loss: 0.015534 Validation loss: 40.512
# Epoch: 648 Train loss: 0.015531 Validation loss: 40.509
# Epoch: 649 Train loss: 0.015529 Validation loss: 40.506
# Epoch: 650 Train loss: 0.015526 Validation loss: 40.503
# Epoch: 651 Train loss: 0.015524 Validation loss: 40.501
# Epoch: 652 Train loss: 0.015522 Validation loss: 40.498
# Epoch: 653 Train loss: 0.01552 Validation loss: 40.495
# Epoch: 654 Train loss: 0.015517 Validation loss: 40.492
# Epoch: 655 Train loss: 0.015515 Validation loss: 40.49
# Epoch: 656 Train loss: 0.015513 Validation loss: 40.487
# Epoch: 657 Train loss: 0.015511 Validation loss: 40.484
# Epoch: 658 Train loss: 0.015509 Validation loss: 40.482
# Epoch: 659 Train loss: 0.015507 Validation loss: 40.479
# Epoch: 660 Train loss: 0.015505 Validation loss: 40.476
# Epoch: 661 Train loss: 0.015503 Validation loss: 40.474
# Epoch: 662 Train loss: 0.015501 Validation loss: 40.471
# Epoch: 663 Train loss: 0.015499 Validation loss: 40.469
# Epoch: 664 Train loss: 0.015497 Validation loss: 40.466
# Epoch: 665 Train loss: 0.015496 Validation loss: 40.463
# Epoch: 666 Train loss: 0.015494 Validation loss: 40.461
# Epoch: 667 Train loss: 0.015492 Validation loss: 40.458
# Epoch: 668 Train loss: 0.015491 Validation loss: 40.456
# Epoch: 669 Train loss: 0.015489 Validation loss: 40.453
# Epoch: 670 Train loss: 0.015487 Validation loss: 40.451
# Epoch: 671 Train loss: 0.015486 Validation loss: 40.448
# Epoch: 672 Train loss: 0.015484 Validation loss: 40.446
# Epoch: 673 Train loss: 0.015483 Validation loss: 40.443
# Epoch: 674 Train loss: 0.015481 Validation loss: 40.441
# Epoch: 675 Train loss: 0.01548 Validation loss: 40.438
# Epoch: 676 Train loss: 0.015478 Validation loss: 40.436
# Epoch: 677 Train loss: 0.015477 Validation loss: 40.434
# Epoch: 678 Train loss: 0.015476 Validation loss: 40.431
# Epoch: 679 Train loss: 0.015475 Validation loss: 40.429
# Epoch: 680 Train loss: 0.015473 Validation loss: 40.427
# Epoch: 681 Train loss: 0.015472 Validation loss: 40.424
# Epoch: 682 Train loss: 0.015471 Validation loss: 40.422
# Epoch: 683 Train loss: 0.01547 Validation loss: 40.419
# Epoch: 684 Train loss: 0.015468 Validation loss: 40.417
# Epoch: 685 Train loss: 0.015467 Validation loss: 40.415
# Epoch: 686 Train loss: 0.015466 Validation loss: 40.413
# Epoch: 687 Train loss: 0.015465 Validation loss: 40.41
# Epoch: 688 Train loss: 0.015464 Validation loss: 40.408
# Epoch: 689 Train loss: 0.015463 Validation loss: 40.406
# Epoch: 690 Train loss: 0.015462 Validation loss: 40.403
# Epoch: 691 Train loss: 0.015461 Validation loss: 40.401
# Epoch: 692 Train loss: 0.01546 Validation loss: 40.399
# Epoch: 693 Train loss: 0.015459 Validation loss: 40.397
# Epoch: 694 Train loss: 0.015459 Validation loss: 40.395
# Epoch: 695 Train loss: 0.015458 Validation loss: 40.392
# Epoch: 696 Train loss: 0.015457 Validation loss: 40.39
# Epoch: 697 Train loss: 0.015456 Validation loss: 40.388
# Epoch: 698 Train loss: 0.015455 Validation loss: 40.386
# Epoch: 699 Train loss: 0.015455 Validation loss: 40.384
# Epoch: 700 Train loss: 0.015454 Validation loss: 40.382
# Epoch: 701 Train loss: 0.015453 Validation loss: 40.379
# Epoch: 702 Train loss: 0.015453 Validation loss: 40.377
# Epoch: 703 Train loss: 0.015452 Validation loss: 40.375
# Epoch: 704 Train loss: 0.015452 Validation loss: 40.373
# Epoch: 705 Train loss: 0.015451 Validation loss: 40.371
# Epoch: 706 Train loss: 0.015451 Validation loss: 40.369
# Epoch: 707 Train loss: 0.01545 Validation loss: 40.367
# Epoch: 708 Train loss: 0.01545 Validation loss: 40.365
# Epoch: 709 Train loss: 0.015449 Validation loss: 40.363
# Epoch: 710 Train loss: 0.015449 Validation loss: 40.361
# Epoch: 711 Train loss: 0.015448 Validation loss: 40.359
# Epoch: 712 Train loss: 0.015448 Validation loss: 40.357
# Epoch: 713 Train loss: 0.015447 Validation loss: 40.355
# Epoch: 714 Train loss: 0.015447 Validation loss: 40.353
# Epoch: 715 Train loss: 0.015447 Validation loss: 40.351
# Epoch: 716 Train loss: 0.015446 Validation loss: 40.349
# Epoch: 717 Train loss: 0.015446 Validation loss: 40.347
# Epoch: 718 Train loss: 0.015446 Validation loss: 40.345
# Epoch: 719 Train loss: 0.015446 Validation loss: 40.343
# Epoch: 720 Train loss: 0.015445 Validation loss: 40.341
# Epoch: 721 Train loss: 0.015445 Validation loss: 40.339
# Epoch: 722 Train loss: 0.015445 Validation loss: 40.337
# Epoch: 723 Train loss: 0.015445 Validation loss: 40.335
# Epoch: 724 Train loss: 0.015444 Validation loss: 40.333
# Epoch: 725 Train loss: 0.015444 Validation loss: 40.332
# Epoch: 726 Train loss: 0.015444 Validation loss: 40.33
# Epoch: 727 Train loss: 0.015444 Validation loss: 40.328
# Epoch: 728 Train loss: 0.015444 Validation loss: 40.326
# Epoch: 729 Train loss: 0.015444 Validation loss: 40.324
# Epoch: 730 Train loss: 0.015444 Validation loss: 40.322
# Epoch: 731 Train loss: 0.015444 Validation loss: 40.32
# Epoch: 732 Train loss: 0.015444 Validation loss: 40.319
# Epoch: 733 Train loss: 0.015444 Validation loss: 40.317
# Epoch: 734 Train loss: 0.015444 Validation loss: 40.315
# Epoch: 735 Train loss: 0.015444 Validation loss: 40.313
# Epoch: 736 Train loss: 0.015444 Validation loss: 40.311
# Epoch: 737 Train loss: 0.015444 Validation loss: 40.31
# Epoch: 738 Train loss: 0.015444 Validation loss: 40.308
# Epoch: 739 Train loss: 0.015444 Validation loss: 40.306
# Epoch: 740 Train loss: 0.015444 Validation loss: 40.304
# Epoch: 741 Train loss: 0.015444 Validation loss: 40.303
# Epoch: 742 Train loss: 0.015444 Validation loss: 40.301
# Epoch: 743 Train loss: 0.015444 Validation loss: 40.299
# Epoch: 744 Train loss: 0.015444 Validation loss: 40.297
# Epoch: 745 Train loss: 0.015444 Validation loss: 40.296
# Epoch: 746 Train loss: 0.015444 Validation loss: 40.294
# Epoch: 747 Train loss: 0.015445 Validation loss: 40.292
# Epoch: 748 Train loss: 0.015445 Validation loss: 40.291
# Epoch: 749 Train loss: 0.015445 Validation loss: 40.289
# Epoch: 750 Train loss: 0.015445 Validation loss: 40.287
# Epoch: 751 Train loss: 0.015445 Validation loss: 40.286
# Epoch: 752 Train loss: 0.015446 Validation loss: 40.284
# Epoch: 753 Train loss: 0.015446 Validation loss: 40.282
# Epoch: 754 Train loss: 0.015446 Validation loss: 40.281
# Epoch: 755 Train loss: 0.015446 Validation loss: 40.279
# Epoch: 756 Train loss: 0.015446 Validation loss: 40.278
# Epoch: 757 Train loss: 0.015447 Validation loss: 40.276
# Epoch: 758 Train loss: 0.015447 Validation loss: 40.274
# Epoch: 759 Train loss: 0.015447 Validation loss: 40.273
# Epoch: 760 Train loss: 0.015447 Validation loss: 40.271
# Epoch: 761 Train loss: 0.015448 Validation loss: 40.269
# Epoch: 762 Train loss: 0.015448 Validation loss: 40.268
# Epoch: 763 Train loss: 0.015448 Validation loss: 40.266
# Epoch: 764 Train loss: 0.015449 Validation loss: 40.265
# Epoch: 765 Train loss: 0.015449 Validation loss: 40.263
# Epoch: 766 Train loss: 0.015449 Validation loss: 40.262
# Epoch: 767 Train loss: 0.01545 Validation loss: 40.26
# Epoch: 768 Train loss: 0.01545 Validation loss: 40.259
# Epoch: 769 Train loss: 0.01545 Validation loss: 40.257
# Epoch: 770 Train loss: 0.015451 Validation loss: 40.256
# Epoch: 771 Train loss: 0.015451 Validation loss: 40.254
# Epoch: 772 Train loss: 0.015451 Validation loss: 40.252
# Epoch: 773 Train loss: 0.015451 Validation loss: 40.251
# Epoch: 774 Train loss: 0.015452 Validation loss: 40.25
# Epoch: 775 Train loss: 0.015452 Validation loss: 40.248
# Epoch: 776 Train loss: 0.015453 Validation loss: 40.247
# Epoch: 777 Train loss: 0.015453 Validation loss: 40.245
# Epoch: 778 Train loss: 0.015453 Validation loss: 40.244
# Epoch: 779 Train loss: 0.015454 Validation loss: 40.242
# Epoch: 780 Train loss: 0.015454 Validation loss: 40.241
# Epoch: 781 Train loss: 0.015454 Validation loss: 40.239
# Epoch: 782 Train loss: 0.015455 Validation loss: 40.238
# Epoch: 783 Train loss: 0.015455 Validation loss: 40.236
# Epoch: 784 Train loss: 0.015456 Validation loss: 40.235
# Epoch: 785 Train loss: 0.015456 Validation loss: 40.233
# Epoch: 786 Train loss: 0.015456 Validation loss: 40.232
# Epoch: 787 Train loss: 0.015457 Validation loss: 40.231
# Epoch: 788 Train loss: 0.015457 Validation loss: 40.229
# Epoch: 789 Train loss: 0.015457 Validation loss: 40.228
# Epoch: 790 Train loss: 0.015458 Validation loss: 40.226
# Epoch: 791 Train loss: 0.015458 Validation loss: 40.225
# Epoch: 792 Train loss: 0.015459 Validation loss: 40.224
# Epoch: 793 Train loss: 0.015459 Validation loss: 40.222
# Epoch: 794 Train loss: 0.015459 Validation loss: 40.221
# Epoch: 795 Train loss: 0.01546 Validation loss: 40.22
# Epoch: 796 Train loss: 0.01546 Validation loss: 40.218
# Epoch: 797 Train loss: 0.015461 Validation loss: 40.217
# Epoch: 798 Train loss: 0.015461 Validation loss: 40.215
# Epoch: 799 Train loss: 0.015462 Validation loss: 40.214
# Epoch: 800 Train loss: 0.015462 Validation loss: 40.213
# Epoch: 801 Train loss: 0.015462 Validation loss: 40.211
# Epoch: 802 Train loss: 0.015463 Validation loss: 40.21
# Epoch: 803 Train loss: 0.015463 Validation loss: 40.209
# Epoch: 804 Train loss: 0.015464 Validation loss: 40.207
# Epoch: 805 Train loss: 0.015464 Validation loss: 40.206
# Epoch: 806 Train loss: 0.015464 Validation loss: 40.205
# Epoch: 807 Train loss: 0.015465 Validation loss: 40.204
# Epoch: 808 Train loss: 0.015465 Validation loss: 40.202
# Epoch: 809 Train loss: 0.015466 Validation loss: 40.201
# Epoch: 810 Train loss: 0.015466 Validation loss: 40.2
# Epoch: 811 Train loss: 0.015466 Validation loss: 40.198
# Epoch: 812 Train loss: 0.015467 Validation loss: 40.197
# Epoch: 813 Train loss: 0.015467 Validation loss: 40.196
# Epoch: 814 Train loss: 0.015468 Validation loss: 40.195
# Epoch: 815 Train loss: 0.015468 Validation loss: 40.193
# Epoch: 816 Train loss: 0.015468 Validation loss: 40.192
# Epoch: 817 Train loss: 0.015469 Validation loss: 40.191
# Epoch: 818 Train loss: 0.015469 Validation loss: 40.19
# Epoch: 819 Train loss: 0.015469 Validation loss: 40.188
# Epoch: 820 Train loss: 0.01547 Validation loss: 40.187
# Epoch: 821 Train loss: 0.01547 Validation loss: 40.186
# Epoch: 822 Train loss: 0.015471 Validation loss: 40.185
# Epoch: 823 Train loss: 0.015471 Validation loss: 40.183
# Epoch: 824 Train loss: 0.015471 Validation loss: 40.182
# Epoch: 825 Train loss: 0.015472 Validation loss: 40.181
# Epoch: 826 Train loss: 0.015472 Validation loss: 40.18
# Epoch: 827 Train loss: 0.015473 Validation loss: 40.179
# Epoch: 828 Train loss: 0.015473 Validation loss: 40.177
# Epoch: 829 Train loss: 0.015473 Validation loss: 40.176
# Epoch: 830 Train loss: 0.015474 Validation loss: 40.175
# Epoch: 831 Train loss: 0.015474 Validation loss: 40.174
# Epoch: 832 Train loss: 0.015474 Validation loss: 40.173
# Epoch: 833 Train loss: 0.015475 Validation loss: 40.171
# Epoch: 834 Train loss: 0.015475 Validation loss: 40.17
# Epoch: 835 Train loss: 0.015475 Validation loss: 40.169
# Epoch: 836 Train loss: 0.015476 Validation loss: 40.168
# Epoch: 837 Train loss: 0.015476 Validation loss: 40.167
# Epoch: 838 Train loss: 0.015476 Validation loss: 40.166
# Epoch: 839 Train loss: 0.015477 Validation loss: 40.164
# Epoch: 840 Train loss: 0.015477 Validation loss: 40.163
# Epoch: 841 Train loss: 0.015477 Validation loss: 40.162
# Epoch: 842 Train loss: 0.015478 Validation loss: 40.161
# Epoch: 843 Train loss: 0.015478 Validation loss: 40.16
# Epoch: 844 Train loss: 0.015478 Validation loss: 40.159
# Epoch: 845 Train loss: 0.015479 Validation loss: 40.158
# Epoch: 846 Train loss: 0.015479 Validation loss: 40.157
# Epoch: 847 Train loss: 0.015479 Validation loss: 40.155
# Epoch: 848 Train loss: 0.01548 Validation loss: 40.154
# Epoch: 849 Train loss: 0.01548 Validation loss: 40.153
# Epoch: 850 Train loss: 0.01548 Validation loss: 40.152
# Epoch: 851 Train loss: 0.015481 Validation loss: 40.151
# Epoch: 852 Train loss: 0.015481 Validation loss: 40.15
# Epoch: 853 Train loss: 0.015481 Validation loss: 40.149
# Epoch: 854 Train loss: 0.015481 Validation loss: 40.148
# Epoch: 855 Train loss: 0.015482 Validation loss: 40.147
# Epoch: 856 Train loss: 0.015482 Validation loss: 40.146
# Epoch: 857 Train loss: 0.015482 Validation loss: 40.145
# Epoch: 858 Train loss: 0.015483 Validation loss: 40.143
# Epoch: 859 Train loss: 0.015483 Validation loss: 40.142
# Epoch: 860 Train loss: 0.015483 Validation loss: 40.141
# Epoch: 861 Train loss: 0.015483 Validation loss: 40.14
# Epoch: 862 Train loss: 0.015484 Validation loss: 40.139
# Epoch: 863 Train loss: 0.015484 Validation loss: 40.138
# Epoch: 864 Train loss: 0.015484 Validation loss: 40.137
# Epoch: 865 Train loss: 0.015484 Validation loss: 40.136
# Epoch: 866 Train loss: 0.015485 Validation loss: 40.135
# Epoch: 867 Train loss: 0.015485 Validation loss: 40.134
# Epoch: 868 Train loss: 0.015485 Validation loss: 40.133
# Epoch: 869 Train loss: 0.015485 Validation loss: 40.132
# Epoch: 870 Train loss: 0.015485 Validation loss: 40.131
# Epoch: 871 Train loss: 0.015486 Validation loss: 40.13
# Epoch: 872 Train loss: 0.015486 Validation loss: 40.129
# Epoch: 873 Train loss: 0.015486 Validation loss: 40.128
# Epoch: 874 Train loss: 0.015486 Validation loss: 40.127
# Epoch: 875 Train loss: 0.015487 Validation loss: 40.126
# Epoch: 876 Train loss: 0.015487 Validation loss: 40.125
# Epoch: 877 Train loss: 0.015487 Validation loss: 40.124
# Epoch: 878 Train loss: 0.015487 Validation loss: 40.123
# Epoch: 879 Train loss: 0.015487 Validation loss: 40.122
# Epoch: 880 Train loss: 0.015488 Validation loss: 40.121
# Epoch: 881 Train loss: 0.015488 Validation loss: 40.12
# Epoch: 882 Train loss: 0.015488 Validation loss: 40.119
# Epoch: 883 Train loss: 0.015488 Validation loss: 40.118
# Epoch: 884 Train loss: 0.015488 Validation loss: 40.117
# Epoch: 885 Train loss: 0.015488 Validation loss: 40.116
# Epoch: 886 Train loss: 0.015489 Validation loss: 40.115
# Epoch: 887 Train loss: 0.015489 Validation loss: 40.114
# Epoch: 888 Train loss: 0.015489 Validation loss: 40.113
# Epoch: 889 Train loss: 0.015489 Validation loss: 40.112
# Epoch: 890 Train loss: 0.015489 Validation loss: 40.111
# Epoch: 891 Train loss: 0.015489 Validation loss: 40.111
# Epoch: 892 Train loss: 0.015489 Validation loss: 40.11
# Epoch: 893 Train loss: 0.01549 Validation loss: 40.109
# Epoch: 894 Train loss: 0.01549 Validation loss: 40.108
# Epoch: 895 Train loss: 0.01549 Validation loss: 40.107
# Epoch: 896 Train loss: 0.01549 Validation loss: 40.106
# Epoch: 897 Train loss: 0.01549 Validation loss: 40.105
# Epoch: 898 Train loss: 0.01549 Validation loss: 40.104
# Epoch: 899 Train loss: 0.01549 Validation loss: 40.103
# Epoch: 900 Train loss: 0.01549 Validation loss: 40.102
# Epoch: 901 Train loss: 0.015491 Validation loss: 40.101
# Epoch: 902 Train loss: 0.015491 Validation loss: 40.1
# Epoch: 903 Train loss: 0.015491 Validation loss: 40.1
# Epoch: 904 Train loss: 0.015491 Validation loss: 40.099
# Epoch: 905 Train loss: 0.015491 Validation loss: 40.098
# Epoch: 906 Train loss: 0.015491 Validation loss: 40.097
# Epoch: 907 Train loss: 0.015491 Validation loss: 40.096
# Epoch: 908 Train loss: 0.015491 Validation loss: 40.095
# Epoch: 909 Train loss: 0.015491 Validation loss: 40.094
# Epoch: 910 Train loss: 0.015491 Validation loss: 40.093
# Epoch: 911 Train loss: 0.015492 Validation loss: 40.093
# Epoch: 912 Train loss: 0.015492 Validation loss: 40.092
# Epoch: 913 Train loss: 0.015492 Validation loss: 40.091
# Epoch: 914 Train loss: 0.015492 Validation loss: 40.09
# Epoch: 915 Train loss: 0.015492 Validation loss: 40.089
# Epoch: 916 Train loss: 0.015492 Validation loss: 40.088
# Epoch: 917 Train loss: 0.015492 Validation loss: 40.087
# Epoch: 918 Train loss: 0.015492 Validation loss: 40.087
# Epoch: 919 Train loss: 0.015492 Validation loss: 40.086
# Epoch: 920 Train loss: 0.015492 Validation loss: 40.085
# Epoch: 921 Train loss: 0.015492 Validation loss: 40.084
# Epoch: 922 Train loss: 0.015492 Validation loss: 40.083
# Epoch: 923 Train loss: 0.015492 Validation loss: 40.082
# Epoch: 924 Train loss: 0.015492 Validation loss: 40.082
# Epoch: 925 Train loss: 0.015492 Validation loss: 40.081
# Epoch: 926 Train loss: 0.015492 Validation loss: 40.08
# Epoch: 927 Train loss: 0.015492 Validation loss: 40.079
# Epoch: 928 Train loss: 0.015492 Validation loss: 40.078
# Epoch: 929 Train loss: 0.015492 Validation loss: 40.078
# Epoch: 930 Train loss: 0.015493 Validation loss: 40.077
# Epoch: 931 Train loss: 0.015493 Validation loss: 40.076
# Epoch: 932 Train loss: 0.015493 Validation loss: 40.075
# Epoch: 933 Train loss: 0.015493 Validation loss: 40.074
# Epoch: 934 Train loss: 0.015493 Validation loss: 40.074
# Epoch: 935 Train loss: 0.015493 Validation loss: 40.073
# Epoch: 936 Train loss: 0.015493 Validation loss: 40.072
# Epoch: 937 Train loss: 0.015493 Validation loss: 40.071
# Epoch: 938 Train loss: 0.015493 Validation loss: 40.071
# Epoch: 939 Train loss: 0.015493 Validation loss: 40.07
# Epoch: 940 Train loss: 0.015493 Validation loss: 40.069
# Epoch: 941 Train loss: 0.015493 Validation loss: 40.068
# Epoch: 942 Train loss: 0.015493 Validation loss: 40.068
# Epoch: 943 Train loss: 0.015493 Validation loss: 40.067
# Epoch: 944 Train loss: 0.015493 Validation loss: 40.066
# Epoch: 945 Train loss: 0.015493 Validation loss: 40.065
# Epoch: 946 Train loss: 0.015493 Validation loss: 40.065
# Epoch: 947 Train loss: 0.015493 Validation loss: 40.064
# Epoch: 948 Train loss: 0.015493 Validation loss: 40.063
# Epoch: 949 Train loss: 0.015493 Validation loss: 40.062
# Epoch: 950 Train loss: 0.015493 Validation loss: 40.062
# Epoch: 951 Train loss: 0.015493 Validation loss: 40.061
# Epoch: 952 Train loss: 0.015493 Validation loss: 40.06
# Epoch: 953 Train loss: 0.015493 Validation loss: 40.06
# Epoch: 954 Train loss: 0.015493 Validation loss: 40.059
# Epoch: 955 Train loss: 0.015493 Validation loss: 40.058
# Epoch: 956 Train loss: 0.015493 Validation loss: 40.057
# Epoch: 957 Train loss: 0.015493 Validation loss: 40.057
# Epoch: 958 Train loss: 0.015493 Validation loss: 40.056
# Epoch: 959 Train loss: 0.015492 Validation loss: 40.055
# Epoch: 960 Train loss: 0.015492 Validation loss: 40.055
# Epoch: 961 Train loss: 0.015492 Validation loss: 40.054
# Epoch: 962 Train loss: 0.015492 Validation loss: 40.053
# Epoch: 963 Train loss: 0.015492 Validation loss: 40.053
# Epoch: 964 Train loss: 0.015492 Validation loss: 40.052
# Epoch: 965 Train loss: 0.015492 Validation loss: 40.051
# Epoch: 966 Train loss: 0.015492 Validation loss: 40.051
# Epoch: 967 Train loss: 0.015492 Validation loss: 40.05
# Epoch: 968 Train loss: 0.015492 Validation loss: 40.049
# Epoch: 969 Train loss: 0.015492 Validation loss: 40.049
# Epoch: 970 Train loss: 0.015492 Validation loss: 40.048
# Epoch: 971 Train loss: 0.015492 Validation loss: 40.047
# Epoch: 972 Train loss: 0.015492 Validation loss: 40.047
# Epoch: 973 Train loss: 0.015492 Validation loss: 40.046
# Epoch: 974 Train loss: 0.015492 Validation loss: 40.045
# Epoch: 975 Train loss: 0.015492 Validation loss: 40.045
# Epoch: 976 Train loss: 0.015492 Validation loss: 40.044
# Epoch: 977 Train loss: 0.015492 Validation loss: 40.043
# Epoch: 978 Train loss: 0.015492 Validation loss: 40.043
# Epoch: 979 Train loss: 0.015492 Validation loss: 40.042
# Epoch: 980 Train loss: 0.015492 Validation loss: 40.042
# Epoch: 981 Train loss: 0.015492 Validation loss: 40.041
# Epoch: 982 Train loss: 0.015492 Validation loss: 40.04
# Epoch: 983 Train loss: 0.015492 Validation loss: 40.04
# Epoch: 984 Train loss: 0.015492 Validation loss: 40.039
# Epoch: 985 Train loss: 0.015492 Validation loss: 40.039
# Epoch: 986 Train loss: 0.015492 Validation loss: 40.038
# Epoch: 987 Train loss: 0.015492 Validation loss: 40.037
# Epoch: 988 Train loss: 0.015492 Validation loss: 40.037
# Epoch: 989 Train loss: 0.015492 Validation loss: 40.036
# Epoch: 990 Train loss: 0.015492 Validation loss: 40.036
# Epoch: 991 Train loss: 0.015491 Validation loss: 40.035
# Epoch: 992 Train loss: 0.015491 Validation loss: 40.034
# Epoch: 993 Train loss: 0.015491 Validation loss: 40.034
# Epoch: 994 Train loss: 0.015491 Validation loss: 40.033
# Epoch: 995 Train loss: 0.015491 Validation loss: 40.033
# Epoch: 996 Train loss: 0.015491 Validation loss: 40.032
# Epoch: 997 Train loss: 0.015491 Validation loss: 40.032
# Epoch: 998 Train loss: 0.015491 Validation loss: 40.031
# Epoch: 999 Train loss: 0.015491 Validation loss: 40.03

# %% [markdown]
# During the training of the regularized model we can already notice, that, although there is still a difference between training and validation loss, the validation loss decreases as the training loss dreases. The effect of the regularization becomes even more evident if we plot the predictions of the regularized model and the overfitting model.

# %%
""" We now want to plot the prediction of the regularized and unregularized big model. """

y_pred = big_reg_mdl(x)# Predict with "big_reg_mdl" on "x"
y_pred_overfit = big_mdl(x)# Predict with "reg_mdl" on "x"
plt.scatter(x_train_overfit, y_train_overfit)
plt.plot(x, y_true)
plt.plot(x, y_pred.numpy())
plt.plot(x, y_pred_overfit.numpy())
plt.legend(["Target", "Regularization", "No regularization", "Training samples"])
plt.show()

# %% [markdown]
# The model with regularization seems to follow the overall trend of the data, while the model without any regularization very precisely fits the training samples. This is espacilly evident in the interval $\left[0,0.5\right]$, where the prediction of the unregularized model shows an oscillating behavior. Such oscillations are however not present in the ground truth and therefore undesirable. The regularized model on the other hand is not as flexible as the unregularized model and therefore does not fit the target function well in the interval $\left[2.25, 3.0\right]$.
#
# ## Conclusion
# In this exercise we revisited the mathematical background for a simple regression task and covered it's practical implementation in Tensorflow 2. We also explored the phenomenon of overfitting and derived different regularizations from a probabilistic perspective. This exercise covers a very simple task with a very basic neural architecture and is intended as a primer for the second part of the regression exercise, which is dealing with a bigger and more realistic problem. In this second part we will consider the problem of estimating the age of a person from a potrait picture.
